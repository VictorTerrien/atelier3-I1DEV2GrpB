// %% [markdown]
// # ATELIER 2

// %%
import scala.util.Random

case class Employee(
  employeeId: Int,
  lastName: String, 
  firstName: String,
  title: String,
  reportsTo: Int
)

case class MediaType(
  mediaTypeId: Int,
  name: String
)

case class Genre(
  genreId: Int,
  name: String
)

case class Track(
  trackId: Int,
  name: String,
  mediaTypeId: Int,
  genreId: Int
)

case class InvoiceItem(
  invoiceLineId: Int,
  invoiceId: Int,
  trackId: Int,
  unitPrice: BigDecimal,
  quantity: Int,
)

case class Invoice(
  invoiceId: Int,
  items: List[Int]
)


val employees = Array(
  Employee(1, "Adams", "Andrew", "General Manager", 0),
  Employee(2, "Edwards", "Nancy", "Sales Manager", 1), 
  Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  Employee(7, "King", "Robert", "IT Staff", 6),
  Employee(8, "Callahan", "Laura", "IT Staff", 6)
)

val mediaTypes = Array(
  MediaType(1, "MPEG audio file"),
  MediaType(2, "Protected AAC audio file"), 
  MediaType(3, "Protected MPEG-4 video file"),
  MediaType(4, "Purchased AAC audio file"),
  MediaType(5, "AAC audio file")
)

val genres = Array(
  Genre(1, "Rock"), 
  Genre(2, "Jazz"),
  Genre(3, "Metal"), 
  Genre(4, "Alternative & Punk"),
  Genre(5, "Rock And Roll"),
  Genre(6, "Blues"),
  Genre(7, "Latin"),
  Genre(8, "Reggae"),
  Genre(9, "Pop"),
  Genre(10, "Soundtrack"),
  Genre(11, "Bossa Nova"),
  Genre(12, "Easy Listening"),
  Genre(13, "Heavy Metal"), 
  Genre(14, "R&B/Soul"),
  Genre(15, "Electronica/Dance"),
  Genre(16, "World"), 
  Genre(17, "Hip Hop/Rap"),
  Genre(18, "Science Fiction"),
  Genre(19, "TV Shows"), 
  Genre(20, "Sci Fi & Fantasy"),
  Genre(21, "Drama"), 
  Genre(22, "Comedy"), 
  Genre(23, "Alternative"),
  Genre(24, "Classical"), 
  Genre(25, "Opera")
)

val adjectives = Array(
  "Cosmic", "Electric", "Velvet", "Mystic", "Atomic", "Phantom", "Silent", 
  "Savage", "Eternal", "Digital", "Lost", "Sacred", "Wild", "Urban", "Golden", 
  "Crystal", "Liquid", "Toxic", "Neon", "Crimson", "Stellar", "Raging", 
  "Arctic", "Sonic", "Primal", "Midnight", "Screaming", "Infinite", "Royal", "Lunar"
)

val nouns = Array(
  "Echo", "Giants", "Wolves", "Horizon", "Empire", "Void", "Thunder", "Dragons", 
  "Saints", "Kings", "Ghosts", "Ravens", "Pirates", "Heroes", "Rebels", "Demons", 
  "Machines", "Angels", "Knights", "Lions", "Shadows", "Zombies", "Wizards", 
  "Killers", "Titans", "Outlaws", "Rebels", "Prophets", "Bandits", "Warriors"
)

val complements = Array(
  "of Doom", "in Chains", "from Mars", "of the North", "of Death", "in Disguise", 
  "of the Night", "from Hell", "of Tomorrow", "in Flames", "of the Deep", 
  "from Beyond", "of Destruction", "in Shadow", "from the Sky", "of the Abyss", 
  "in Exile", "from the East", "of Eternity", "from the Desert", "of the Underground"
)

object Track {
  def generateTrack(trackId: Int): Track = {
    val randomGenre = genres(Random.nextInt(genres.length))
    val randomMediaType = mediaTypes(Random.nextInt(mediaTypes.length))
    
    val adjective = adjectives(Random.nextInt(adjectives.length))
    val noun = nouns(Random.nextInt(nouns.length))
    val complement = complements(Random.nextInt(complements.length))
    
    val trackName = s"$adjective $noun $complement"
    
    Track(trackId, trackName, randomMediaType.mediaTypeId, randomGenre.genreId)
  }
}


object Invoice {
  def generateInvoice(invoiceId: Int, availableTracks: Array[Track]): Invoice = {
    val itemCount = Random.nextInt(5) + 1
    val selectedTracks = Random.shuffle(availableTracks.toList).take(itemCount)
    
    val items = selectedTracks.zipWithIndex.map { case (track, index) =>
      val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
      val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
      
      InvoiceItem(
        invoiceLineId = invoiceId * 10 + index + 1,
        invoiceId = invoiceId,
        trackId = track.trackId,
        unitPrice = unitPrice,
        quantity = quantity,
      )
    }
    
    Invoice(invoiceId, items.map(_.invoiceLineId))
  }
}

val tracks = for(index <- 1 to 200) yield Track.generateTrack(index)
val tracksArray = tracks.toArray
println("Liste des tracks :")
tracksArray.foreach(println)


val invoices = for(index <- 1 to 2000) yield Invoice.generateInvoice(index, tracksArray)
val invoicesArray = invoices.toArray
println("\nListe des invoices :")
invoicesArray.foreach(println)
// Out:
// Liste des tracks :
// Track(1,Cosmic Zombies from the Desert,3,25)
// Track(2,Sacred Rebels of Eternity,4,1)
// Track(3,Raging Titans of Doom,5,25)
// Track(4,Urban Giants from Hell,5,9)
// Track(5,Phantom Rebels in Flames,4,4)
// Track(6,Atomic Bandits of Doom,3,6)
// Track(7,Lunar Titans of the Underground,2,9)
// Track(8,Toxic Killers in Flames,1,18)
// Track(9,Royal Kings from Beyond,3,2)
// Track(10,Neon Thunder from the Desert,5,18)
// Track(11,Savage Ghosts of Eternity,4,7)
// Track(12,Primal Dragons from Hell,2,7)
// Track(13,Electric Outlaws of the Deep,3,15)
// Track(14,Infinite Killers of Eternity,3,3)
// Track(15,Infinite Empire from the Sky,5,4)
// Track(16,Crystal Prophets of the North,2,18)
// Track(17,Royal Saints in Exile,2,19)
// Track(18,Digital Wolves in Disguise,3,6)
// Track(19,Crystal Echo in Exile,3,5)
// Track(20,Phantom Thunder of Tomorrow,3,17)
// Track(21,Midnight Demons from Mars,1,5)
// Track(22,Raging Heroes of the Underground,2,11)
// Track(23,Stellar Rebels of the North,3,17)
// Track(24,Neon Shadows from the Desert,2,18)
// Track(25,Electric Wolves of Eternity,2,25)
// Track(26,Infinite Prophets of the Deep,2,15)
// Track(27,Digital Warriors of Death,1,21)
// Track(28,Raging Wolves in Shadow,1,17)
// Track(29,Crimson Kings of Death,5,5)
// Track(30,Atomic Shadows in Shadow,5,9)
// Track(31,Lunar Angels of Doom,4,24)
// Track(32,Crimson Wolves from Hell,2,18)
// Track(33,Liquid Prophets from the Desert,3,24)
// Track(34,Crimson Ghosts from the Sky,5,12)
// Track(35,Lunar Void of Destruction,2,2)
// Track(36,Primal Pirates from the East,4,16)
// Track(37,Lost Machines in Shadow,1,9)
// Track(38,Wild Zombies from Beyond,4,1)
// Track(39,Crystal Killers in Shadow,3,22)
// Track(40,Phantom Bandits in Disguise,5,10)
// Track(41,Arctic Outlaws of the Underground,4,8)
// Track(42,Neon Zombies from Mars,1,11)
// Track(43,Urban Void of the Abyss,1,23)
// Track(44,Electric Horizon from Hell,3,6)
// Track(45,Velvet Demons from the Sky,4,9)
// Track(46,Sonic Ghosts in Chains,2,6)
// Track(47,Crimson Lions from Mars,2,22)
// Track(48,Royal Ghosts of the Underground,5,23)
// Track(49,Midnight Titans of Doom,2,16)
// Track(50,Midnight Rebels of the Night,5,11)
// Track(51,Wild Horizon from Beyond,3,7)
// Track(52,Screaming Rebels of the Underground,1,7)
// Track(53,Primal Giants of Death,1,20)
// Track(54,Toxic Wizards in Disguise,1,13)
// Track(55,Eternal Void from the East,1,22)
// Track(56,Stellar Wolves in Shadow,5,1)
// Track(57,Lunar Lions of Doom,1,6)
// Track(58,Primal Rebels from Hell,1,2)
// Track(59,Golden Bandits of the Night,3,17)
// Track(60,Crimson Saints of Doom,5,16)
// Track(61,Cosmic Machines of Doom,2,13)
// Track(62,Electric Machines of Doom,1,6)
// Track(63,Liquid Outlaws from the East,1,1)
// Track(64,Silent Echo in Shadow,5,24)
// Track(65,Savage Kings of Doom,2,17)
// Track(66,Royal Bandits of Destruction,2,6)
// Track(67,Cosmic Horizon of the Deep,3,2)
// Track(68,Electric Demons of Destruction,5,10)
// Track(69,Cosmic Rebels in Exile,2,25)
// Track(70,Lunar Killers of Eternity,4,16)
// Track(71,Crystal Wolves from Beyond,5,23)
// Track(72,Screaming Bandits of Destruction,4,23)
// Track(73,Wild Angels from the East,3,3)
// Track(74,Sacred Prophets of the Underground,4,1)
// Track(75,Infinite Void of the Deep,4,20)
// Track(76,Raging Void from the East,5,12)
// Track(77,Raging Demons of the Underground,3,4)
// Track(78,Wild Wizards of the North,5,9)
// Track(79,Neon Thunder of Death,5,21)
// Track(80,Infinite Wizards in Flames,4,2)
// Track(81,Crystal Saints from the Sky,2,19)
// Track(82,Primal Pirates of Death,5,8)
// Track(83,Electric Heroes in Exile,3,5)
// Track(84,Stellar Horizon in Chains,3,18)
// Track(85,Stellar Void of Eternity,1,13)
// Track(86,Crystal Dragons of Doom,1,1)
// Track(87,Toxic Lions from the Desert,4,16)
// Track(88,Arctic Echo of Tomorrow,2,12)
// Track(89,Lost Titans from the Sky,5,6)
// Track(90,Raging Zombies from the Desert,4,5)
// Track(91,Sonic Wolves from Hell,3,2)
// Track(92,Phantom Bandits of Destruction,3,24)
// Track(93,Electric Void in Disguise,3,9)
// Track(94,Stellar Giants of the Deep,4,12)
// Track(95,Atomic Ghosts in Chains,1,10)
// Track(96,Digital Shadows in Shadow,1,12)
// Track(97,Velvet Prophets of the Underground,2,4)
// Track(98,Arctic Killers of Eternity,5,5)
// Track(99,Electric Wolves in Disguise,3,4)
// Track(100,Toxic Angels from the East,1,25)
// Track(101,Savage Warriors in Chains,5,1)
// Track(102,Mystic Kings of the Night,3,21)
// Track(103,Golden Echo from Beyond,4,2)
// Track(104,Neon Demons in Chains,5,10)
// Track(105,Infinite Shadows of Destruction,2,20)
// Track(106,Sonic Killers of the North,1,9)
// Track(107,Royal Echo of the North,5,2)
// Track(108,Digital Titans of the Abyss,5,14)
// Track(109,Screaming Horizon in Shadow,2,25)
// Track(110,Cosmic Giants from the Desert,3,10)
// Track(111,Silent Warriors from Mars,5,25)
// Track(112,Urban Echo in Shadow,3,19)
// Track(113,Savage Rebels in Disguise,5,22)
// Track(114,Crimson Killers in Disguise,4,8)
// Track(115,Velvet Wolves from Mars,3,22)
// Track(116,Mystic Killers of the Abyss,3,16)
// Track(117,Infinite Thunder of Eternity,1,3)
// Track(118,Toxic Machines from the Desert,1,15)
// Track(119,Liquid Demons in Exile,2,24)
// Track(120,Midnight Wolves in Exile,2,20)
// Track(121,Atomic Void from Mars,5,20)
// Track(122,Lost Lions of the Abyss,3,17)
// Track(123,Atomic Killers of the Underground,2,18)
// Track(124,Stellar Machines from Beyond,5,4)
// Track(125,Primal Void of Death,3,13)
// Track(126,Liquid Ghosts of Death,4,22)
// Track(127,Raging Demons from Beyond,5,23)
// Track(128,Stellar Ravens of Death,3,19)
// Track(129,Lost Demons of the Deep,4,8)
// Track(130,Velvet Killers of Death,4,17)
// Track(131,Atomic Giants in Exile,2,23)
// Track(132,Lost Kings from the Desert,3,2)
// Track(133,Primal Killers of Doom,4,14)
// Track(134,Lunar Prophets of the Night,3,3)
// Track(135,Crimson Wolves from Hell,5,7)
// Track(136,Crimson Outlaws from Mars,4,12)
// Track(137,Arctic Empire of Doom,5,13)
// Track(138,Savage Dragons of the Abyss,2,21)
// Track(139,Mystic Pirates from Hell,5,4)
// Track(140,Raging Outlaws from the Desert,3,12)
// Track(141,Lunar Thunder from Beyond,1,17)
// Track(142,Digital Wizards of Death,5,22)
// Track(143,Royal Killers of the Night,1,10)
// Track(144,Eternal Saints of the Deep,1,10)
// Track(145,Lunar Kings from Beyond,4,13)
// Track(146,Eternal Titans of Death,3,17)
// Track(147,Screaming Wolves of Death,5,6)
// Track(148,Golden Heroes of Doom,5,9)
// Track(149,Urban Ravens from Hell,3,12)
// Track(150,Screaming Wolves in Exile,5,16)
// Track(151,Cosmic Angels of Eternity,1,15)
// Track(152,Velvet Prophets of Death,2,3)
// Track(153,Primal Saints in Disguise,4,18)
// Track(154,Royal Ghosts of Eternity,5,18)
// Track(155,Atomic Thunder of the Deep,1,6)
// Track(156,Wild Zombies of Tomorrow,1,8)
// Track(157,Lunar Warriors in Disguise,4,14)
// Track(158,Golden Demons of the Night,2,14)
// Track(159,Screaming Killers from Hell,4,1)
// Track(160,Electric Prophets of Destruction,2,16)
// Track(161,Atomic Dragons of Eternity,1,13)
// Track(162,Crimson Prophets of the Night,1,14)
// Track(163,Mystic Outlaws from the East,2,16)
// Track(164,Raging Empire in Disguise,2,10)
// Track(165,Midnight Demons of the North,5,1)
// Track(166,Velvet Ravens from the East,2,12)
// Track(167,Primal Void of Death,5,8)
// Track(168,Arctic Rebels in Flames,5,4)
// Track(169,Raging Pirates of the Abyss,1,16)
// Track(170,Velvet Void from Hell,3,8)
// Track(171,Mystic Warriors from the Sky,4,14)
// Track(172,Raging Warriors of the Underground,2,15)
// Track(173,Golden Rebels in Chains,4,7)
// Track(174,Phantom Angels of Doom,4,25)
// Track(175,Liquid Saints of Doom,4,10)
// Track(176,Royal Kings from the Desert,3,9)
// Track(177,Atomic Pirates of Death,5,9)
// Track(178,Crimson Angels of Eternity,2,18)
// Track(179,Liquid Kings of the Night,2,23)
// Track(180,Cosmic Outlaws in Flames,1,5)
// Track(181,Screaming Outlaws of Destruction,3,11)
// Track(182,Neon Void of Death,4,18)
// Track(183,Stellar Pirates from Mars,3,20)
// Track(184,Raging Horizon in Disguise,3,16)
// Track(185,Lunar Wizards from Mars,1,16)
// Track(186,Mystic Heroes from Mars,4,21)
// Track(187,Velvet Outlaws from Mars,3,25)
// Track(188,Toxic Demons of Destruction,3,21)
// Track(189,Royal Shadows of the Deep,1,20)
// Track(190,Atomic Titans of the Underground,5,15)
// Track(191,Screaming Demons in Exile,3,4)
// Track(192,Toxic Zombies from Beyond,5,24)
// Track(193,Royal Machines of the Underground,3,16)
// Track(194,Stellar Knights from the Sky,5,20)
// Track(195,Raging Outlaws of the North,5,15)
// Track(196,Crystal Dragons in Flames,1,23)
// Track(197,Cosmic Zombies of Eternity,1,5)
// Track(198,Silent Ravens from Beyond,3,14)
// Track(199,Digital Outlaws from Beyond,4,21)
// Track(200,Phantom Killers of Death,2,25)
//
// Liste des invoices :
// Invoice(1,List(11, 12))
// Invoice(2,List(21, 22, 23))
// Invoice(3,List(31))
// Invoice(4,List(41, 42, 43, 44))
// Invoice(5,List(51, 52, 53))
// Invoice(6,List(61, 62, 63))
// Invoice(7,List(71, 72, 73, 74, 75))
// Invoice(8,List(81, 82, 83))
// Invoice(9,List(91, 92, 93, 94))
// Invoice(10,List(101, 102, 103, 104))
// Invoice(11,List(111, 112, 113, 114, 115))
// Invoice(12,List(121, 122, 123))
// Invoice(13,List(131, 132, 133, 134, 135))
// Invoice(14,List(141, 142, 143))
// Invoice(15,List(151))
// Invoice(16,List(161, 162, 163))
// Invoice(17,List(171, 172))
// Invoice(18,List(181, 182, 183))
// Invoice(19,List(191))
// Invoice(20,List(201, 202, 203, 204, 205))
// Invoice(21,List(211, 212, 213))
// Invoice(22,List(221, 222, 223, 224))
// Invoice(23,List(231, 232, 233, 234))
// Invoice(24,List(241, 242, 243))
// Invoice(25,List(251, 252))
// Invoice(26,List(261, 262, 263, 264, 265))
// Invoice(27,List(271, 272))
// Invoice(28,List(281, 282, 283))
// Invoice(29,List(291, 292))
// Invoice(30,List(301, 302))
// Invoice(31,List(311, 312))
// Invoice(32,List(321, 322))
// Invoice(33,List(331))
// Invoice(34,List(341, 342, 343))
// Invoice(35,List(351))
// Invoice(36,List(361, 362, 363, 364, 365))
// Invoice(37,List(371, 372, 373))
// Invoice(38,List(381, 382, 383, 384, 385))
// Invoice(39,List(391, 392, 393, 394, 395))
// Invoice(40,List(401, 402))
// Invoice(41,List(411, 412, 413))
// Invoice(42,List(421, 422, 423, 424))
// Invoice(43,List(431, 432, 433, 434, 435))
// Invoice(44,List(441))
// Invoice(45,List(451, 452, 453, 454))
// Invoice(46,List(461, 462))
// Invoice(47,List(471))
// Invoice(48,List(481, 482, 483, 484, 485))
// Invoice(49,List(491))
// Invoice(50,List(501, 502, 503, 504, 505))
// Invoice(51,List(511, 512, 513, 514))
// Invoice(52,List(521, 522, 523))
// Invoice(53,List(531, 532, 533, 534))
// Invoice(54,List(541, 542, 543, 544))
// Invoice(55,List(551, 552, 553))
// Invoice(56,List(561, 562))
// Invoice(57,List(571))
// Invoice(58,List(581, 582, 583, 584, 585))
// Invoice(59,List(591, 592, 593))
// Invoice(60,List(601, 602, 603, 604))
// Invoice(61,List(611, 612))
// Invoice(62,List(621))
// Invoice(63,List(631, 632, 633))
// Invoice(64,List(641, 642, 643, 644, 645))
// Invoice(65,List(651, 652, 653, 654, 655))
// Invoice(66,List(661, 662, 663))
// Invoice(67,List(671, 672, 673, 674, 675))
// Invoice(68,List(681))
// Invoice(69,List(691, 692, 693))
// Invoice(70,List(701, 702))
// Invoice(71,List(711))
// Invoice(72,List(721, 722, 723, 724))
// Invoice(73,List(731, 732, 733, 734, 735))
// Invoice(74,List(741))
// Invoice(75,List(751, 752))
// Invoice(76,List(761, 762, 763, 764, 765))
// Invoice(77,List(771, 772, 773, 774))
// Invoice(78,List(781, 782))
// Invoice(79,List(791, 792, 793))
// Invoice(80,List(801, 802))
// Invoice(81,List(811, 812, 813))
// Invoice(82,List(821, 822, 823, 824, 825))
// Invoice(83,List(831, 832, 833, 834))
// Invoice(84,List(841, 842, 843))
// Invoice(85,List(851, 852))
// Invoice(86,List(861, 862, 863, 864, 865))
// Invoice(87,List(871, 872, 873))
// Invoice(88,List(881, 882, 883, 884))
// Invoice(89,List(891))
// Invoice(90,List(901, 902, 903, 904, 905))
// Invoice(91,List(911))
// Invoice(92,List(921, 922, 923))
// Invoice(93,List(931, 932, 933))
// Invoice(94,List(941, 942, 943, 944))
// Invoice(95,List(951, 952, 953, 954, 955))
// Invoice(96,List(961, 962, 963, 964, 965))
// Invoice(97,List(971, 972, 973, 974))
// Invoice(98,List(981, 982, 983, 984))
// Invoice(99,List(991, 992, 993, 994))
// Invoice(100,List(1001, 1002))
// Invoice(101,List(1011))
// Invoice(102,List(1021, 1022))
// Invoice(103,List(1031, 1032, 1033, 1034))
// Invoice(104,List(1041, 1042, 1043, 1044))
// Invoice(105,List(1051, 1052, 1053, 1054))
// Invoice(106,List(1061, 1062, 1063, 1064))
// Invoice(107,List(1071))
// Invoice(108,List(1081, 1082, 1083, 1084, 1085))
// Invoice(109,List(1091))
// Invoice(110,List(1101, 1102))
// Invoice(111,List(1111, 1112, 1113, 1114, 1115))
// Invoice(112,List(1121, 1122, 1123, 1124))
// Invoice(113,List(1131, 1132, 1133))
// Invoice(114,List(1141, 1142, 1143))
// Invoice(115,List(1151, 1152, 1153, 1154, 1155))
// Invoice(116,List(1161, 1162, 1163))
// Invoice(117,List(1171, 1172, 1173, 1174, 1175))
// Invoice(118,List(1181, 1182, 1183))
// Invoice(119,List(1191))
// Invoice(120,List(1201, 1202, 1203))
// Invoice(121,List(1211, 1212))
// Invoice(122,List(1221, 1222, 1223, 1224))
// Invoice(123,List(1231, 1232))
// Invoice(124,List(1241, 1242, 1243, 1244, 1245))
// Invoice(125,List(1251, 1252, 1253, 1254, 1255))
// Invoice(126,List(1261, 1262, 1263, 1264))
// Invoice(127,List(1271))
// Invoice(128,List(1281, 1282, 1283, 1284, 1285))
// Invoice(129,List(1291, 1292, 1293))
// Invoice(130,List(1301, 1302))
// Invoice(131,List(1311, 1312, 1313, 1314))
// Invoice(132,List(1321))
// Invoice(133,List(1331, 1332, 1333, 1334))
// Invoice(134,List(1341, 1342))
// Invoice(135,List(1351, 1352, 1353))
// Invoice(136,List(1361, 1362))
// Invoice(137,List(1371, 1372, 1373, 1374))
// Invoice(138,List(1381, 1382, 1383))
// Invoice(139,List(1391, 1392))
// Invoice(140,List(1401, 1402, 1403, 1404, 1405))
// Invoice(141,List(1411, 1412, 1413, 1414, 1415))
// Invoice(142,List(1421, 1422, 1423, 1424, 1425))
// Invoice(143,List(1431, 1432, 1433, 1434, 1435))
// Invoice(144,List(1441, 1442))
// Invoice(145,List(1451, 1452, 1453, 1454, 1455))
// Invoice(146,List(1461, 1462))
// Invoice(147,List(1471, 1472))
// Invoice(148,List(1481))
// Invoice(149,List(1491, 1492))
// Invoice(150,List(1501, 1502, 1503, 1504))
// Invoice(151,List(1511, 1512, 1513, 1514))
// Invoice(152,List(1521))
// Invoice(153,List(1531))
// Invoice(154,List(1541))
// Invoice(155,List(1551))
// Invoice(156,List(1561))
// Invoice(157,List(1571))
// Invoice(158,List(1581, 1582, 1583))
// Invoice(159,List(1591))
// Invoice(160,List(1601, 1602, 1603, 1604, 1605))
// Invoice(161,List(1611, 1612, 1613))
// Invoice(162,List(1621, 1622))
// Invoice(163,List(1631))
// Invoice(164,List(1641, 1642, 1643, 1644, 1645))
// Invoice(165,List(1651, 1652, 1653))
// Invoice(166,List(1661, 1662))
// Invoice(167,List(1671, 1672, 1673))
// Invoice(168,List(1681))
// Invoice(169,List(1691, 1692, 1693))
// Invoice(170,List(1701, 1702, 1703))
// Invoice(171,List(1711))
// Invoice(172,List(1721))
// Invoice(173,List(1731, 1732))
// Invoice(174,List(1741, 1742, 1743, 1744))
// Invoice(175,List(1751, 1752, 1753))
// Invoice(176,List(1761, 1762, 1763, 1764))
// Invoice(177,List(1771, 1772, 1773))
// Invoice(178,List(1781))
// Invoice(179,List(1791, 1792, 1793))
// Invoice(180,List(1801, 1802, 1803, 1804, 1805))
// Invoice(181,List(1811, 1812, 1813, 1814))
// Invoice(182,List(1821))
// Invoice(183,List(1831, 1832, 1833))
// Invoice(184,List(1841, 1842, 1843, 1844))
// Invoice(185,List(1851, 1852, 1853, 1854, 1855))
// Invoice(186,List(1861, 1862, 1863, 1864, 1865))
// Invoice(187,List(1871, 1872, 1873, 1874, 1875))
// Invoice(188,List(1881, 1882, 1883))
// Invoice(189,List(1891, 1892))
// Invoice(190,List(1901, 1902, 1903, 1904, 1905))
// Invoice(191,List(1911, 1912, 1913))
// Invoice(192,List(1921, 1922, 1923, 1924, 1925))
// Invoice(193,List(1931, 1932, 1933, 1934, 1935))
// Invoice(194,List(1941, 1942, 1943, 1944, 1945))
// Invoice(195,List(1951))
// Invoice(196,List(1961, 1962, 1963))
// Invoice(197,List(1971, 1972))
// Invoice(198,List(1981, 1982, 1983, 1984))
// Invoice(199,List(1991, 1992, 1993, 1994, 1995))
// Invoice(200,List(2001, 2002, 2003, 2004, 2005))
// Invoice(201,List(2011, 2012, 2013, 2014))
// Invoice(202,List(2021, 2022, 2023, 2024, 2025))
// Invoice(203,List(2031, 2032, 2033, 2034))
// Invoice(204,List(2041, 2042))
// Invoice(205,List(2051, 2052, 2053, 2054, 2055))
// Invoice(206,List(2061, 2062, 2063, 2064))
// Invoice(207,List(2071))
// Invoice(208,List(2081, 2082, 2083, 2084, 2085))
// Invoice(209,List(2091, 2092, 2093))
// Invoice(210,List(2101, 2102))
// Invoice(211,List(2111, 2112, 2113, 2114))
// Invoice(212,List(2121, 2122))
// Invoice(213,List(2131, 2132, 2133))
// Invoice(214,List(2141, 2142, 2143, 2144, 2145))
// Invoice(215,List(2151, 2152))
// Invoice(216,List(2161, 2162, 2163, 2164, 2165))
// Invoice(217,List(2171, 2172, 2173))
// Invoice(218,List(2181, 2182, 2183, 2184))
// Invoice(219,List(2191, 2192, 2193, 2194))
// Invoice(220,List(2201, 2202))
// Invoice(221,List(2211))
// Invoice(222,List(2221, 2222))
// Invoice(223,List(2231, 2232))
// Invoice(224,List(2241))
// Invoice(225,List(2251, 2252, 2253, 2254))
// Invoice(226,List(2261, 2262))
// Invoice(227,List(2271))
// Invoice(228,List(2281, 2282))
// Invoice(229,List(2291, 2292))
// Invoice(230,List(2301))
// Invoice(231,List(2311))
// Invoice(232,List(2321, 2322))
// Invoice(233,List(2331, 2332, 2333, 2334))
// Invoice(234,List(2341, 2342))
// Invoice(235,List(2351, 2352, 2353))
// Invoice(236,List(2361, 2362, 2363))
// Invoice(237,List(2371, 2372))
// Invoice(238,List(2381, 2382))
// Invoice(239,List(2391))
// Invoice(240,List(2401, 2402))
// Invoice(241,List(2411, 2412))
// Invoice(242,List(2421, 2422, 2423, 2424))
// Invoice(243,List(2431, 2432, 2433, 2434))
// Invoice(244,List(2441, 2442, 2443))
// Invoice(245,List(2451, 2452, 2453, 2454, 2455))
// Invoice(246,List(2461))
// Invoice(247,List(2471, 2472, 2473, 2474, 2475))
// Invoice(248,List(2481, 2482, 2483))
// Invoice(249,List(2491, 2492, 2493))
// Invoice(250,List(2501))
// Invoice(251,List(2511))
// Invoice(252,List(2521, 2522, 2523, 2524, 2525))
// Invoice(253,List(2531, 2532, 2533, 2534, 2535))
// Invoice(254,List(2541, 2542, 2543, 2544))
// Invoice(255,List(2551, 2552))
// Invoice(256,List(2561, 2562, 2563, 2564, 2565))
// Invoice(257,List(2571, 2572, 2573, 2574, 2575))
// Invoice(258,List(2581, 2582, 2583))
// Invoice(259,List(2591, 2592, 2593, 2594))
// Invoice(260,List(2601, 2602))
// Invoice(261,List(2611, 2612, 2613))
// Invoice(262,List(2621, 2622, 2623, 2624, 2625))
// Invoice(263,List(2631, 2632, 2633, 2634))
// Invoice(264,List(2641, 2642))
// Invoice(265,List(2651, 2652, 2653, 2654, 2655))
// Invoice(266,List(2661, 2662, 2663, 2664))
// Invoice(267,List(2671, 2672))
// Invoice(268,List(2681))
// Invoice(269,List(2691, 2692, 2693, 2694))
// Invoice(270,List(2701, 2702, 2703, 2704, 2705))
// Invoice(271,List(2711))
// Invoice(272,List(2721))
// Invoice(273,List(2731))
// Invoice(274,List(2741, 2742, 2743, 2744, 2745))
// Invoice(275,List(2751))
// Invoice(276,List(2761, 2762, 2763))
// Invoice(277,List(2771))
// Invoice(278,List(2781, 2782, 2783, 2784))
// Invoice(279,List(2791, 2792))
// Invoice(280,List(2801, 2802, 2803, 2804, 2805))
// Invoice(281,List(2811, 2812, 2813, 2814))
// Invoice(282,List(2821, 2822, 2823, 2824, 2825))
// Invoice(283,List(2831, 2832, 2833, 2834, 2835))
// Invoice(284,List(2841, 2842, 2843))
// Invoice(285,List(2851))
// Invoice(286,List(2861, 2862, 2863))
// Invoice(287,List(2871, 2872))
// Invoice(288,List(2881, 2882))
// Invoice(289,List(2891, 2892, 2893, 2894))
// Invoice(290,List(2901, 2902, 2903, 2904))
// Invoice(291,List(2911))
// Invoice(292,List(2921, 2922, 2923, 2924))
// Invoice(293,List(2931, 2932, 2933, 2934))
// Invoice(294,List(2941, 2942))
// Invoice(295,List(2951, 2952, 2953, 2954, 2955))
// Invoice(296,List(2961, 2962, 2963, 2964, 2965))
// Invoice(297,List(2971, 2972, 2973))
// Invoice(298,List(2981, 2982, 2983, 2984, 2985))
// Invoice(299,List(2991, 2992, 2993, 2994))
// Invoice(300,List(3001, 3002))
// Invoice(301,List(3011, 3012, 3013, 3014))
// Invoice(302,List(3021, 3022, 3023))
// Invoice(303,List(3031, 3032))
// Invoice(304,List(3041, 3042))
// Invoice(305,List(3051, 3052, 3053))
// Invoice(306,List(3061, 3062, 3063, 3064))
// Invoice(307,List(3071, 3072, 3073, 3074, 3075))
// Invoice(308,List(3081, 3082))
// Invoice(309,List(3091, 3092, 3093, 3094))
// Invoice(310,List(3101))
// Invoice(311,List(3111, 3112, 3113))
// Invoice(312,List(3121, 3122, 3123, 3124, 3125))
// Invoice(313,List(3131, 3132))
// Invoice(314,List(3141, 3142, 3143, 3144))
// Invoice(315,List(3151, 3152, 3153, 3154))
// Invoice(316,List(3161, 3162))
// Invoice(317,List(3171, 3172))
// Invoice(318,List(3181))
// Invoice(319,List(3191, 3192))
// Invoice(320,List(3201, 3202, 3203, 3204))
// Invoice(321,List(3211, 3212, 3213))
// Invoice(322,List(3221, 3222, 3223))
// Invoice(323,List(3231, 3232))
// Invoice(324,List(3241, 3242, 3243, 3244, 3245))
// Invoice(325,List(3251, 3252))
// Invoice(326,List(3261, 3262, 3263, 3264, 3265))
// Invoice(327,List(3271, 3272, 3273, 3274, 3275))
// Invoice(328,List(3281, 3282, 3283))
// Invoice(329,List(3291, 3292, 3293))
// Invoice(330,List(3301, 3302, 3303))
// Invoice(331,List(3311, 3312, 3313, 3314))
// Invoice(332,List(3321, 3322, 3323))
// Invoice(333,List(3331))
// Invoice(334,List(3341, 3342, 3343))
// Invoice(335,List(3351, 3352, 3353, 3354, 3355))
// Invoice(336,List(3361, 3362, 3363, 3364))
// Invoice(337,List(3371))
// Invoice(338,List(3381))
// Invoice(339,List(3391, 3392, 3393))
// Invoice(340,List(3401, 3402, 3403))
// Invoice(341,List(3411))
// Invoice(342,List(3421, 3422, 3423))
// Invoice(343,List(3431, 3432, 3433, 3434, 3435))
// Invoice(344,List(3441, 3442, 3443))
// Invoice(345,List(3451, 3452))
// Invoice(346,List(3461, 3462))
// Invoice(347,List(3471))
// Invoice(348,List(3481))
// Invoice(349,List(3491, 3492, 3493, 3494))
// Invoice(350,List(3501, 3502, 3503))
// Invoice(351,List(3511, 3512, 3513))
// Invoice(352,List(3521, 3522, 3523, 3524, 3525))
// Invoice(353,List(3531, 3532, 3533))
// Invoice(354,List(3541, 3542, 3543, 3544, 3545))
// Invoice(355,List(3551, 3552, 3553, 3554))
// Invoice(356,List(3561, 3562, 3563, 3564, 3565))
// Invoice(357,List(3571, 3572, 3573, 3574, 3575))
// Invoice(358,List(3581, 3582))
// Invoice(359,List(3591))
// Invoice(360,List(3601, 3602))
// Invoice(361,List(3611, 3612))
// Invoice(362,List(3621, 3622, 3623))
// Invoice(363,List(3631))
// Invoice(364,List(3641, 3642, 3643, 3644, 3645))
// Invoice(365,List(3651, 3652))
// Invoice(366,List(3661, 3662, 3663, 3664))
// Invoice(367,List(3671, 3672, 3673))
// Invoice(368,List(3681))
// Invoice(369,List(3691, 3692))
// Invoice(370,List(3701))
// Invoice(371,List(3711, 3712, 3713, 3714, 3715))
// Invoice(372,List(3721, 3722, 3723))
// Invoice(373,List(3731, 3732, 3733, 3734))
// Invoice(374,List(3741, 3742, 3743))
// Invoice(375,List(3751, 3752, 3753, 3754, 3755))
// Invoice(376,List(3761, 3762, 3763, 3764, 3765))
// Invoice(377,List(3771, 3772, 3773))
// Invoice(378,List(3781, 3782, 3783, 3784, 3785))
// Invoice(379,List(3791, 3792))
// Invoice(380,List(3801))
// Invoice(381,List(3811, 3812))
// Invoice(382,List(3821, 3822, 3823, 3824, 3825))
// Invoice(383,List(3831, 3832, 3833, 3834, 3835))
// Invoice(384,List(3841))
// Invoice(385,List(3851, 3852, 3853))
// Invoice(386,List(3861, 3862, 3863, 3864))
// Invoice(387,List(3871))
// Invoice(388,List(3881, 3882, 3883, 3884, 3885))
// Invoice(389,List(3891, 3892, 3893, 3894, 3895))
// Invoice(390,List(3901, 3902, 3903, 3904, 3905))
// Invoice(391,List(3911))
// Invoice(392,List(3921, 3922, 3923, 3924, 3925))
// Invoice(393,List(3931))
// Invoice(394,List(3941, 3942))
// Invoice(395,List(3951, 3952, 3953, 3954, 3955))
// Invoice(396,List(3961))
// Invoice(397,List(3971, 3972, 3973, 3974))
// Invoice(398,List(3981))
// Invoice(399,List(3991))
// Invoice(400,List(4001, 4002))
// Invoice(401,List(4011))
// Invoice(402,List(4021, 4022, 4023, 4024))
// Invoice(403,List(4031))
// Invoice(404,List(4041, 4042, 4043, 4044, 4045))
// Invoice(405,List(4051))
// Invoice(406,List(4061, 4062, 4063, 4064, 4065))
// Invoice(407,List(4071))
// Invoice(408,List(4081, 4082, 4083, 4084))
// Invoice(409,List(4091, 4092, 4093, 4094, 4095))
// Invoice(410,List(4101))
// Invoice(411,List(4111, 4112, 4113, 4114, 4115))
// Invoice(412,List(4121, 4122, 4123, 4124))
// Invoice(413,List(4131))
// Invoice(414,List(4141, 4142))
// Invoice(415,List(4151))
// Invoice(416,List(4161, 4162))
// Invoice(417,List(4171, 4172, 4173, 4174))
// Invoice(418,List(4181))
// Invoice(419,List(4191, 4192, 4193, 4194, 4195))
// Invoice(420,List(4201, 4202, 4203, 4204, 4205))
// Invoice(421,List(4211, 4212))
// Invoice(422,List(4221, 4222, 4223))
// Invoice(423,List(4231, 4232, 4233, 4234, 4235))
// Invoice(424,List(4241, 4242, 4243))
// Invoice(425,List(4251, 4252, 4253, 4254))
// Invoice(426,List(4261, 4262, 4263))
// Invoice(427,List(4271, 4272))
// Invoice(428,List(4281))
// Invoice(429,List(4291, 4292, 4293, 4294))
// Invoice(430,List(4301, 4302, 4303))
// Invoice(431,List(4311, 4312, 4313))
// Invoice(432,List(4321, 4322))
// Invoice(433,List(4331))
// Invoice(434,List(4341, 4342, 4343, 4344, 4345))
// Invoice(435,List(4351, 4352, 4353, 4354, 4355))
// Invoice(436,List(4361, 4362, 4363))
// Invoice(437,List(4371, 4372, 4373, 4374))
// Invoice(438,List(4381, 4382, 4383, 4384, 4385))
// Invoice(439,List(4391, 4392))
// Invoice(440,List(4401))
// Invoice(441,List(4411))
// Invoice(442,List(4421))
// Invoice(443,List(4431, 4432, 4433))
// Invoice(444,List(4441))
// Invoice(445,List(4451, 4452))
// Invoice(446,List(4461, 4462, 4463))
// Invoice(447,List(4471, 4472))
// Invoice(448,List(4481, 4482))
// Invoice(449,List(4491, 4492, 4493, 4494))
// Invoice(450,List(4501, 4502))
// Invoice(451,List(4511))
// Invoice(452,List(4521, 4522, 4523))
// Invoice(453,List(4531, 4532, 4533))
// Invoice(454,List(4541, 4542, 4543, 4544, 4545))
// Invoice(455,List(4551, 4552))
// Invoice(456,List(4561))
// Invoice(457,List(4571, 4572, 4573, 4574))
// Invoice(458,List(4581, 4582, 4583, 4584, 4585))
// Invoice(459,List(4591, 4592))
// Invoice(460,List(4601, 4602, 4603, 4604))
// Invoice(461,List(4611))
// Invoice(462,List(4621, 4622, 4623))
// Invoice(463,List(4631, 4632, 4633, 4634, 4635))
// Invoice(464,List(4641, 4642))
// Invoice(465,List(4651, 4652, 4653, 4654))
// Invoice(466,List(4661, 4662, 4663, 4664, 4665))
// Invoice(467,List(4671, 4672, 4673))
// Invoice(468,List(4681))
// Invoice(469,List(4691, 4692))
// Invoice(470,List(4701, 4702, 4703, 4704))
// Invoice(471,List(4711, 4712, 4713, 4714))
// Invoice(472,List(4721, 4722, 4723, 4724, 4725))
// Invoice(473,List(4731, 4732, 4733))
// Invoice(474,List(4741, 4742))
// Invoice(475,List(4751, 4752))
// Invoice(476,List(4761, 4762, 4763))
// Invoice(477,List(4771, 4772, 4773, 4774, 4775))
// Invoice(478,List(4781))
// Invoice(479,List(4791))
// Invoice(480,List(4801))
// Invoice(481,List(4811, 4812, 4813, 4814))
// Invoice(482,List(4821, 4822, 4823, 4824, 4825))
// Invoice(483,List(4831))
// Invoice(484,List(4841, 4842, 4843, 4844))
// Invoice(485,List(4851, 4852, 4853, 4854))
// Invoice(486,List(4861, 4862, 4863, 4864))
// Invoice(487,List(4871, 4872, 4873))
// Invoice(488,List(4881, 4882, 4883, 4884))
// Invoice(489,List(4891, 4892, 4893, 4894))
// Invoice(490,List(4901, 4902, 4903))
// Invoice(491,List(4911, 4912, 4913, 4914))
// Invoice(492,List(4921, 4922, 4923, 4924, 4925))
// Invoice(493,List(4931, 4932, 4933, 4934))
// Invoice(494,List(4941))
// Invoice(495,List(4951, 4952, 4953))
// Invoice(496,List(4961, 4962, 4963, 4964))
// Invoice(497,List(4971, 4972))
// Invoice(498,List(4981))
// Invoice(499,List(4991, 4992, 4993))
// Invoice(500,List(5001, 5002))
// Invoice(501,List(5011, 5012, 5013))
// Invoice(502,List(5021, 5022, 5023, 5024))
// Invoice(503,List(5031, 5032, 5033))
// Invoice(504,List(5041, 5042))
// Invoice(505,List(5051))
// Invoice(506,List(5061, 5062))
// Invoice(507,List(5071))
// Invoice(508,List(5081))
// Invoice(509,List(5091))
// Invoice(510,List(5101, 5102, 5103, 5104, 5105))
// Invoice(511,List(5111, 5112, 5113))
// Invoice(512,List(5121, 5122, 5123, 5124, 5125))
// Invoice(513,List(5131, 5132, 5133, 5134))
// Invoice(514,List(5141, 5142))
// Invoice(515,List(5151, 5152, 5153))
// Invoice(516,List(5161, 5162, 5163, 5164))
// Invoice(517,List(5171))
// Invoice(518,List(5181, 5182, 5183, 5184))
// Invoice(519,List(5191, 5192))
// Invoice(520,List(5201))
// Invoice(521,List(5211, 5212, 5213, 5214, 5215))
// Invoice(522,List(5221, 5222, 5223))
// Invoice(523,List(5231, 5232, 5233, 5234))
// Invoice(524,List(5241, 5242, 5243, 5244))
// Invoice(525,List(5251, 5252, 5253, 5254, 5255))
// Invoice(526,List(5261, 5262, 5263, 5264))
// Invoice(527,List(5271, 5272, 5273, 5274, 5275))
// Invoice(528,List(5281, 5282, 5283, 5284))
// Invoice(529,List(5291, 5292, 5293))
// Invoice(530,List(5301, 5302, 5303))
// Invoice(531,List(5311, 5312, 5313))
// Invoice(532,List(5321, 5322, 5323, 5324))
// Invoice(533,List(5331, 5332, 5333))
// Invoice(534,List(5341))
// Invoice(535,List(5351, 5352, 5353))
// Invoice(536,List(5361, 5362))
// Invoice(537,List(5371))
// Invoice(538,List(5381, 5382, 5383, 5384, 5385))
// Invoice(539,List(5391))
// Invoice(540,List(5401, 5402))
// Invoice(541,List(5411, 5412, 5413, 5414))
// Invoice(542,List(5421, 5422, 5423))
// Invoice(543,List(5431, 5432, 5433, 5434))
// Invoice(544,List(5441, 5442))
// Invoice(545,List(5451, 5452))
// Invoice(546,List(5461))
// Invoice(547,List(5471, 5472, 5473, 5474))
// Invoice(548,List(5481, 5482, 5483, 5484))
// Invoice(549,List(5491, 5492, 5493, 5494, 5495))
// Invoice(550,List(5501, 5502))
// Invoice(551,List(5511, 5512, 5513, 5514, 5515))
// Invoice(552,List(5521, 5522))
// Invoice(553,List(5531, 5532))
// Invoice(554,List(5541, 5542))
// Invoice(555,List(5551))
// Invoice(556,List(5561, 5562, 5563, 5564))
// Invoice(557,List(5571, 5572, 5573, 5574))
// Invoice(558,List(5581))
// Invoice(559,List(5591, 5592, 5593, 5594))
// Invoice(560,List(5601))
// Invoice(561,List(5611, 5612, 5613, 5614, 5615))
// Invoice(562,List(5621, 5622, 5623, 5624, 5625))
// Invoice(563,List(5631, 5632))
// Invoice(564,List(5641, 5642, 5643))
// Invoice(565,List(5651, 5652, 5653, 5654))
// Invoice(566,List(5661, 5662, 5663, 5664))
// Invoice(567,List(5671, 5672, 5673, 5674))
// Invoice(568,List(5681, 5682))
// Invoice(569,List(5691, 5692, 5693))
// Invoice(570,List(5701, 5702, 5703))
// Invoice(571,List(5711, 5712, 5713))
// Invoice(572,List(5721))
// Invoice(573,List(5731, 5732, 5733, 5734))
// Invoice(574,List(5741, 5742, 5743, 5744))
// Invoice(575,List(5751, 5752))
// Invoice(576,List(5761, 5762))
// Invoice(577,List(5771))
// Invoice(578,List(5781, 5782, 5783, 5784, 5785))
// Invoice(579,List(5791, 5792, 5793))
// Invoice(580,List(5801, 5802, 5803))
// Invoice(581,List(5811, 5812, 5813, 5814))
// Invoice(582,List(5821, 5822, 5823, 5824))
// Invoice(583,List(5831, 5832, 5833, 5834, 5835))
// Invoice(584,List(5841, 5842, 5843, 5844))
// Invoice(585,List(5851, 5852, 5853, 5854, 5855))
// Invoice(586,List(5861, 5862, 5863, 5864, 5865))
// Invoice(587,List(5871, 5872))
// Invoice(588,List(5881, 5882, 5883, 5884, 5885))
// Invoice(589,List(5891, 5892, 5893))
// Invoice(590,List(5901))
// Invoice(591,List(5911))
// Invoice(592,List(5921, 5922))
// Invoice(593,List(5931, 5932, 5933, 5934, 5935))
// Invoice(594,List(5941))
// Invoice(595,List(5951, 5952, 5953, 5954))
// Invoice(596,List(5961, 5962))
// Invoice(597,List(5971))
// Invoice(598,List(5981))
// Invoice(599,List(5991, 5992, 5993, 5994))
// Invoice(600,List(6001))
// Invoice(601,List(6011, 6012, 6013, 6014))
// Invoice(602,List(6021, 6022, 6023))
// Invoice(603,List(6031, 6032))
// Invoice(604,List(6041, 6042, 6043))
// Invoice(605,List(6051))
// Invoice(606,List(6061, 6062))
// Invoice(607,List(6071, 6072, 6073))
// Invoice(608,List(6081, 6082))
// Invoice(609,List(6091, 6092, 6093, 6094))
// Invoice(610,List(6101, 6102))
// Invoice(611,List(6111))
// Invoice(612,List(6121, 6122, 6123, 6124, 6125))
// Invoice(613,List(6131, 6132, 6133, 6134, 6135))
// Invoice(614,List(6141, 6142, 6143, 6144))
// Invoice(615,List(6151, 6152, 6153))
// Invoice(616,List(6161, 6162, 6163, 6164))
// Invoice(617,List(6171, 6172, 6173, 6174, 6175))
// Invoice(618,List(6181, 6182))
// Invoice(619,List(6191, 6192, 6193, 6194))
// Invoice(620,List(6201, 6202, 6203, 6204, 6205))
// Invoice(621,List(6211))
// Invoice(622,List(6221, 6222, 6223, 6224, 6225))
// Invoice(623,List(6231, 6232, 6233, 6234))
// Invoice(624,List(6241, 6242, 6243))
// Invoice(625,List(6251, 6252))
// Invoice(626,List(6261, 6262, 6263, 6264, 6265))
// Invoice(627,List(6271, 6272))
// Invoice(628,List(6281, 6282))
// Invoice(629,List(6291, 6292, 6293))
// Invoice(630,List(6301))
// Invoice(631,List(6311, 6312, 6313, 6314))
// Invoice(632,List(6321, 6322, 6323, 6324))
// Invoice(633,List(6331))
// Invoice(634,List(6341, 6342, 6343, 6344, 6345))
// Invoice(635,List(6351, 6352, 6353, 6354))
// Invoice(636,List(6361, 6362, 6363, 6364, 6365))
// Invoice(637,List(6371, 6372, 6373, 6374))
// Invoice(638,List(6381, 6382))
// Invoice(639,List(6391))
// Invoice(640,List(6401, 6402, 6403, 6404))
// Invoice(641,List(6411))
// Invoice(642,List(6421, 6422))
// Invoice(643,List(6431, 6432))
// Invoice(644,List(6441))
// Invoice(645,List(6451, 6452, 6453, 6454, 6455))
// Invoice(646,List(6461, 6462, 6463))
// Invoice(647,List(6471, 6472, 6473, 6474, 6475))
// Invoice(648,List(6481, 6482))
// Invoice(649,List(6491, 6492, 6493, 6494))
// Invoice(650,List(6501))
// Invoice(651,List(6511, 6512, 6513))
// Invoice(652,List(6521, 6522))
// Invoice(653,List(6531, 6532))
// Invoice(654,List(6541, 6542, 6543))
// Invoice(655,List(6551, 6552))
// Invoice(656,List(6561, 6562, 6563, 6564, 6565))
// Invoice(657,List(6571, 6572, 6573, 6574, 6575))
// Invoice(658,List(6581, 6582, 6583, 6584))
// Invoice(659,List(6591, 6592))
// Invoice(660,List(6601, 6602, 6603, 6604, 6605))
// Invoice(661,List(6611, 6612, 6613, 6614, 6615))
// Invoice(662,List(6621, 6622, 6623, 6624, 6625))
// Invoice(663,List(6631, 6632, 6633))
// Invoice(664,List(6641))
// Invoice(665,List(6651, 6652))
// Invoice(666,List(6661, 6662))
// Invoice(667,List(6671, 6672, 6673, 6674))
// Invoice(668,List(6681, 6682, 6683, 6684))
// Invoice(669,List(6691, 6692))
// Invoice(670,List(6701, 6702, 6703, 6704))
// Invoice(671,List(6711))
// Invoice(672,List(6721))
// Invoice(673,List(6731, 6732, 6733))
// Invoice(674,List(6741, 6742, 6743, 6744, 6745))
// Invoice(675,List(6751, 6752))
// Invoice(676,List(6761))
// Invoice(677,List(6771, 6772, 6773))
// Invoice(678,List(6781))
// Invoice(679,List(6791, 6792, 6793, 6794, 6795))
// Invoice(680,List(6801, 6802))
// Invoice(681,List(6811, 6812, 6813))
// Invoice(682,List(6821, 6822))
// Invoice(683,List(6831))
// Invoice(684,List(6841, 6842, 6843, 6844))
// Invoice(685,List(6851, 6852, 6853, 6854, 6855))
// Invoice(686,List(6861))
// Invoice(687,List(6871, 6872))
// Invoice(688,List(6881))
// Invoice(689,List(6891, 6892, 6893, 6894, 6895))
// Invoice(690,List(6901, 6902, 6903, 6904))
// Invoice(691,List(6911, 6912, 6913, 6914, 6915))
// Invoice(692,List(6921, 6922, 6923, 6924))
// Invoice(693,List(6931, 6932, 6933, 6934))
// Invoice(694,List(6941, 6942, 6943, 6944, 6945))
// Invoice(695,List(6951))
// Invoice(696,List(6961))
// Invoice(697,List(6971, 6972, 6973, 6974))
// Invoice(698,List(6981))
// Invoice(699,List(6991))
// Invoice(700,List(7001, 7002, 7003, 7004))
// Invoice(701,List(7011))
// Invoice(702,List(7021, 7022, 7023, 7024, 7025))
// Invoice(703,List(7031, 7032))
// Invoice(704,List(7041, 7042))
// Invoice(705,List(7051, 7052, 7053, 7054))
// Invoice(706,List(7061))
// Invoice(707,List(7071, 7072, 7073))
// Invoice(708,List(7081, 7082, 7083, 7084))
// Invoice(709,List(7091, 7092, 7093, 7094))
// Invoice(710,List(7101, 7102))
// Invoice(711,List(7111))
// Invoice(712,List(7121, 7122, 7123, 7124))
// Invoice(713,List(7131, 7132, 7133, 7134, 7135))
// Invoice(714,List(7141, 7142))
// Invoice(715,List(7151))
// Invoice(716,List(7161))
// Invoice(717,List(7171, 7172))
// Invoice(718,List(7181, 7182, 7183, 7184, 7185))
// Invoice(719,List(7191))
// Invoice(720,List(7201, 7202, 7203, 7204))
// Invoice(721,List(7211))
// Invoice(722,List(7221, 7222, 7223, 7224, 7225))
// Invoice(723,List(7231, 7232, 7233, 7234))
// Invoice(724,List(7241, 7242, 7243))
// Invoice(725,List(7251, 7252, 7253, 7254, 7255))
// Invoice(726,List(7261, 7262, 7263))
// Invoice(727,List(7271, 7272))
// Invoice(728,List(7281, 7282, 7283))
// Invoice(729,List(7291, 7292, 7293, 7294))
// Invoice(730,List(7301))
// Invoice(731,List(7311))
// Invoice(732,List(7321, 7322, 7323, 7324, 7325))
// Invoice(733,List(7331, 7332))
// Invoice(734,List(7341, 7342, 7343))
// Invoice(735,List(7351, 7352, 7353, 7354))
// Invoice(736,List(7361, 7362, 7363, 7364))
// Invoice(737,List(7371, 7372, 7373, 7374))
// Invoice(738,List(7381, 7382, 7383, 7384, 7385))
// Invoice(739,List(7391, 7392, 7393, 7394))
// Invoice(740,List(7401))
// Invoice(741,List(7411))
// Invoice(742,List(7421, 7422, 7423, 7424, 7425))
// Invoice(743,List(7431, 7432, 7433, 7434))
// Invoice(744,List(7441, 7442, 7443))
// Invoice(745,List(7451, 7452, 7453))
// Invoice(746,List(7461, 7462, 7463, 7464, 7465))
// Invoice(747,List(7471))
// Invoice(748,List(7481))
// Invoice(749,List(7491, 7492, 7493))
// Invoice(750,List(7501, 7502, 7503, 7504, 7505))
// Invoice(751,List(7511, 7512))
// Invoice(752,List(7521))
// Invoice(753,List(7531, 7532, 7533))
// Invoice(754,List(7541, 7542, 7543, 7544, 7545))
// Invoice(755,List(7551, 7552, 7553, 7554, 7555))
// Invoice(756,List(7561, 7562, 7563, 7564))
// Invoice(757,List(7571, 7572, 7573, 7574, 7575))
// Invoice(758,List(7581, 7582, 7583, 7584))
// Invoice(759,List(7591, 7592, 7593, 7594))
// Invoice(760,List(7601))
// Invoice(761,List(7611, 7612))
// Invoice(762,List(7621, 7622, 7623, 7624))
// Invoice(763,List(7631, 7632, 7633))
// Invoice(764,List(7641))
// Invoice(765,List(7651))
// Invoice(766,List(7661, 7662, 7663))
// Invoice(767,List(7671, 7672, 7673))
// Invoice(768,List(7681, 7682))
// Invoice(769,List(7691, 7692, 7693, 7694, 7695))
// Invoice(770,List(7701, 7702))
// Invoice(771,List(7711, 7712, 7713, 7714))
// Invoice(772,List(7721, 7722, 7723))
// Invoice(773,List(7731, 7732, 7733, 7734, 7735))
// Invoice(774,List(7741, 7742, 7743, 7744, 7745))
// Invoice(775,List(7751, 7752, 7753, 7754))
// Invoice(776,List(7761))
// Invoice(777,List(7771))
// Invoice(778,List(7781, 7782, 7783, 7784, 7785))
// Invoice(779,List(7791, 7792, 7793, 7794, 7795))
// Invoice(780,List(7801, 7802, 7803, 7804, 7805))
// Invoice(781,List(7811, 7812, 7813))
// Invoice(782,List(7821, 7822, 7823, 7824, 7825))
// Invoice(783,List(7831))
// Invoice(784,List(7841, 7842, 7843, 7844, 7845))
// Invoice(785,List(7851, 7852, 7853, 7854, 7855))
// Invoice(786,List(7861, 7862, 7863))
// Invoice(787,List(7871, 7872, 7873))
// Invoice(788,List(7881, 7882, 7883, 7884, 7885))
// Invoice(789,List(7891, 7892, 7893))
// Invoice(790,List(7901, 7902, 7903, 7904, 7905))
// Invoice(791,List(7911, 7912, 7913))
// Invoice(792,List(7921, 7922, 7923, 7924))
// Invoice(793,List(7931, 7932))
// Invoice(794,List(7941, 7942, 7943, 7944))
// Invoice(795,List(7951, 7952))
// Invoice(796,List(7961, 7962, 7963, 7964, 7965))
// Invoice(797,List(7971, 7972, 7973))
// Invoice(798,List(7981))
// Invoice(799,List(7991))
// Invoice(800,List(8001, 8002, 8003))
// Invoice(801,List(8011, 8012))
// Invoice(802,List(8021, 8022))
// Invoice(803,List(8031, 8032, 8033))
// Invoice(804,List(8041))
// Invoice(805,List(8051))
// Invoice(806,List(8061))
// Invoice(807,List(8071))
// Invoice(808,List(8081, 8082, 8083, 8084))
// Invoice(809,List(8091))
// Invoice(810,List(8101, 8102, 8103, 8104, 8105))
// Invoice(811,List(8111, 8112, 8113, 8114))
// Invoice(812,List(8121, 8122))
// Invoice(813,List(8131, 8132, 8133, 8134))
// Invoice(814,List(8141, 8142, 8143, 8144))
// Invoice(815,List(8151, 8152, 8153))
// Invoice(816,List(8161, 8162, 8163))
// Invoice(817,List(8171, 8172, 8173, 8174))
// Invoice(818,List(8181, 8182))
// Invoice(819,List(8191, 8192))
// Invoice(820,List(8201, 8202))
// Invoice(821,List(8211, 8212, 8213, 8214, 8215))
// Invoice(822,List(8221, 8222, 8223, 8224, 8225))
// Invoice(823,List(8231, 8232, 8233, 8234, 8235))
// Invoice(824,List(8241, 8242))
// Invoice(825,List(8251, 8252, 8253))
// Invoice(826,List(8261, 8262))
// Invoice(827,List(8271, 8272, 8273, 8274, 8275))
// Invoice(828,List(8281))
// Invoice(829,List(8291, 8292, 8293))
// Invoice(830,List(8301))
// Invoice(831,List(8311, 8312))
// Invoice(832,List(8321, 8322, 8323, 8324, 8325))
// Invoice(833,List(8331, 8332, 8333))
// Invoice(834,List(8341))
// Invoice(835,List(8351, 8352, 8353, 8354))
// Invoice(836,List(8361, 8362, 8363))
// Invoice(837,List(8371, 8372, 8373, 8374))
// Invoice(838,List(8381, 8382))
// Invoice(839,List(8391, 8392, 8393))
// Invoice(840,List(8401, 8402, 8403, 8404, 8405))
// Invoice(841,List(8411))
// Invoice(842,List(8421))
// Invoice(843,List(8431, 8432, 8433, 8434, 8435))
// Invoice(844,List(8441))
// Invoice(845,List(8451, 8452, 8453, 8454, 8455))
// Invoice(846,List(8461, 8462))
// Invoice(847,List(8471, 8472))
// Invoice(848,List(8481, 8482, 8483, 8484, 8485))
// Invoice(849,List(8491, 8492))
// Invoice(850,List(8501, 8502))
// Invoice(851,List(8511, 8512, 8513))
// Invoice(852,List(8521, 8522, 8523, 8524))
// Invoice(853,List(8531))
// Invoice(854,List(8541, 8542))
// Invoice(855,List(8551))
// Invoice(856,List(8561, 8562, 8563))
// Invoice(857,List(8571, 8572, 8573, 8574, 8575))
// Invoice(858,List(8581, 8582))
// Invoice(859,List(8591))
// Invoice(860,List(8601, 8602, 8603))
// Invoice(861,List(8611, 8612, 8613))
// Invoice(862,List(8621, 8622, 8623, 8624, 8625))
// Invoice(863,List(8631, 8632, 8633, 8634, 8635))
// Invoice(864,List(8641, 8642, 8643, 8644))
// Invoice(865,List(8651))
// Invoice(866,List(8661, 8662, 8663))
// Invoice(867,List(8671, 8672, 8673, 8674))
// Invoice(868,List(8681, 8682, 8683, 8684))
// Invoice(869,List(8691, 8692))
// Invoice(870,List(8701, 8702, 8703))
// Invoice(871,List(8711, 8712))
// Invoice(872,List(8721))
// Invoice(873,List(8731, 8732, 8733))
// Invoice(874,List(8741, 8742, 8743, 8744, 8745))
// Invoice(875,List(8751, 8752, 8753))
// Invoice(876,List(8761, 8762, 8763, 8764, 8765))
// Invoice(877,List(8771, 8772, 8773, 8774))
// Invoice(878,List(8781, 8782, 8783))
// Invoice(879,List(8791, 8792, 8793))
// Invoice(880,List(8801, 8802, 8803, 8804))
// Invoice(881,List(8811, 8812, 8813, 8814, 8815))
// Invoice(882,List(8821))
// Invoice(883,List(8831, 8832, 8833, 8834, 8835))
// Invoice(884,List(8841))
// Invoice(885,List(8851, 8852))
// Invoice(886,List(8861, 8862, 8863))
// Invoice(887,List(8871, 8872, 8873))
// Invoice(888,List(8881, 8882, 8883, 8884, 8885))
// Invoice(889,List(8891, 8892))
// Invoice(890,List(8901, 8902))
// Invoice(891,List(8911, 8912, 8913, 8914, 8915))
// Invoice(892,List(8921, 8922, 8923))
// Invoice(893,List(8931, 8932, 8933))
// Invoice(894,List(8941, 8942, 8943))
// Invoice(895,List(8951, 8952, 8953, 8954, 8955))
// Invoice(896,List(8961, 8962, 8963, 8964))
// Invoice(897,List(8971, 8972, 8973))
// Invoice(898,List(8981, 8982))
// Invoice(899,List(8991))
// Invoice(900,List(9001, 9002, 9003, 9004))
// Invoice(901,List(9011))
// Invoice(902,List(9021, 9022, 9023))
// Invoice(903,List(9031, 9032, 9033, 9034, 9035))
// Invoice(904,List(9041, 9042, 9043, 9044, 9045))
// Invoice(905,List(9051, 9052, 9053, 9054, 9055))
// Invoice(906,List(9061, 9062))
// Invoice(907,List(9071, 9072, 9073))
// Invoice(908,List(9081, 9082, 9083))
// Invoice(909,List(9091, 9092))
// Invoice(910,List(9101, 9102, 9103))
// Invoice(911,List(9111, 9112))
// Invoice(912,List(9121, 9122))
// Invoice(913,List(9131, 9132, 9133, 9134, 9135))
// Invoice(914,List(9141, 9142, 9143, 9144))
// Invoice(915,List(9151, 9152, 9153, 9154, 9155))
// Invoice(916,List(9161, 9162, 9163, 9164))
// Invoice(917,List(9171, 9172, 9173, 9174, 9175))
// Invoice(918,List(9181))
// Invoice(919,List(9191, 9192))
// Invoice(920,List(9201, 9202))
// Invoice(921,List(9211, 9212, 9213, 9214, 9215))
// Invoice(922,List(9221))
// Invoice(923,List(9231, 9232, 9233, 9234, 9235))
// Invoice(924,List(9241, 9242))
// Invoice(925,List(9251, 9252))
// Invoice(926,List(9261, 9262))
// Invoice(927,List(9271, 9272, 9273))
// Invoice(928,List(9281, 9282))
// Invoice(929,List(9291, 9292, 9293, 9294, 9295))
// Invoice(930,List(9301, 9302, 9303))
// Invoice(931,List(9311, 9312, 9313, 9314))
// Invoice(932,List(9321))
// Invoice(933,List(9331))
// Invoice(934,List(9341, 9342, 9343))
// Invoice(935,List(9351, 9352, 9353, 9354))
// Invoice(936,List(9361))
// Invoice(937,List(9371))
// Invoice(938,List(9381, 9382))
// Invoice(939,List(9391))
// Invoice(940,List(9401, 9402, 9403, 9404, 9405))
// Invoice(941,List(9411, 9412, 9413, 9414, 9415))
// Invoice(942,List(9421, 9422, 9423))
// Invoice(943,List(9431))
// Invoice(944,List(9441, 9442, 9443, 9444, 9445))
// Invoice(945,List(9451, 9452))
// Invoice(946,List(9461, 9462))
// Invoice(947,List(9471, 9472))
// Invoice(948,List(9481))
// Invoice(949,List(9491, 9492))
// Invoice(950,List(9501, 9502, 9503, 9504))
// Invoice(951,List(9511, 9512, 9513, 9514))
// Invoice(952,List(9521))
// Invoice(953,List(9531, 9532, 9533))
// Invoice(954,List(9541, 9542))
// Invoice(955,List(9551, 9552, 9553, 9554, 9555))
// Invoice(956,List(9561))
// Invoice(957,List(9571, 9572, 9573, 9574))
// Invoice(958,List(9581, 9582, 9583, 9584))
// Invoice(959,List(9591))
// Invoice(960,List(9601, 9602, 9603))
// Invoice(961,List(9611))
// Invoice(962,List(9621, 9622, 9623, 9624, 9625))
// Invoice(963,List(9631))
// Invoice(964,List(9641, 9642))
// Invoice(965,List(9651, 9652))
// Invoice(966,List(9661, 9662, 9663, 9664))
// Invoice(967,List(9671))
// Invoice(968,List(9681, 9682, 9683, 9684, 9685))
// Invoice(969,List(9691, 9692, 9693, 9694))
// Invoice(970,List(9701))
// Invoice(971,List(9711, 9712))
// Invoice(972,List(9721, 9722, 9723, 9724))
// Invoice(973,List(9731))
// Invoice(974,List(9741, 9742, 9743, 9744, 9745))
// Invoice(975,List(9751, 9752, 9753, 9754))
// Invoice(976,List(9761, 9762, 9763, 9764, 9765))
// Invoice(977,List(9771, 9772, 9773, 9774, 9775))
// Invoice(978,List(9781, 9782, 9783, 9784, 9785))
// Invoice(979,List(9791, 9792))
// Invoice(980,List(9801, 9802, 9803))
// Invoice(981,List(9811, 9812, 9813))
// Invoice(982,List(9821, 9822, 9823, 9824))
// Invoice(983,List(9831, 9832, 9833, 9834))
// Invoice(984,List(9841, 9842))
// Invoice(985,List(9851, 9852, 9853))
// Invoice(986,List(9861, 9862))
// Invoice(987,List(9871, 9872, 9873))
// Invoice(988,List(9881, 9882, 9883))
// Invoice(989,List(9891, 9892, 9893, 9894, 9895))
// Invoice(990,List(9901, 9902))
// Invoice(991,List(9911, 9912))
// Invoice(992,List(9921, 9922, 9923))
// Invoice(993,List(9931, 9932, 9933, 9934))
// Invoice(994,List(9941, 9942, 9943))
// Invoice(995,List(9951, 9952, 9953, 9954, 9955))
// Invoice(996,List(9961, 9962))
// Invoice(997,List(9971))
// Invoice(998,List(9981, 9982, 9983, 9984))
// Invoice(999,List(9991, 9992, 9993, 9994, 9995))
// Invoice(1000,List(10001))
// Invoice(1001,List(10011))
// Invoice(1002,List(10021))
// Invoice(1003,List(10031, 10032, 10033, 10034))
// Invoice(1004,List(10041, 10042, 10043))
// Invoice(1005,List(10051))
// Invoice(1006,List(10061, 10062, 10063, 10064))
// Invoice(1007,List(10071, 10072))
// Invoice(1008,List(10081, 10082))
// Invoice(1009,List(10091, 10092, 10093, 10094, 10095))
// Invoice(1010,List(10101, 10102, 10103, 10104, 10105))
// Invoice(1011,List(10111, 10112, 10113, 10114))
// Invoice(1012,List(10121, 10122, 10123, 10124))
// Invoice(1013,List(10131, 10132))
// Invoice(1014,List(10141, 10142))
// Invoice(1015,List(10151))
// Invoice(1016,List(10161, 10162))
// Invoice(1017,List(10171))
// Invoice(1018,List(10181, 10182, 10183, 10184, 10185))
// Invoice(1019,List(10191, 10192, 10193))
// Invoice(1020,List(10201, 10202, 10203))
// Invoice(1021,List(10211))
// Invoice(1022,List(10221))
// Invoice(1023,List(10231, 10232))
// Invoice(1024,List(10241))
// Invoice(1025,List(10251, 10252, 10253, 10254, 10255))
// Invoice(1026,List(10261, 10262, 10263))
// Invoice(1027,List(10271, 10272))
// Invoice(1028,List(10281))
// Invoice(1029,List(10291, 10292, 10293, 10294))
// Invoice(1030,List(10301, 10302))
// Invoice(1031,List(10311, 10312, 10313))
// Invoice(1032,List(10321, 10322))
// Invoice(1033,List(10331, 10332, 10333, 10334, 10335))
// Invoice(1034,List(10341, 10342, 10343, 10344))
// Invoice(1035,List(10351))
// Invoice(1036,List(10361, 10362, 10363, 10364))
// Invoice(1037,List(10371, 10372, 10373, 10374))
// Invoice(1038,List(10381, 10382, 10383, 10384))
// Invoice(1039,List(10391, 10392, 10393))
// Invoice(1040,List(10401))
// Invoice(1041,List(10411))
// Invoice(1042,List(10421))
// Invoice(1043,List(10431, 10432, 10433, 10434))
// Invoice(1044,List(10441, 10442, 10443, 10444))
// Invoice(1045,List(10451))
// Invoice(1046,List(10461, 10462, 10463, 10464))
// Invoice(1047,List(10471, 10472, 10473))
// Invoice(1048,List(10481, 10482, 10483))
// Invoice(1049,List(10491, 10492, 10493, 10494))
// Invoice(1050,List(10501, 10502, 10503, 10504, 10505))
// Invoice(1051,List(10511, 10512, 10513, 10514, 10515))
// Invoice(1052,List(10521, 10522, 10523, 10524, 10525))
// Invoice(1053,List(10531, 10532, 10533, 10534, 10535))
// Invoice(1054,List(10541, 10542, 10543, 10544, 10545))
// Invoice(1055,List(10551, 10552, 10553))
// Invoice(1056,List(10561, 10562, 10563))
// Invoice(1057,List(10571))
// Invoice(1058,List(10581, 10582, 10583))
// Invoice(1059,List(10591, 10592, 10593))
// Invoice(1060,List(10601, 10602, 10603))
// Invoice(1061,List(10611, 10612))
// Invoice(1062,List(10621, 10622, 10623, 10624, 10625))
// Invoice(1063,List(10631, 10632, 10633))
// Invoice(1064,List(10641))
// Invoice(1065,List(10651, 10652, 10653, 10654))
// Invoice(1066,List(10661, 10662, 10663))
// Invoice(1067,List(10671))
// Invoice(1068,List(10681, 10682, 10683, 10684))
// Invoice(1069,List(10691))
// Invoice(1070,List(10701))
// Invoice(1071,List(10711, 10712, 10713, 10714, 10715))
// Invoice(1072,List(10721, 10722, 10723, 10724))
// Invoice(1073,List(10731, 10732, 10733))
// Invoice(1074,List(10741))
// Invoice(1075,List(10751, 10752))
// Invoice(1076,List(10761, 10762, 10763, 10764))
// Invoice(1077,List(10771, 10772, 10773))
// Invoice(1078,List(10781, 10782, 10783))
// Invoice(1079,List(10791, 10792, 10793))
// Invoice(1080,List(10801))
// Invoice(1081,List(10811))
// Invoice(1082,List(10821, 10822, 10823, 10824))
// Invoice(1083,List(10831, 10832, 10833))
// Invoice(1084,List(10841, 10842, 10843, 10844))
// Invoice(1085,List(10851, 10852, 10853, 10854, 10855))
// Invoice(1086,List(10861, 10862))
// Invoice(1087,List(10871, 10872))
// Invoice(1088,List(10881, 10882, 10883))
// Invoice(1089,List(10891, 10892, 10893, 10894))
// Invoice(1090,List(10901))
// Invoice(1091,List(10911))
// Invoice(1092,List(10921))
// Invoice(1093,List(10931, 10932, 10933, 10934, 10935))
// Invoice(1094,List(10941, 10942, 10943))
// Invoice(1095,List(10951, 10952, 10953))
// Invoice(1096,List(10961, 10962, 10963, 10964, 10965))
// Invoice(1097,List(10971, 10972, 10973))
// Invoice(1098,List(10981, 10982))
// Invoice(1099,List(10991, 10992, 10993, 10994))
// Invoice(1100,List(11001, 11002, 11003, 11004, 11005))
// Invoice(1101,List(11011, 11012, 11013, 11014))
// ...
// Invoice(1622,List(16221, 16222, 16223, 16224, 16225))
// Invoice(1623,List(16231, 16232, 16233, 16234, 16235))
// Invoice(1624,List(16241, 16242, 16243))
// Invoice(1625,List(16251, 16252, 16253, 16254))
// Invoice(1626,List(16261, 16262, 16263, 16264, 16265))
// Invoice(1627,List(16271))
// Invoice(1628,List(16281, 16282))
// Invoice(1629,List(16291, 16292, 16293))
// Invoice(1630,List(16301, 16302, 16303, 16304))
// Invoice(1631,List(16311, 16312))
// Invoice(1632,List(16321, 16322))
// Invoice(1633,List(16331, 16332))
// Invoice(1634,List(16341, 16342, 16343, 16344, 16345))
// Invoice(1635,List(16351, 16352, 16353, 16354, 16355))
// Invoice(1636,List(16361, 16362, 16363, 16364))
// Invoice(1637,List(16371, 16372, 16373, 16374, 16375))
// Invoice(1638,List(16381, 16382, 16383, 16384, 16385))
// Invoice(1639,List(16391, 16392))
// Invoice(1640,List(16401))
// Invoice(1641,List(16411, 16412))
// Invoice(1642,List(16421, 16422, 16423, 16424))
// Invoice(1643,List(16431, 16432, 16433, 16434, 16435))
// Invoice(1644,List(16441, 16442, 16443))
// Invoice(1645,List(16451, 16452, 16453))
// Invoice(1646,List(16461, 16462, 16463, 16464))
// Invoice(1647,List(16471, 16472, 16473, 16474, 16475))
// Invoice(1648,List(16481, 16482, 16483))
// Invoice(1649,List(16491, 16492, 16493))
// Invoice(1650,List(16501))
// Invoice(1651,List(16511, 16512, 16513))
// Invoice(1652,List(16521))
// Invoice(1653,List(16531, 16532))
// Invoice(1654,List(16541, 16542))
// Invoice(1655,List(16551, 16552))
// Invoice(1656,List(16561))
// Invoice(1657,List(16571, 16572))
// Invoice(1658,List(16581, 16582, 16583, 16584, 16585))
// Invoice(1659,List(16591, 16592, 16593, 16594, 16595))
// Invoice(1660,List(16601, 16602))
// Invoice(1661,List(16611, 16612, 16613, 16614, 16615))
// Invoice(1662,List(16621, 16622, 16623))
// Invoice(1663,List(16631))
// Invoice(1664,List(16641, 16642, 16643, 16644))
// Invoice(1665,List(16651, 16652, 16653, 16654, 16655))
// Invoice(1666,List(16661, 16662, 16663))
// Invoice(1667,List(16671, 16672, 16673, 16674, 16675))
// Invoice(1668,List(16681, 16682, 16683))
// Invoice(1669,List(16691, 16692, 16693))
// Invoice(1670,List(16701))
// Invoice(1671,List(16711, 16712, 16713, 16714, 16715))
// Invoice(1672,List(16721, 16722, 16723, 16724, 16725))
// Invoice(1673,List(16731, 16732, 16733, 16734, 16735))
// Invoice(1674,List(16741))
// Invoice(1675,List(16751, 16752, 16753, 16754))
// Invoice(1676,List(16761, 16762, 16763, 16764, 16765))
// Invoice(1677,List(16771))
// Invoice(1678,List(16781))
// Invoice(1679,List(16791, 16792, 16793, 16794))
// Invoice(1680,List(16801, 16802, 16803, 16804, 16805))
// Invoice(1681,List(16811, 16812, 16813))
// Invoice(1682,List(16821, 16822))
// Invoice(1683,List(16831, 16832))
// Invoice(1684,List(16841, 16842, 16843, 16844))
// Invoice(1685,List(16851))
// Invoice(1686,List(16861, 16862, 16863, 16864, 16865))
// Invoice(1687,List(16871, 16872, 16873))
// Invoice(1688,List(16881, 16882))
// Invoice(1689,List(16891))
// Invoice(1690,List(16901, 16902, 16903))
// Invoice(1691,List(16911, 16912, 16913))
// Invoice(1692,List(16921, 16922, 16923, 16924, 16925))
// Invoice(1693,List(16931, 16932, 16933, 16934))
// Invoice(1694,List(16941, 16942, 16943, 16944, 16945))
// Invoice(1695,List(16951))
// Invoice(1696,List(16961, 16962, 16963, 16964))
// Invoice(1697,List(16971, 16972, 16973, 16974))
// Invoice(1698,List(16981, 16982))
// Invoice(1699,List(16991, 16992, 16993))
// Invoice(1700,List(17001, 17002, 17003, 17004, 17005))
// Invoice(1701,List(17011, 17012))
// Invoice(1702,List(17021, 17022))
// Invoice(1703,List(17031, 17032, 17033, 17034))
// Invoice(1704,List(17041, 17042, 17043, 17044, 17045))
// Invoice(1705,List(17051, 17052, 17053, 17054))
// Invoice(1706,List(17061, 17062, 17063))
// Invoice(1707,List(17071, 17072))
// Invoice(1708,List(17081, 17082))
// Invoice(1709,List(17091, 17092, 17093, 17094))
// Invoice(1710,List(17101, 17102, 17103, 17104, 17105))
// Invoice(1711,List(17111, 17112, 17113, 17114))
// Invoice(1712,List(17121, 17122, 17123, 17124, 17125))
// Invoice(1713,List(17131, 17132, 17133, 17134))
// Invoice(1714,List(17141, 17142, 17143, 17144, 17145))
// Invoice(1715,List(17151, 17152))
// Invoice(1716,List(17161, 17162, 17163, 17164))
// Invoice(1717,List(17171, 17172))
// Invoice(1718,List(17181, 17182, 17183, 17184, 17185))
// Invoice(1719,List(17191))
// Invoice(1720,List(17201))
// Invoice(1721,List(17211))
// Invoice(1722,List(17221, 17222))
// Invoice(1723,List(17231, 17232, 17233))
// Invoice(1724,List(17241))
// Invoice(1725,List(17251, 17252, 17253))
// Invoice(1726,List(17261, 17262, 17263, 17264, 17265))
// Invoice(1727,List(17271, 17272, 17273, 17274, 17275))
// Invoice(1728,List(17281, 17282, 17283, 17284, 17285))
// Invoice(1729,List(17291, 17292, 17293, 17294))
// Invoice(1730,List(17301, 17302, 17303, 17304, 17305))
// Invoice(1731,List(17311, 17312, 17313, 17314, 17315))
// Invoice(1732,List(17321, 17322, 17323))
// Invoice(1733,List(17331, 17332))
// Invoice(1734,List(17341, 17342, 17343, 17344, 17345))
// Invoice(1735,List(17351, 17352, 17353, 17354, 17355))
// Invoice(1736,List(17361))
// Invoice(1737,List(17371, 17372, 17373))
// Invoice(1738,List(17381, 17382, 17383))
// Invoice(1739,List(17391, 17392))
// Invoice(1740,List(17401, 17402, 17403, 17404))
// Invoice(1741,List(17411, 17412, 17413, 17414, 17415))
// Invoice(1742,List(17421, 17422))
// Invoice(1743,List(17431))
// Invoice(1744,List(17441, 17442, 17443, 17444, 17445))
// Invoice(1745,List(17451, 17452, 17453))
// Invoice(1746,List(17461, 17462))
// Invoice(1747,List(17471, 17472, 17473))
// Invoice(1748,List(17481, 17482))
// Invoice(1749,List(17491, 17492))
// Invoice(1750,List(17501, 17502, 17503, 17504))
// Invoice(1751,List(17511, 17512, 17513, 17514))
// Invoice(1752,List(17521, 17522, 17523, 17524))
// Invoice(1753,List(17531, 17532, 17533, 17534, 17535))
// Invoice(1754,List(17541))
// Invoice(1755,List(17551, 17552, 17553))
// Invoice(1756,List(17561))
// Invoice(1757,List(17571, 17572, 17573, 17574))
// Invoice(1758,List(17581, 17582))
// Invoice(1759,List(17591, 17592, 17593, 17594))
// Invoice(1760,List(17601, 17602, 17603))
// Invoice(1761,List(17611))
// Invoice(1762,List(17621))
// Invoice(1763,List(17631))
// Invoice(1764,List(17641, 17642, 17643, 17644))
// Invoice(1765,List(17651, 17652, 17653, 17654, 17655))
// Invoice(1766,List(17661, 17662, 17663, 17664, 17665))
// Invoice(1767,List(17671))
// Invoice(1768,List(17681, 17682, 17683, 17684))
// Invoice(1769,List(17691, 17692))
// Invoice(1770,List(17701, 17702, 17703, 17704, 17705))
// Invoice(1771,List(17711))
// Invoice(1772,List(17721))
// Invoice(1773,List(17731, 17732, 17733))
// Invoice(1774,List(17741))
// Invoice(1775,List(17751))
// Invoice(1776,List(17761, 17762))
// Invoice(1777,List(17771, 17772))
// Invoice(1778,List(17781, 17782, 17783, 17784, 17785))
// Invoice(1779,List(17791, 17792, 17793))
// Invoice(1780,List(17801, 17802))
// Invoice(1781,List(17811))
// Invoice(1782,List(17821, 17822))
// Invoice(1783,List(17831, 17832, 17833))
// Invoice(1784,List(17841, 17842))
// Invoice(1785,List(17851, 17852, 17853, 17854))
// Invoice(1786,List(17861, 17862))
// Invoice(1787,List(17871, 17872, 17873, 17874, 17875))
// Invoice(1788,List(17881))
// Invoice(1789,List(17891, 17892))
// Invoice(1790,List(17901, 17902))
// Invoice(1791,List(17911, 17912))
// Invoice(1792,List(17921, 17922, 17923, 17924, 17925))
// Invoice(1793,List(17931, 17932))
// Invoice(1794,List(17941))
// Invoice(1795,List(17951, 17952))
// Invoice(1796,List(17961, 17962, 17963))
// Invoice(1797,List(17971, 17972, 17973))
// Invoice(1798,List(17981))
// Invoice(1799,List(17991, 17992, 17993, 17994, 17995))
// Invoice(1800,List(18001, 18002, 18003, 18004))
// Invoice(1801,List(18011, 18012, 18013, 18014))
// Invoice(1802,List(18021, 18022, 18023, 18024))
// Invoice(1803,List(18031, 18032))
// Invoice(1804,List(18041, 18042, 18043, 18044, 18045))
// Invoice(1805,List(18051))
// Invoice(1806,List(18061, 18062, 18063, 18064))
// Invoice(1807,List(18071))
// Invoice(1808,List(18081, 18082, 18083))
// Invoice(1809,List(18091))
// Invoice(1810,List(18101, 18102, 18103, 18104, 18105))
// Invoice(1811,List(18111))
// Invoice(1812,List(18121, 18122, 18123, 18124))
// Invoice(1813,List(18131, 18132))
// Invoice(1814,List(18141))
// Invoice(1815,List(18151, 18152, 18153, 18154, 18155))
// Invoice(1816,List(18161, 18162, 18163, 18164))
// Invoice(1817,List(18171))
// Invoice(1818,List(18181, 18182, 18183))
// Invoice(1819,List(18191, 18192, 18193, 18194))
// Invoice(1820,List(18201, 18202, 18203, 18204))
// Invoice(1821,List(18211))
// Invoice(1822,List(18221, 18222, 18223, 18224, 18225))
// Invoice(1823,List(18231, 18232))
// Invoice(1824,List(18241, 18242, 18243))
// Invoice(1825,List(18251, 18252, 18253, 18254, 18255))
// Invoice(1826,List(18261, 18262, 18263, 18264))
// Invoice(1827,List(18271, 18272, 18273, 18274, 18275))
// Invoice(1828,List(18281, 18282))
// Invoice(1829,List(18291, 18292, 18293))
// Invoice(1830,List(18301, 18302, 18303, 18304))
// Invoice(1831,List(18311, 18312, 18313))
// Invoice(1832,List(18321, 18322, 18323, 18324, 18325))
// Invoice(1833,List(18331, 18332, 18333, 18334))
// Invoice(1834,List(18341, 18342, 18343))
// Invoice(1835,List(18351, 18352, 18353, 18354))
// Invoice(1836,List(18361, 18362, 18363, 18364, 18365))
// Invoice(1837,List(18371, 18372, 18373, 18374, 18375))
// Invoice(1838,List(18381, 18382, 18383))
// Invoice(1839,List(18391))
// Invoice(1840,List(18401))
// Invoice(1841,List(18411, 18412))
// Invoice(1842,List(18421, 18422, 18423, 18424))
// Invoice(1843,List(18431, 18432, 18433))
// Invoice(1844,List(18441, 18442, 18443, 18444))
// Invoice(1845,List(18451))
// Invoice(1846,List(18461, 18462, 18463, 18464, 18465))
// Invoice(1847,List(18471))
// Invoice(1848,List(18481, 18482))
// Invoice(1849,List(18491, 18492, 18493, 18494, 18495))
// Invoice(1850,List(18501, 18502))
// Invoice(1851,List(18511, 18512, 18513, 18514))
// Invoice(1852,List(18521, 18522, 18523, 18524))
// Invoice(1853,List(18531, 18532))
// Invoice(1854,List(18541, 18542))
// Invoice(1855,List(18551, 18552, 18553, 18554))
// Invoice(1856,List(18561))
// Invoice(1857,List(18571))
// Invoice(1858,List(18581, 18582, 18583, 18584, 18585))
// Invoice(1859,List(18591, 18592))
// Invoice(1860,List(18601, 18602))
// Invoice(1861,List(18611, 18612))
// Invoice(1862,List(18621, 18622, 18623))
// Invoice(1863,List(18631, 18632))
// Invoice(1864,List(18641, 18642, 18643, 18644, 18645))
// Invoice(1865,List(18651))
// Invoice(1866,List(18661))
// Invoice(1867,List(18671, 18672, 18673, 18674, 18675))
// Invoice(1868,List(18681, 18682, 18683, 18684, 18685))
// Invoice(1869,List(18691, 18692, 18693))
// Invoice(1870,List(18701, 18702, 18703))
// Invoice(1871,List(18711, 18712, 18713, 18714))
// Invoice(1872,List(18721, 18722))
// Invoice(1873,List(18731, 18732))
// Invoice(1874,List(18741, 18742, 18743))
// Invoice(1875,List(18751))
// Invoice(1876,List(18761, 18762, 18763))
// Invoice(1877,List(18771, 18772, 18773, 18774))
// Invoice(1878,List(18781))
// Invoice(1879,List(18791, 18792, 18793, 18794, 18795))
// Invoice(1880,List(18801))
// Invoice(1881,List(18811))
// Invoice(1882,List(18821, 18822))
// Invoice(1883,List(18831, 18832, 18833, 18834))
// Invoice(1884,List(18841))
// Invoice(1885,List(18851, 18852, 18853, 18854, 18855))
// Invoice(1886,List(18861, 18862, 18863, 18864))
// Invoice(1887,List(18871))
// Invoice(1888,List(18881, 18882))
// Invoice(1889,List(18891))
// Invoice(1890,List(18901, 18902, 18903))
// Invoice(1891,List(18911, 18912))
// Invoice(1892,List(18921, 18922))
// Invoice(1893,List(18931, 18932, 18933, 18934))
// Invoice(1894,List(18941, 18942, 18943, 18944, 18945))
// Invoice(1895,List(18951, 18952))
// Invoice(1896,List(18961, 18962))
// Invoice(1897,List(18971, 18972, 18973, 18974))
// Invoice(1898,List(18981, 18982, 18983, 18984, 18985))
// Invoice(1899,List(18991, 18992))
// Invoice(1900,List(19001, 19002, 19003, 19004, 19005))
// Invoice(1901,List(19011, 19012, 19013, 19014))
// Invoice(1902,List(19021))
// Invoice(1903,List(19031))
// Invoice(1904,List(19041))
// Invoice(1905,List(19051))
// Invoice(1906,List(19061, 19062, 19063, 19064, 19065))
// Invoice(1907,List(19071, 19072, 19073, 19074))
// Invoice(1908,List(19081))
// Invoice(1909,List(19091, 19092))
// Invoice(1910,List(19101, 19102, 19103, 19104))
// Invoice(1911,List(19111, 19112, 19113, 19114))
// Invoice(1912,List(19121, 19122, 19123, 19124))
// Invoice(1913,List(19131, 19132, 19133))
// Invoice(1914,List(19141))
// Invoice(1915,List(19151, 19152, 19153, 19154))
// Invoice(1916,List(19161, 19162, 19163))
// Invoice(1917,List(19171))
// Invoice(1918,List(19181, 19182, 19183))
// Invoice(1919,List(19191, 19192, 19193, 19194, 19195))
// Invoice(1920,List(19201, 19202, 19203, 19204, 19205))
// Invoice(1921,List(19211, 19212, 19213))
// Invoice(1922,List(19221))
// Invoice(1923,List(19231, 19232, 19233, 19234))
// Invoice(1924,List(19241, 19242, 19243))
// Invoice(1925,List(19251, 19252, 19253, 19254))
// Invoice(1926,List(19261, 19262, 19263, 19264, 19265))
// Invoice(1927,List(19271, 19272, 19273, 19274))
// Invoice(1928,List(19281, 19282, 19283))
// Invoice(1929,List(19291, 19292, 19293))
// Invoice(1930,List(19301))
// Invoice(1931,List(19311, 19312))
// Invoice(1932,List(19321, 19322, 19323, 19324, 19325))
// Invoice(1933,List(19331, 19332))
// Invoice(1934,List(19341, 19342, 19343, 19344))
// Invoice(1935,List(19351, 19352, 19353))
// Invoice(1936,List(19361))
// Invoice(1937,List(19371, 19372, 19373, 19374, 19375))
// Invoice(1938,List(19381, 19382, 19383))
// Invoice(1939,List(19391, 19392))
// Invoice(1940,List(19401))
// Invoice(1941,List(19411, 19412, 19413, 19414))
// Invoice(1942,List(19421, 19422, 19423, 19424))
// Invoice(1943,List(19431, 19432, 19433, 19434, 19435))
// Invoice(1944,List(19441, 19442, 19443, 19444, 19445))
// Invoice(1945,List(19451, 19452, 19453, 19454))
// Invoice(1946,List(19461, 19462, 19463, 19464))
// Invoice(1947,List(19471, 19472, 19473))
// Invoice(1948,List(19481, 19482, 19483))
// Invoice(1949,List(19491, 19492, 19493, 19494, 19495))
// Invoice(1950,List(19501))
// Invoice(1951,List(19511, 19512, 19513))
// Invoice(1952,List(19521, 19522))
// Invoice(1953,List(19531, 19532, 19533, 19534, 19535))
// Invoice(1954,List(19541))
// Invoice(1955,List(19551, 19552))
// Invoice(1956,List(19561, 19562, 19563, 19564))
// Invoice(1957,List(19571, 19572, 19573, 19574))
// Invoice(1958,List(19581, 19582))
// Invoice(1959,List(19591, 19592, 19593, 19594))
// Invoice(1960,List(19601, 19602, 19603, 19604, 19605))
// Invoice(1961,List(19611, 19612, 19613, 19614))
// Invoice(1962,List(19621, 19622, 19623, 19624, 19625))
// Invoice(1963,List(19631))
// Invoice(1964,List(19641, 19642, 19643, 19644, 19645))
// Invoice(1965,List(19651))
// Invoice(1966,List(19661, 19662))
// Invoice(1967,List(19671, 19672, 19673))
// Invoice(1968,List(19681, 19682, 19683))
// Invoice(1969,List(19691, 19692, 19693))
// Invoice(1970,List(19701, 19702, 19703))
// Invoice(1971,List(19711, 19712, 19713, 19714, 19715))
// Invoice(1972,List(19721, 19722, 19723, 19724))
// Invoice(1973,List(19731, 19732))
// Invoice(1974,List(19741))
// Invoice(1975,List(19751, 19752, 19753, 19754, 19755))
// Invoice(1976,List(19761, 19762, 19763, 19764, 19765))
// Invoice(1977,List(19771))
// Invoice(1978,List(19781, 19782))
// Invoice(1979,List(19791, 19792))
// Invoice(1980,List(19801))
// Invoice(1981,List(19811, 19812))
// Invoice(1982,List(19821))
// Invoice(1983,List(19831, 19832, 19833, 19834))
// Invoice(1984,List(19841))
// Invoice(1985,List(19851, 19852, 19853))
// Invoice(1986,List(19861, 19862, 19863, 19864))
// Invoice(1987,List(19871, 19872))
// Invoice(1988,List(19881, 19882, 19883, 19884))
// Invoice(1989,List(19891, 19892, 19893))
// Invoice(1990,List(19901, 19902))
// Invoice(1991,List(19911, 19912, 19913, 19914))
// Invoice(1992,List(19921, 19922, 19923, 19924, 19925))
// Invoice(1993,List(19931, 19932, 19933, 19934, 19935))
// Invoice(1994,List(19941, 19942, 19943, 19944))
// Invoice(1995,List(19951, 19952))
// Invoice(1996,List(19961, 19962))
// Invoice(1997,List(19971))
// Invoice(1998,List(19981, 19982, 19983, 19984, 19985))
// Invoice(1999,List(19991))
// Invoice(2000,List(20001, 20002, 20003, 20004, 20005))
// defined class Employee
// defined class MediaType
// defined class Genre
// defined class Track
// defined class InvoiceItem
// defined class Invoice
// employees = Array(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// mediaTypes = Array(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// genres = Array(Genre(...
// Array(Genre(...

// %% [markdown]
// # Atelier 3
//
// ## 1/ Filtrage - Titre en fonction d'un média spécifique

// %%
val mediaFilter = List(1, 3, 5)

val filteredTracks = tracksArray.filter(track => mediaFilter.contains(track.mediaTypeId))

println(s"Nombre de tracks filtrées: ${filteredTracks.length}")
// Out:
// Nombre de tracks filtrées: 129
// mediaFilter = List(1, 3, 5)
// filteredTracks = Array(Track(1,Cosmic Zombies from the Desert,3,25), Track(3,Raging Titans of Doom,5,25), Track(4,Urban Giants from Hell,5,9), Track(6,Atomic Bandits of Doom,3,6), Track(8,Toxic Killers in Flames,1,18), Track(9,Royal Kings from Beyond,3,2), Track(10,Neon Thunder from the Desert,5,18), Track(13,Electric Outlaws of the Deep,3,15), Track(14,Infinite Killers of Eternity,3,3), Track(15,Infinite Empire from the Sky,5,4), Track(18,Digital Wolves in Disguise,3,6), Track(19,Crystal Echo in Exile,3,5), Track(20,Phantom Thunder of Tomorrow,3,17), Track(21,Midnight Demons from Mars,1,5), Track(23,Stellar Rebels of the North,3,17), Track(27,Digital Warriors of Death,1,21), Track(28,Raging Wolves in Shadow,1,17), Track(29,Crimson Ki...
// Array(Track(1,Cosmic Zombies from the Desert,3,25), Track(3,Raging Titans of Doom,5,25), Track(4,Urban Giants from Hell,5,9), Track(6,Atomic Bandits of Doom,3,6), Track(8,Toxic Killers in Flames,1,18), Track(9,Royal Kings from Beyond,3,2), Track(10,Neon Thunder from the Desert,5,18), Track(13,Electric Outlaws of the Deep,3,15), Track(14,Infinite Killers of Eternity,3,3), Track(15,Infinite Empire from the Sky,5,4), Track(18,Digital Wolves in Disguise,3,6), Track(19,Crystal Echo in Exile,3,5), Track(20,Phantom Thunder of Tomorrow,3,17), Track(21,Midnight Demons from Mars,1,5), Track(23,Stellar Rebels of the North,3,17), Track(27,Digital Warriors of Death,1,21), Track(28,Raging Wolves in Shadow,1,17), Track(29,Crimson Ki...

// %% [markdown]
// ## 1/ Filtrage - Commandes ayant un maximum de titres du genre 1

// %%
// Initiation InvoiceItems
val invoiceItems = invoicesArray.flatMap { invoice =>
  val itemCount = Random.nextInt(5) + 1
  val selectedTracks = Random.shuffle(tracksArray.toList).take(itemCount)
  
  selectedTracks.zipWithIndex.map { case (track, index) =>
    val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
    val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
    
    InvoiceItem(
      invoiceLineId = invoice.invoiceId * 10 + index + 1,
      invoiceId = invoice.invoiceId,
      trackId = track.trackId,
      unitPrice = unitPrice,
      quantity = quantity
    )
  }
}

def countGenre1TracksInInvoice(invoiceId: Int): Int = {
  invoiceItems
    .filter(_.invoiceId == invoiceId)
    .map(_.trackId)
    .map(trackId => tracksArray.find(_.trackId == trackId))
    .flatten
    .count(_.genreId == 1)
}

val maxGenre1Count = invoicesArray.map(invoice => countGenre1TracksInInvoice(invoice.invoiceId)).max

val invoicesWithMaxGenre1 = invoicesArray.filter(invoice => 
  countGenre1TracksInInvoice(invoice.invoiceId) == maxGenre1Count
)

println(s"Maximum de titres du genre 1 (Rock) dans une commande: $maxGenre1Count")
println(s"Nombre de commandes ayant ce maximum: ${invoicesWithMaxGenre1.length}")
// Out:
// Maximum de titres du genre 1 (Rock) dans une commande: 2
// Nombre de commandes ayant ce maximum: 14
// invoiceItems = Array(InvoiceItem(11,1,69,1.16,1), InvoiceItem(12,1,71,1.94,1), InvoiceItem(21,2,190,1.08,1), InvoiceItem(31,3,199,1.20,1), InvoiceItem(32,3,82,1.98,1), InvoiceItem(33,3,86,1.09,1), InvoiceItem(34,3,47,1.97,1), InvoiceItem(41,4,147,1.47,1), InvoiceItem(42,4,143,1.94,1), InvoiceItem(43,4,146,1.62,1), InvoiceItem(44,4,77,1.71,1), InvoiceItem(51,5,159,1.52,1), InvoiceItem(52,5,5,1.71,1), InvoiceItem(53,5,8,1.20,1), InvoiceItem(54,5,162,1.69,1), InvoiceItem(61,6,74,1.34,1), InvoiceItem(62,6,72,1.03,1), InvoiceItem(63,6,122,1.93,1), InvoiceItem(64,6,182,1.05,1), InvoiceItem(65,6,191,1.65,1), InvoiceItem(71,7,33,1.57,1), InvoiceItem(72,7,86,1.08,1), InvoiceItem(81,8,198,1.77,1), InvoiceItem(91,9,83,1.60,1), InvoiceItem(101,10,192,1.59,1), InvoiceItem(102,10,...
// Array(InvoiceItem(11,1,69,1.16,1), InvoiceItem(12,1,71,1.94,1), InvoiceItem(21,2,190,1.08,1), InvoiceItem(31,3,199,1.20,1), InvoiceItem(32,3,82,1.98,1), InvoiceItem(33,3,86,1.09,1), InvoiceItem(34,3,47,1.97,1), InvoiceItem(41,4,147,1.47,1), InvoiceItem(42,4,143,1.94,1), InvoiceItem(43,4,146,1.62,1), InvoiceItem(44,4,77,1.71,1), InvoiceItem(51,5,159,1.52,1), InvoiceItem(52,5,5,1.71,1), InvoiceItem(53,5,8,1.20,1), InvoiceItem(54,5,162,1.69,1), InvoiceItem(61,6,74,1.34,1), InvoiceItem(62,6,72,1.03,1), InvoiceItem(63,6,122,1.93,1), InvoiceItem(64,6,182,1.05,1), InvoiceItem(65,6,191,1.65,1), InvoiceItem(71,7,33,1.57,1), InvoiceItem(72,7,86,1.08,1), InvoiceItem(81,8,198,1.77,1), InvoiceItem(91,9,83,1.60,1), InvoiceItem(101,10,192,1.59,1), InvoiceItem(102,10,...

// %% [markdown]
// ## 2/ Agrégations - Top 5 titres en nombre de ventes

// %%
val trackSales = invoiceItems
  .groupBy(_.trackId)
  .map { case (trackId, items) =>
    trackId -> items.map(_.quantity).sum
  }

val top5Tracks = trackSales
  .toSeq
  .sortBy(-_._2)
  .take(5)
  .map { case (trackId, totalSales) =>
    val track = tracksArray.find(_.trackId == trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (track, totalSales, genreName)
  }

println("Top 5 des titres en nombre de ventes:")
top5Tracks.zipWithIndex.foreach { case ((track, sales, genre), index) =>
  println(s"${index + 1}. ${track.name} - $sales ventes (Genre: $genre)")
}
// Out:
// Top 5 des titres en nombre de ventes:
// 1. Arctic Rebels in Flames - 57 ventes (Genre: Alternative & Punk)
// 2. Infinite Shadows of Destruction - 56 ventes (Genre: Sci Fi & Fantasy)
// 3. Stellar Machines from Beyond - 55 ventes (Genre: Alternative & Punk)
// 4. Screaming Rebels of the Underground - 52 ventes (Genre: Latin)
// 5. Digital Warriors of Death - 52 ventes (Genre: Drama)
// trackSales = Map(69 -> 36, 138 -> 33, 101 -> 47, 88 -> 46, 170 -> 24, 115 -> 29, 5 -> 42, 120 -> 42, 10 -> 46, 56 -> 34, 142 -> 47, 153 -> 34, 174 -> 40, 185 -> 34, 42 -> 30, 24 -> 38, 37 -> 35, 25 -> 40, 52 -> 52, 14 -> 34, 184 -> 33, 110 -> 32, 125 -> 40, 196 -> 40, 157 -> 30, 189 -> 33, 20 -> 37, 46 -> 46, 93 -> 36, 152 -> 40, 57 -> 31, 78 -> 32, 29 -> 40, 164 -> 32, 179 -> 28, 106 -> 46, 121 -> 39, 84 -> 39, 147 -> 34, 61 -> 36, 132 -> 35, 89 -> 43, 133 -> 29, 116 -> 44, 1 -> 27, 74 -> 34, 6 -> 31, 60 -> 35, 117 -> 35, 85 -> 32, 102 -> 36, 28 -> 36, 38 -> 33, 160 -> 44, 70 -> 40, 192 -> 27, 21 -> 44, 137 -> 36, 165 -> 29, 33 -> 29, 92 -> 49, 197 -> 39, 65 -> 42, 97 -> 22, 156 -> 33, 9 -> 39, 188 -> 28, 53 -> 28, 169 -> 38, 141 -> 36, 109 -> 3...
// Map(69 -> 36, 138 -> 33, 101 -> 47, 88 -> 46, 170 -> 24, 115 -> 29, 5 -> 42, 120 -> 42, 10 -> 46, 56 -> 34, 142 -> 47, 153 -> 34, 174 -> 40, 185 -> 34, 42 -> 30, 24 -> 38, 37 -> 35, 25 -> 40, 52 -> 52, 14 -> 34, 184 -> 33, 110 -> 32, 125 -> 40, 196 -> 40, 157 -> 30, 189 -> 33, 20 -> 37, 46 -> 46, 93 -> 36, 152 -> 40, 57 -> 31, 78 -> 32, 29 -> 40, 164 -> 32, 179 -> 28, 106 -> 46, 121 -> 39, 84 -> 39, 147 -> 34, 61 -> 36, 132 -> 35, 89 -> 43, 133 -> 29, 116 -> 44, 1 -> 27, 74 -> 34, 6 -> 31, 60 -> 35, 117 -> 35, 85 -> 32, 102 -> 36, 28 -> 36, 38 -> 33, 160 -> 44, 70 -> 40, 192 -> 27, 21 -> 44, 137 -> 36, 165 -> 29, 33 -> 29, 92 -> 49, 197 -> 39, 65 -> 42, 97 -> 22, 156 -> 33, 9 -> 39, 188 -> 28, 53 -> 28, 169 -> 38, 141 -> 36, 109 -> 3...

// %% [markdown]
// ## 2/ Agrégations - Total commande par genre

// %%
val totalByGenre = invoiceItems
  .map { item =>
    val track = tracksArray.find(_.trackId == item.trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (genreName, item.unitPrice * item.quantity, item.quantity)
  }
  .groupBy(_._1)
  .map { case (genre, items) =>
    val total = items.map(_._2).sum
    val commandes = items.map(_._3).sum
    (genre, total, commandes)
  }
  .toSeq
  .sortBy(-_._2)

println("Total des commandes par genre:")
totalByGenre.foreach { case (genre, total, commandes) =>
  println(f"$genre: $commandes commandes pour ${total}%.2f€")
}
// Out:
// Total des commandes par genre:
// World: 470 commandes pour 701.01€
// Pop: 405 commandes pour 615.67€
// Science Fiction: 404 commandes pour 604.05€
// Blues: 383 commandes pour 574.68€
// Opera: 372 commandes pour 556.31€
// Alternative & Punk: 367 commandes pour 546.21€
// Easy Listening: 352 commandes pour 535.37€
// Rock: 338 commandes pour 513.84€
// Hip Hop/Rap: 344 commandes pour 511.56€
// Jazz: 341 commandes pour 502.65€
// Alternative: 301 commandes pour 454.89€
// Sci Fi & Fantasy: 301 commandes pour 444.41€
// Rock And Roll: 290 commandes pour 442.08€
// Soundtrack: 301 commandes pour 440.87€
// Drama: 262 commandes pour 387.59€
// Latin: 251 commandes pour 385.02€
// Heavy Metal: 251 commandes pour 378.57€
// Electronica/Dance: 256 commandes pour 375.70€
// Comedy: 229 commandes pour 349.51€
// Reggae: 228 commandes pour 338.70€
// Classical: 220 commandes pour 333.02€
// R&B/Soul: 216 commandes pour 324.78€
// Metal: 187 commandes pour 284.49€
// Bossa Nova: 149 commandes pour 229.44€
// TV Shows: 136 commandes pour 196.93€
// totalByGenre = List((World,701.01,470), (Pop,615.67,405), (Science Fiction,604.05,404), (Blues,574.68,383), (Opera,556.31,372), (Alternative & Punk,546.21,367), (Easy Listening,535.37,352), (Rock,513.84,338), (Hip Hop/Rap,511.56,344), (Jazz,502.65,341), (Alternative,454.89,301), (Sci Fi & Fantasy,444.41,301), (Rock And Roll,442.08,290), (Soundtrack,440.87,301), (Drama,387.59,262), (Latin,385.02,251), (Heavy Metal,378.57,251), (Electronica/Dance,375.70,256), (Comedy,349.51,229), (Reggae,338.70,228), (Classical,333.02,220), (R&B/Soul,324.78,216), (Metal,284.49,187), (Bossa Nova,229.44,149), (TV Shows,196.93,136))
// List((World,701.01,470), (Pop,615.67,405), (Science Fiction,604.05,404), (Blues,574.68,383), (Opera,556.31,372), (Alternative & Punk,546.21,367), (Easy Listening,535.37,352), (Rock,513.84,338), (Hip Hop/Rap,511.56,344), (Jazz,502.65,341), (Alternative,454.89,301), (Sci Fi & Fantasy,444.41,301), (Rock And Roll,442.08,290), (Soundtrack,440.87,301), (Drama,387.59,262), (Latin,385.02,251), (Heavy Metal,378.57,251), (Electronica/Dance,375.70,256), (Comedy,349.51,229), (Reggae,338.70,228), (Classical,333.02,220), (R&B/Soul,324.78,216), (Metal,284.49,187), (Bossa Nova,229.44,149), (TV Shows,196.93,136))

// %% [markdown]
// ## 3/ Traitement récursif - Fonction récursive pour trouver le plus haut responsable

// %%
def findTopManager(employeeId: Int): Employee = {
  val employee = employees.find(_.employeeId == employeeId)
    .getOrElse(throw new IllegalArgumentException(s"Employee $employeeId not found"))
  
  if (employee.reportsTo == 0) {
    employee
  } else {
    findTopManager(employee.reportsTo)
  }
}

println("Tests de la fonction récursive findTopManager:")
println()

employees.foreach { employee =>
  val topManager = findTopManager(employee.employeeId)
  val hierarchy = buildHierarchyPath(employee.employeeId)
  
  println(s"${employee.firstName} ${employee.lastName} (${employee.title})")
  println(s"  → Plus haut responsable: ${topManager.firstName} ${topManager.lastName} (${topManager.title})")
  println(s"  → Chemin hiérarchique: $hierarchy")
  println()
}

def buildHierarchyPath(employeeId: Int): String = {
  def buildPath(currentId: Int, path: List[String]): List[String] = {
    val employee = employees.find(_.employeeId == currentId).get
    val employeeName = s"${employee.firstName} ${employee.lastName}"

    if (employee.reportsTo == 0) {
      path :+ employeeName
    } else {
      buildPath(employee.reportsTo, path :+ employeeName)
    }
  }

  buildPath(employeeId, List()).mkString(" → ")
}
// Out:
// findTopManager: (employeeId: Int)Employee
// buildHierarchyPath: (employeeId: Int)String
// Tests de la fonction récursive findTopManager:
//
// Andrew Adams (General Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Andrew Adams
//
// Nancy Edwards (Sales Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Nancy Edwards → Andrew Adams
//
// Jane Peacock (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Jane Peacock → Nancy Edwards → Andrew Adams
//
// Margaret Park (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Margaret Park → Nancy Edwards → Andrew Adams
//
// Steve Johnson (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Steve Johnson → Nancy Edwards → Andrew Adams
//
// Michael Mitchell (IT Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Michael Mitchell → Andrew Adams
//
// Robert King (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Robert King → Michael Mitchell → Andrew Adams
//
// Laura Callahan (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Laura Callahan → Michael Mitchell → Andrew Adams

// %% [markdown]
// # ATELIER 4 - Transposition sur Spark
//
// ## At. 4 - Etape 1/ Manipulation des données générées

// %%
// Creation RDD
// tracks / invoices / invoiceItems / mediaFilter => générés pendant l'atelier 3
val tracksRDD = sc.parallelize(tracks)
val invoiceItemsRDD = sc.parallelize(invoiceItems)
val invoicesRDD = sc.parallelize(invoices)

val filteredTracksRDD = tracksRDD.filter(track => mediaFilter.contains(track.mediaTypeId))

val trackGenreRDD = tracksRDD.map(track => (track.trackId, track.genreId))
val invoiceTrackRDD = invoiceItemsRDD.map(item => (item.trackId, item.invoiceId))
val invoiceGenreCountRDD = invoiceTrackRDD
  .join(trackGenreRDD) 
  .filter(_._2._2 == 1)  // 1 = Genre Rock
  .map { case (trackId, (invoiceId, genreId)) => (invoiceId, 1) }
  .reduceByKey(_ + _) 

val maxGenre1CountRDD = invoiceGenreCountRDD.map(_._2).max()
val invoicesWithMaxGenre1RDD = invoiceGenreCountRDD.filter(_._2 == maxGenre1CountRDD)

// Affichage résultat RDD
println(s"Maximum de titres Rock dans une commande: $maxGenre1CountRDD")
println(s"Nombre de commandes ayant ce maximum: ${invoicesWithMaxGenre1RDD.count()}")
// Out:
// Maximum de titres Rock dans une commande: 2
// Nombre de commandes ayant ce maximum: 14
// tracksRDD = ParallelCollectionRDD[7] at parallelize at <console>:33
// invoiceItemsRDD = ParallelCollectionRDD[8] at parallelize at <console>:34
// invoicesRDD = ParallelCollectionRDD[9] at parallelize at <console>:35
// filteredTracksRDD = MapPartitionsRDD[10] at filter at <console>:37
// trackGenreRDD = MapPartitionsRDD[11] at map at <console>:39
// invoiceTrackRDD = MapPartitionsRDD[12] at map at <console>:40
// invoiceGenreCountRDD = ShuffledRDD[18] at reduceByKey at <console>:45
// maxGenre1CountRDD = 2
// invoicesWithMaxGenre1RDD: org.apache.spark.rd...
// 2

// %% [markdown]
// ## Etape 2/ Analyse des transformation

// %% [markdown]
// ## Etape 3/ Chargement des CSV
