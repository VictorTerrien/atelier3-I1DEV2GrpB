// %% [markdown]
// # ATELIER 2

// %%
import scala.util.Random

case class Employee(
  employeeId: Int,
  lastName: String, 
  firstName: String,
  title: String,
  reportsTo: Int
)

case class MediaType(
  mediaTypeId: Int,
  name: String
)

case class Genre(
  genreId: Int,
  name: String
)

case class Track(
  trackId: Int,
  name: String,
  mediaTypeId: Int,
  genreId: Int
)

case class InvoiceItem(
  invoiceLineId: Int,
  invoiceId: Int,
  trackId: Int,
  unitPrice: BigDecimal,
  quantity: Int,
)

case class Invoice(
  invoiceId: Int,
  items: List[Int]
)


val employees = Array(
  Employee(1, "Adams", "Andrew", "General Manager", 0),
  Employee(2, "Edwards", "Nancy", "Sales Manager", 1), 
  Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  Employee(7, "King", "Robert", "IT Staff", 6),
  Employee(8, "Callahan", "Laura", "IT Staff", 6)
)

val mediaTypes = Array(
  MediaType(1, "MPEG audio file"),
  MediaType(2, "Protected AAC audio file"), 
  MediaType(3, "Protected MPEG-4 video file"),
  MediaType(4, "Purchased AAC audio file"),
  MediaType(5, "AAC audio file")
)

val genres = Array(
  Genre(1, "Rock"), 
  Genre(2, "Jazz"),
  Genre(3, "Metal"), 
  Genre(4, "Alternative & Punk"),
  Genre(5, "Rock And Roll"),
  Genre(6, "Blues"),
  Genre(7, "Latin"),
  Genre(8, "Reggae"),
  Genre(9, "Pop"),
  Genre(10, "Soundtrack"),
  Genre(11, "Bossa Nova"),
  Genre(12, "Easy Listening"),
  Genre(13, "Heavy Metal"), 
  Genre(14, "R&B/Soul"),
  Genre(15, "Electronica/Dance"),
  Genre(16, "World"), 
  Genre(17, "Hip Hop/Rap"),
  Genre(18, "Science Fiction"),
  Genre(19, "TV Shows"), 
  Genre(20, "Sci Fi & Fantasy"),
  Genre(21, "Drama"), 
  Genre(22, "Comedy"), 
  Genre(23, "Alternative"),
  Genre(24, "Classical"), 
  Genre(25, "Opera")
)

val adjectives = Array(
  "Cosmic", "Electric", "Velvet", "Mystic", "Atomic", "Phantom", "Silent", 
  "Savage", "Eternal", "Digital", "Lost", "Sacred", "Wild", "Urban", "Golden", 
  "Crystal", "Liquid", "Toxic", "Neon", "Crimson", "Stellar", "Raging", 
  "Arctic", "Sonic", "Primal", "Midnight", "Screaming", "Infinite", "Royal", "Lunar"
)

val nouns = Array(
  "Echo", "Giants", "Wolves", "Horizon", "Empire", "Void", "Thunder", "Dragons", 
  "Saints", "Kings", "Ghosts", "Ravens", "Pirates", "Heroes", "Rebels", "Demons", 
  "Machines", "Angels", "Knights", "Lions", "Shadows", "Zombies", "Wizards", 
  "Killers", "Titans", "Outlaws", "Rebels", "Prophets", "Bandits", "Warriors"
)

val complements = Array(
  "of Doom", "in Chains", "from Mars", "of the North", "of Death", "in Disguise", 
  "of the Night", "from Hell", "of Tomorrow", "in Flames", "of the Deep", 
  "from Beyond", "of Destruction", "in Shadow", "from the Sky", "of the Abyss", 
  "in Exile", "from the East", "of Eternity", "from the Desert", "of the Underground"
)

object Track {
  def generateTrack(trackId: Int): Track = {
    val randomGenre = genres(Random.nextInt(genres.length))
    val randomMediaType = mediaTypes(Random.nextInt(mediaTypes.length))
    
    val adjective = adjectives(Random.nextInt(adjectives.length))
    val noun = nouns(Random.nextInt(nouns.length))
    val complement = complements(Random.nextInt(complements.length))
    
    val trackName = s"$adjective $noun $complement"
    
    Track(trackId, trackName, randomMediaType.mediaTypeId, randomGenre.genreId)
  }
}


object Invoice {
  def generateInvoice(invoiceId: Int, availableTracks: Array[Track]): Invoice = {
    val itemCount = Random.nextInt(5) + 1
    val selectedTracks = Random.shuffle(availableTracks.toList).take(itemCount)
    
    val items = selectedTracks.zipWithIndex.map { case (track, index) =>
      val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
      val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
      
      InvoiceItem(
        invoiceLineId = invoiceId * 10 + index + 1,
        invoiceId = invoiceId,
        trackId = track.trackId,
        unitPrice = unitPrice,
        quantity = quantity,
      )
    }
    
    Invoice(invoiceId, items.map(_.invoiceLineId))
  }
}

val tracks = for(index <- 1 to 200) yield Track.generateTrack(index)
val tracksArray = tracks.toArray
println("Liste des tracks :")
tracksArray.foreach(println)


val invoices = for(index <- 1 to 2000) yield Invoice.generateInvoice(index, tracksArray)
val invoicesArray = invoices.toArray
println("\nListe des invoices :")
invoicesArray.foreach(println)
// Out:
// Track(1,Raging Knights from the East,5,7)
// Track(2,Toxic Machines in Chains,5,7)
// Track(3,Midnight Shadows of Death,3,15)
// Track(4,Eternal Prophets from Mars,3,18)
// Track(5,Silent Kings of Destruction,4,3)
// Track(6,Lost Angels in Chains,2,7)
// Track(7,Atomic Ghosts in Flames,1,4)
// Track(8,Liquid Outlaws in Flames,4,2)
// Track(9,Wild Wizards of the Abyss,1,18)
// Track(10,Velvet Warriors of the Abyss,2,8)
// Track(11,Sonic Giants in Flames,3,9)
// Track(12,Wild Ravens from Beyond,4,3)
// Track(13,Arctic Ghosts in Disguise,4,13)
// Liste des tracks :
// Track(14,Electric Demons of Destruction,4,5)
// Track(15,Electric Knights in Flames,4,22)
// Track(16,Primal Giants from the East,1,11)
// Track(17,Screaming Outlaws in Disguise,5,23)
// Track(18,Golden Outlaws in Shadow,4,14)
// Track(19,Sacred Ravens of Doom,4,2)
// Track(20,Golden Horizon from Mars,3,8)
// Track(21,Wild Heroes of the Deep,4,4)
// Track(22,Raging Giants of the Night,4,7)
// Track(23,Eternal Shadows of the North,1,16)
// Track(24,Eternal Empire of the Deep,4,7)
// Track(25,Phantom Horizon of the North,1,21)
// Track(26,Golden Wolves of Death,3,3)
// Track(27,Primal Kings of the Deep,4,20)
// Track(28,Primal Rebels of Death,3,24)
// Track(29,Urban Knights of Destruction,3,8)
// Track(30,Sonic Giants from the Desert,1,23)
// Track(31,Silent Ravens in Disguise,1,13)
// Track(32,Digital Kings in Exile,4,19)
// Track(33,Urban Zombies from the East,4,7)
// Track(34,Eternal Echo of Death,1,6)
// Track(35,Cosmic Machines from Beyond,2,12)
// Track(36,Neon Horizon of the North,5,17)
// Track(37,Stellar Wolves from the East,5,16)
// Track(38,Arctic Kings from the East,1,1)
// Track(39,Crimson Zombies in Flames,2,7)
// Track(40,Lunar Angels of Eternity,1,25)
// Track(41,Atomic Rebels in Flames,5,5)
// Track(42,Lost Empire of the North,3,1)
// Track(43,Stellar Empire of the Abyss,4,2)
// Track(44,Eternal Warriors of the Underground,3,2)
// Track(45,Toxic Ravens in Flames,5,17)
// Track(46,Stellar Bandits in Exile,4,9)
// Track(47,Screaming Ravens from Mars,2,3)
// Track(48,Stellar Wolves of Tomorrow,3,18)
// Track(49,Arctic Thunder from Hell,2,25)
// Track(50,Cosmic Dragons of Tomorrow,4,4)
// Track(51,Sonic Demons of the Deep,2,9)
// Track(52,Lunar Saints of the Night,5,16)
// Track(53,Liquid Machines of the North,4,1)
// Track(54,Liquid Thunder from the East,1,18)
// Track(55,Liquid Killers of Doom,4,16)
// Track(56,Digital Shadows of Destruction,1,17)
// Track(57,Sacred Rebels from Hell,3,6)
// Track(58,Golden Killers in Chains,4,8)
// Track(59,Velvet Prophets of the Abyss,3,4)
// Track(60,Sacred Echo of Doom,4,22)
// Track(61,Wild Knights from Mars,4,13)
// Track(62,Raging Bandits of the Underground,4,4)
// Track(63,Mystic Pirates from Mars,4,11)
// Track(64,Neon Outlaws from the Sky,2,13)
// Track(65,Digital Outlaws of Tomorrow,3,24)
// Track(66,Cosmic Dragons from Hell,1,14)
// Track(67,Stellar Machines from Beyond,2,20)
// Track(68,Cosmic Ravens of the Deep,2,25)
// Track(69,Sacred Angels in Chains,2,6)
// Track(70,Phantom Empire from Mars,5,24)
// Track(71,Toxic Killers of Tomorrow,4,22)
// Track(72,Primal Wizards of Tomorrow,5,7)
// Track(73,Urban Giants in Disguise,1,22)
// Track(74,Eternal Kings from the Desert,4,20)
// Track(75,Silent Zombies from Hell,4,11)
// Track(76,Electric Rebels from Beyond,4,22)
// Track(77,Atomic Zombies of Destruction,2,21)
// Track(78,Infinite Rebels in Disguise,4,4)
// Track(79,Eternal Bandits in Exile,4,18)
// Track(80,Wild Thunder from Beyond,2,1)
// Track(81,Crystal Wolves of Destruction,1,12)
// Track(82,Liquid Kings from Hell,5,15)
// Track(83,Crystal Ghosts of Death,2,2)
// Track(84,Electric Echo of Tomorrow,3,25)
// Track(85,Royal Angels from the Sky,2,4)
// Track(86,Midnight Machines from the Sky,1,11)
// Track(87,Golden Wizards in Chains,1,6)
// Track(88,Mystic Wizards in Chains,3,21)
// Track(89,Crystal Void from Mars,3,14)
// Track(90,Phantom Dragons from the East,1,7)
// Track(91,Phantom Empire from Beyond,3,13)
// Track(92,Neon Kings of the North,4,20)
// Track(93,Primal Dragons in Shadow,3,13)
// Track(94,Infinite Rebels from Hell,5,22)
// Track(95,Eternal Titans in Disguise,3,11)
// Track(96,Digital Outlaws of Doom,4,12)
// Track(97,Midnight Empire of Doom,2,9)
// Track(98,Urban Horizon from Hell,5,18)
// Track(99,Midnight Demons from the East,1,2)
// Track(100,Arctic Demons in Flames,3,16)
// Track(101,Wild Outlaws from Mars,3,3)
// Track(102,Stellar Dragons of Tomorrow,2,11)
// Track(103,Liquid Knights from the Sky,1,1)
// Track(104,Silent Killers from the Sky,1,1)
// Track(105,Crystal Killers from Beyond,2,10)
// Track(106,Wild Angels from the Desert,3,3)
// Track(107,Electric Thunder from Hell,3,9)
// Track(108,Mystic Empire of Doom,3,5)
// Track(109,Stellar Rebels of Tomorrow,3,19)
// Track(110,Sacred Horizon of Eternity,5,15)
// Track(111,Phantom Ravens of the Deep,2,20)
// Track(112,Crystal Rebels in Flames,5,22)
// Track(113,Velvet Void from the East,4,15)
// Track(114,Screaming Kings from the Desert,1,17)
// Track(115,Sonic Pirates in Chains,5,10)
// Track(116,Primal Killers from the East,1,2)
// Track(117,Sonic Knights of Death,1,13)
// Track(118,Crimson Heroes of Destruction,2,23)
// Track(119,Liquid Angels from Mars,1,20)
// Track(120,Stellar Giants in Flames,2,12)
// Track(121,Eternal Killers in Chains,5,6)
// Track(122,Mystic Bandits from Hell,5,21)
// Track(123,Silent Lions from Hell,3,20)
// Track(124,Wild Outlaws from the East,4,15)
// Track(125,Golden Knights of the Abyss,2,13)
// Track(126,Arctic Demons from Beyond,4,20)
// Track(127,Neon Shadows from Mars,2,23)
// Track(128,Midnight Rebels in Exile,3,12)
// Track(129,Crystal Killers of the Underground,3,1)
// Track(130,Digital Shadows from the Sky,5,9)
// Track(131,Infinite Pirates of Doom,3,8)
// Track(132,Sonic Angels of Tomorrow,5,11)
// Track(133,Electric Empire from Mars,1,20)
// Track(134,Golden Dragons of the Night,2,3)
// Track(135,Crystal Demons in Chains,4,2)
// Track(136,Eternal Rebels from Beyond,1,18)
// Track(137,Phantom Ghosts in Disguise,3,23)
// Track(138,Sonic Saints from the Sky,2,2)
// Track(139,Lost Ghosts of the Underground,1,25)
// Track(140,Electric Angels of the Abyss,1,23)
// Track(141,Stellar Angels of the Deep,1,22)
// Track(142,Neon Ghosts of the Underground,4,25)
// Track(143,Crystal Outlaws of Eternity,5,19)
// Track(144,Electric Outlaws of the North,1,1)
// Track(145,Lost Thunder of the Night,4,16)
// Track(146,Wild Angels in Chains,2,22)
// Track(147,Lost Bandits from the Desert,4,12)
// Track(148,Midnight Knights of Tomorrow,5,5)
// Track(149,Wild Dragons in Disguise,4,12)
// Track(150,Crystal Rebels of the Abyss,3,13)
// Track(151,Wild Warriors from the Desert,5,2)
// Track(152,Primal Saints in Chains,4,20)
// Track(153,Royal Pirates from Mars,1,21)
// Track(154,Mystic Bandits from Beyond,1,14)
// Track(155,Neon Bandits in Disguise,3,12)
// Track(156,Lunar Machines in Flames,4,13)
// Track(157,Urban Heroes of the Abyss,1,5)
// Track(158,Raging Wizards of Destruction,2,13)
// Track(159,Liquid Empire from the Sky,3,2)
// Track(160,Mystic Bandits of Eternity,3,4)
// Track(161,Infinite Kings from the East,1,23)
// Track(162,Neon Ravens in Flames,2,4)
// Track(163,Arctic Ravens of the Night,3,20)
// Track(164,Velvet Dragons in Exile,5,24)
// Track(165,Urban Saints of the Abyss,1,20)
// Track(166,Sacred Shadows of the North,5,4)
// Track(167,Infinite Machines from the Desert,1,24)
// Track(168,Lost Wizards in Chains,5,17)
// Track(169,Digital Warriors of the Underground,1,5)
// Track(170,Electric Warriors of the Night,4,3)
// Track(171,Arctic Rebels from the Sky,1,22)
// Track(172,Mystic Zombies of the Abyss,1,6)
// Track(173,Mystic Thunder of Eternity,5,24)
// Track(174,Lunar Kings in Flames,2,9)
// Track(175,Silent Saints from Mars,5,24)
// Track(176,Mystic Wolves in Chains,2,20)
// Track(177,Infinite Heroes of Tomorrow,5,2)
// Track(178,Lost Bandits from the East,2,5)
// Track(179,Crimson Lions of the Abyss,5,22)
// Track(180,Digital Wolves in Chains,4,5)
// Track(181,Golden Shadows from the Sky,1,14)
// Track(182,Cosmic Prophets in Shadow,5,14)
// Track(183,Screaming Zombies in Chains,2,16)
// Track(184,Raging Wizards of Eternity,5,19)
// Track(185,Lunar Angels from Mars,5,17)
// Track(186,Electric Killers of Tomorrow,4,14)
// Track(187,Crystal Ghosts in Disguise,3,7)
// Track(188,Toxic Wolves of the Deep,1,5)
// Track(189,Mystic Shadows in Chains,1,9)
// Track(190,Stellar Titans from Mars,4,3)
// Track(191,Royal Titans from Hell,2,16)
// Track(192,Midnight Pirates of the Night,2,25)
// Track(193,Royal Titans from Beyond,3,11)
// Track(194,Lost Saints in Exile,2,7)
// Track(195,Atomic Outlaws in Flames,4,18)
// Track(196,Velvet Rebels of Death,4,22)
// Track(197,Silent Rebels from Mars,4,18)
// Track(198,Stellar Thunder of the Abyss,2,9)
// Track(199,Silent Giants from the Desert,1,20)
// Track(200,Sacred Killers of Doom,3,10)
//
// Liste des invoices :
// Invoice(1,List(11, 12, 13, 14))
// Invoice(2,List(21, 22, 23))
// Invoice(3,List(31))
// Invoice(4,List(41, 42, 43))
// Invoice(5,List(51))
// Invoice(6,List(61))
// Invoice(7,List(71, 72, 73, 74, 75))
// Invoice(8,List(81))
// Invoice(9,List(91, 92))
// Invoice(10,List(101, 102, 103, 104))
// Invoice(11,List(111, 112, 113, 114))
// Invoice(12,List(121, 122, 123, 124))
// Invoice(13,List(131, 132, 133, 134))
// Invoice(14,List(141, 142))
// Invoice(15,List(151, 152, 153))
// Invoice(16,List(161, 162, 163))
// Invoice(17,List(171, 172, 173, 174))
// Invoice(18,List(181, 182, 183))
// Invoice(19,List(191, 192))
// Invoice(20,List(201, 202, 203, 204))
// Invoice(21,List(211, 212, 213))
// Invoice(22,List(221, 222))
// Invoice(23,List(231, 232, 233, 234))
// Invoice(24,List(241, 242, 243))
// Invoice(25,List(251, 252, 253, 254, 255))
// Invoice(26,List(261, 262, 263))
// Invoice(27,List(271, 272, 273, 274))
// Invoice(28,List(281, 282, 283, 284, 285))
// Invoice(29,List(291, 292, 293, 294))
// Invoice(30,List(301))
// Invoice(31,List(311, 312, 313))
// Invoice(32,List(321, 322))
// Invoice(33,List(331, 332, 333, 334, 335))
// Invoice(34,List(341))
// Invoice(35,List(351, 352))
// Invoice(36,List(361, 362, 363, 364))
// Invoice(37,List(371, 372))
// Invoice(38,List(381))
// Invoice(39,List(391))
// Invoice(40,List(401, 402, 403, 404, 405))
// Invoice(41,List(411, 412))
// Invoice(42,List(421, 422))
// Invoice(43,List(431))
// Invoice(44,List(441, 442, 443, 444))
// Invoice(45,List(451))
// Invoice(46,List(461, 462, 463, 464))
// Invoice(47,List(471, 472, 473, 474))
// Invoice(48,List(481, 482))
// Invoice(49,List(491, 492, 493))
// Invoice(50,List(501, 502, 503, 504, 505))
// Invoice(51,List(511, 512))
// Invoice(52,List(521, 522, 523, 524, 525))
// Invoice(53,List(531, 532))
// Invoice(54,List(541, 542))
// Invoice(55,List(551, 552, 553, 554, 555))
// Invoice(56,List(561))
// Invoice(57,List(571))
// Invoice(58,List(581, 582, 583, 584))
// Invoice(59,List(591, 592))
// Invoice(60,List(601))
// Invoice(61,List(611, 612))
// Invoice(62,List(621, 622, 623))
// Invoice(63,List(631, 632))
// Invoice(64,List(641, 642, 643, 644))
// Invoice(65,List(651, 652, 653, 654, 655))
// Invoice(66,List(661, 662, 663, 664, 665))
// Invoice(67,List(671, 672, 673))
// Invoice(68,List(681, 682))
// Invoice(69,List(691, 692, 693))
// Invoice(70,List(701, 702, 703, 704))
// Invoice(71,List(711, 712, 713, 714, 715))
// Invoice(72,List(721, 722, 723))
// Invoice(73,List(731, 732, 733, 734, 735))
// Invoice(74,List(741, 742, 743, 744, 745))
// Invoice(75,List(751, 752, 753))
// Invoice(76,List(761, 762))
// Invoice(77,List(771, 772, 773, 774, 775))
// Invoice(78,List(781))
// Invoice(79,List(791, 792, 793, 794, 795))
// Invoice(80,List(801))
// Invoice(81,List(811, 812, 813))
// Invoice(82,List(821, 822))
// Invoice(83,List(831, 832, 833))
// Invoice(84,List(841, 842, 843, 844))
// Invoice(85,List(851, 852))
// Invoice(86,List(861, 862))
// Invoice(87,List(871, 872, 873))
// Invoice(88,List(881))
// Invoice(89,List(891, 892))
// Invoice(90,List(901, 902, 903))
// Invoice(91,List(911, 912, 913))
// Invoice(92,List(921, 922, 923, 924))
// Invoice(93,List(931))
// Invoice(94,List(941, 942))
// Invoice(95,List(951, 952, 953, 954, 955))
// Invoice(96,List(961, 962, 963))
// Invoice(97,List(971, 972, 973, 974))
// Invoice(98,List(981, 982, 983, 984))
// Invoice(99,List(991, 992, 993))
// Invoice(100,List(1001, 1002, 1003, 1004, 1005))
// Invoice(101,List(1011))
// Invoice(102,List(1021, 1022))
// Invoice(103,List(1031, 1032, 1033))
// Invoice(104,List(1041, 1042, 1043, 1044))
// Invoice(105,List(1051, 1052, 1053, 1054, 1055))
// Invoice(106,List(1061, 1062))
// Invoice(107,List(1071, 1072, 1073, 1074, 1075))
// Invoice(108,List(1081, 1082, 1083, 1084))
// Invoice(109,List(1091, 1092, 1093, 1094))
// Invoice(110,List(1101, 1102, 1103, 1104))
// Invoice(111,List(1111, 1112, 1113, 1114, 1115))
// Invoice(112,List(1121, 1122, 1123, 1124))
// Invoice(113,List(1131, 1132, 1133, 1134, 1135))
// Invoice(114,List(1141, 1142, 1143, 1144, 1145))
// Invoice(115,List(1151, 1152, 1153))
// Invoice(116,List(1161))
// Invoice(117,List(1171, 1172))
// Invoice(118,List(1181, 1182, 1183, 1184))
// Invoice(119,List(1191, 1192, 1193))
// Invoice(120,List(1201, 1202, 1203))
// Invoice(121,List(1211, 1212))
// Invoice(122,List(1221))
// Invoice(123,List(1231, 1232, 1233, 1234))
// Invoice(124,List(1241, 1242, 1243))
// Invoice(125,List(1251, 1252, 1253, 1254))
// Invoice(126,List(1261, 1262, 1263, 1264))
// Invoice(127,List(1271))
// Invoice(128,List(1281, 1282, 1283, 1284))
// Invoice(129,List(1291, 1292, 1293))
// Invoice(130,List(1301, 1302, 1303, 1304, 1305))
// Invoice(131,List(1311, 1312, 1313, 1314, 1315))
// Invoice(132,List(1321, 1322, 1323, 1324, 1325))
// Invoice(133,List(1331, 1332, 1333))
// Invoice(134,List(1341, 1342, 1343))
// Invoice(135,List(1351, 1352, 1353, 1354))
// Invoice(136,List(1361, 1362, 1363, 1364))
// Invoice(137,List(1371, 1372))
// Invoice(138,List(1381))
// Invoice(139,List(1391))
// Invoice(140,List(1401, 1402, 1403, 1404, 1405))
// Invoice(141,List(1411, 1412, 1413, 1414, 1415))
// Invoice(142,List(1421, 1422, 1423))
// Invoice(143,List(1431, 1432, 1433))
// Invoice(144,List(1441, 1442, 1443, 1444))
// Invoice(145,List(1451, 1452))
// Invoice(146,List(1461, 1462, 1463, 1464, 1465))
// Invoice(147,List(1471, 1472, 1473, 1474))
// Invoice(148,List(1481, 1482))
// Invoice(149,List(1491, 1492, 1493))
// Invoice(150,List(1501, 1502))
// Invoice(151,List(1511, 1512))
// Invoice(152,List(1521, 1522, 1523, 1524, 1525))
// Invoice(153,List(1531, 1532, 1533))
// Invoice(154,List(1541, 1542, 1543))
// Invoice(155,List(1551, 1552))
// Invoice(156,List(1561, 1562, 1563))
// Invoice(157,List(1571, 1572, 1573))
// Invoice(158,List(1581, 1582, 1583, 1584))
// Invoice(159,List(1591, 1592, 1593, 1594))
// Invoice(160,List(1601))
// Invoice(161,List(1611))
// Invoice(162,List(1621, 1622, 1623))
// Invoice(163,List(1631, 1632, 1633, 1634))
// Invoice(164,List(1641))
// Invoice(165,List(1651, 1652, 1653, 1654, 1655))
// Invoice(166,List(1661, 1662, 1663, 1664))
// Invoice(167,List(1671))
// Invoice(168,List(1681, 1682, 1683, 1684, 1685))
// Invoice(169,List(1691, 1692, 1693))
// Invoice(170,List(1701, 1702))
// Invoice(171,List(1711))
// Invoice(172,List(1721, 1722, 1723, 1724))
// Invoice(173,List(1731, 1732, 1733, 1734))
// Invoice(174,List(1741, 1742, 1743, 1744))
// Invoice(175,List(1751, 1752))
// Invoice(176,List(1761, 1762, 1763, 1764))
// Invoice(177,List(1771, 1772, 1773, 1774, 1775))
// Invoice(178,List(1781, 1782, 1783, 1784, 1785))
// Invoice(179,List(1791, 1792, 1793))
// Invoice(180,List(1801, 1802, 1803, 1804, 1805))
// Invoice(181,List(1811, 1812))
// Invoice(182,List(1821))
// Invoice(183,List(1831, 1832, 1833, 1834, 1835))
// Invoice(184,List(1841, 1842, 1843, 1844, 1845))
// Invoice(185,List(1851, 1852, 1853, 1854))
// Invoice(186,List(1861))
// Invoice(187,List(1871, 1872, 1873))
// Invoice(188,List(1881))
// Invoice(189,List(1891, 1892, 1893, 1894))
// Invoice(190,List(1901))
// Invoice(191,List(1911, 1912, 1913))
// Invoice(192,List(1921, 1922, 1923, 1924))
// Invoice(193,List(1931, 1932, 1933, 1934, 1935))
// Invoice(194,List(1941, 1942, 1943, 1944, 1945))
// Invoice(195,List(1951, 1952, 1953, 1954, 1955))
// Invoice(196,List(1961, 1962, 1963, 1964, 1965))
// Invoice(197,List(1971))
// Invoice(198,List(1981, 1982, 1983, 1984))
// Invoice(199,List(1991, 1992, 1993, 1994))
// Invoice(200,List(2001, 2002, 2003, 2004))
// Invoice(201,List(2011, 2012, 2013, 2014))
// Invoice(202,List(2021, 2022, 2023))
// Invoice(203,List(2031, 2032, 2033, 2034, 2035))
// Invoice(204,List(2041, 2042))
// Invoice(205,List(2051, 2052, 2053))
// Invoice(206,List(2061, 2062, 2063, 2064))
// Invoice(207,List(2071, 2072, 2073))
// Invoice(208,List(2081, 2082))
// Invoice(209,List(2091, 2092, 2093))
// Invoice(210,List(2101))
// Invoice(211,List(2111, 2112, 2113, 2114, 2115))
// Invoice(212,List(2121, 2122, 2123, 2124))
// Invoice(213,List(2131))
// Invoice(214,List(2141, 2142))
// Invoice(215,List(2151))
// Invoice(216,List(2161, 2162))
// Invoice(217,List(2171, 2172))
// Invoice(218,List(2181, 2182))
// Invoice(219,List(2191, 2192))
// Invoice(220,List(2201, 2202, 2203, 2204, 2205))
// Invoice(221,List(2211, 2212, 2213, 2214, 2215))
// Invoice(222,List(2221, 2222, 2223))
// Invoice(223,List(2231, 2232, 2233))
// Invoice(224,List(2241))
// Invoice(225,List(2251))
// Invoice(226,List(2261, 2262, 2263, 2264))
// Invoice(227,List(2271))
// Invoice(228,List(2281, 2282))
// Invoice(229,List(2291, 2292, 2293, 2294))
// Invoice(230,List(2301, 2302, 2303))
// Invoice(231,List(2311, 2312, 2313, 2314, 2315))
// Invoice(232,List(2321, 2322, 2323, 2324))
// Invoice(233,List(2331, 2332, 2333, 2334, 2335))
// Invoice(234,List(2341, 2342, 2343, 2344))
// Invoice(235,List(2351))
// Invoice(236,List(2361, 2362))
// Invoice(237,List(2371, 2372, 2373, 2374))
// Invoice(238,List(2381, 2382, 2383, 2384, 2385))
// Invoice(239,List(2391, 2392, 2393, 2394))
// Invoice(240,List(2401, 2402, 2403))
// Invoice(241,List(2411, 2412))
// Invoice(242,List(2421, 2422, 2423, 2424, 2425))
// Invoice(243,List(2431))
// Invoice(244,List(2441, 2442, 2443, 2444))
// Invoice(245,List(2451, 2452, 2453, 2454))
// Invoice(246,List(2461, 2462, 2463, 2464))
// Invoice(247,List(2471))
// Invoice(248,List(2481))
// Invoice(249,List(2491, 2492, 2493, 2494, 2495))
// Invoice(250,List(2501, 2502, 2503, 2504, 2505))
// Invoice(251,List(2511))
// Invoice(252,List(2521, 2522))
// Invoice(253,List(2531, 2532, 2533, 2534))
// Invoice(254,List(2541, 2542, 2543, 2544))
// Invoice(255,List(2551, 2552, 2553, 2554))
// Invoice(256,List(2561))
// Invoice(257,List(2571))
// Invoice(258,List(2581, 2582))
// Invoice(259,List(2591, 2592, 2593, 2594, 2595))
// Invoice(260,List(2601, 2602, 2603, 2604))
// Invoice(261,List(2611, 2612, 2613))
// Invoice(262,List(2621, 2622))
// Invoice(263,List(2631))
// Invoice(264,List(2641, 2642, 2643, 2644, 2645))
// Invoice(265,List(2651))
// Invoice(266,List(2661))
// Invoice(267,List(2671, 2672))
// Invoice(268,List(2681, 2682, 2683))
// Invoice(269,List(2691, 2692, 2693))
// Invoice(270,List(2701, 2702, 2703, 2704, 2705))
// Invoice(271,List(2711, 2712, 2713))
// Invoice(272,List(2721, 2722, 2723))
// Invoice(273,List(2731, 2732, 2733, 2734))
// Invoice(274,List(2741, 2742))
// Invoice(275,List(2751, 2752))
// Invoice(276,List(2761))
// Invoice(277,List(2771, 2772, 2773))
// Invoice(278,List(2781, 2782, 2783, 2784))
// Invoice(279,List(2791, 2792))
// Invoice(280,List(2801, 2802, 2803))
// Invoice(281,List(2811, 2812, 2813))
// Invoice(282,List(2821, 2822, 2823, 2824, 2825))
// Invoice(283,List(2831, 2832, 2833))
// Invoice(284,List(2841))
// Invoice(285,List(2851, 2852, 2853))
// Invoice(286,List(2861))
// Invoice(287,List(2871, 2872, 2873))
// Invoice(288,List(2881, 2882))
// Invoice(289,List(2891, 2892))
// Invoice(290,List(2901, 2902, 2903, 2904, 2905))
// Invoice(291,List(2911, 2912))
// Invoice(292,List(2921, 2922, 2923, 2924))
// Invoice(293,List(2931, 2932, 2933, 2934))
// Invoice(294,List(2941, 2942))
// Invoice(295,List(2951, 2952))
// Invoice(296,List(2961, 2962, 2963))
// Invoice(297,List(2971, 2972, 2973, 2974))
// Invoice(298,List(2981, 2982, 2983))
// Invoice(299,List(2991))
// Invoice(300,List(3001, 3002, 3003))
// Invoice(301,List(3011, 3012, 3013, 3014, 3015))
// Invoice(302,List(3021))
// Invoice(303,List(3031, 3032, 3033))
// Invoice(304,List(3041))
// Invoice(305,List(3051, 3052, 3053, 3054))
// Invoice(306,List(3061, 3062, 3063, 3064, 3065))
// Invoice(307,List(3071, 3072, 3073, 3074, 3075))
// Invoice(308,List(3081, 3082, 3083))
// Invoice(309,List(3091, 3092, 3093, 3094, 3095))
// Invoice(310,List(3101, 3102, 3103, 3104, 3105))
// Invoice(311,List(3111, 3112, 3113, 3114))
// Invoice(312,List(3121, 3122, 3123))
// Invoice(313,List(3131, 3132, 3133, 3134))
// Invoice(314,List(3141))
// Invoice(315,List(3151, 3152, 3153, 3154))
// Invoice(316,List(3161, 3162))
// Invoice(317,List(3171, 3172, 3173, 3174))
// Invoice(318,List(3181, 3182, 3183, 3184, 3185))
// Invoice(319,List(3191, 3192, 3193))
// Invoice(320,List(3201, 3202, 3203, 3204))
// Invoice(321,List(3211, 3212, 3213, 3214))
// Invoice(322,List(3221, 3222, 3223, 3224, 3225))
// Invoice(323,List(3231, 3232))
// Invoice(324,List(3241, 3242))
// Invoice(325,List(3251, 3252, 3253))
// Invoice(326,List(3261, 3262, 3263, 3264, 3265))
// Invoice(327,List(3271, 3272, 3273, 3274))
// Invoice(328,List(3281, 3282))
// Invoice(329,List(3291))
// Invoice(330,List(3301, 3302))
// Invoice(331,List(3311))
// Invoice(332,List(3321, 3322, 3323))
// Invoice(333,List(3331, 3332, 3333, 3334))
// Invoice(334,List(3341, 3342, 3343, 3344))
// Invoice(335,List(3351))
// Invoice(336,List(3361, 3362, 3363))
// Invoice(337,List(3371))
// Invoice(338,List(3381, 3382, 3383, 3384))
// Invoice(339,List(3391, 3392, 3393, 3394))
// Invoice(340,List(3401, 3402, 3403, 3404))
// Invoice(341,List(3411, 3412, 3413, 3414, 3415))
// Invoice(342,List(3421))
// Invoice(343,List(3431, 3432, 3433))
// Invoice(344,List(3441, 3442))
// Invoice(345,List(3451, 3452, 3453, 3454, 3455))
// Invoice(346,List(3461, 3462, 3463, 3464))
// Invoice(347,List(3471, 3472, 3473, 3474))
// Invoice(348,List(3481, 3482))
// Invoice(349,List(3491, 3492))
// Invoice(350,List(3501, 3502, 3503, 3504))
// Invoice(351,List(3511, 3512, 3513, 3514, 3515))
// Invoice(352,List(3521, 3522, 3523))
// Invoice(353,List(3531, 3532, 3533, 3534, 3535))
// Invoice(354,List(3541, 3542, 3543))
// Invoice(355,List(3551, 3552))
// Invoice(356,List(3561, 3562))
// Invoice(357,List(3571, 3572, 3573, 3574, 3575))
// Invoice(358,List(3581, 3582, 3583))
// Invoice(359,List(3591))
// Invoice(360,List(3601))
// Invoice(361,List(3611, 3612))
// Invoice(362,List(3621, 3622, 3623, 3624, 3625))
// Invoice(363,List(3631, 3632, 3633))
// Invoice(364,List(3641, 3642, 3643, 3644))
// Invoice(365,List(3651, 3652))
// Invoice(366,List(3661, 3662, 3663, 3664, 3665))
// Invoice(367,List(3671, 3672, 3673))
// Invoice(368,List(3681, 3682, 3683, 3684))
// Invoice(369,List(3691, 3692, 3693, 3694))
// Invoice(370,List(3701, 3702, 3703, 3704))
// Invoice(371,List(3711, 3712))
// Invoice(372,List(3721))
// Invoice(373,List(3731))
// Invoice(374,List(3741, 3742))
// Invoice(375,List(3751))
// Invoice(376,List(3761, 3762, 3763, 3764, 3765))
// Invoice(377,List(3771, 3772, 3773))
// Invoice(378,List(3781))
// Invoice(379,List(3791, 3792))
// Invoice(380,List(3801))
// Invoice(381,List(3811, 3812, 3813, 3814, 3815))
// Invoice(382,List(3821, 3822))
// Invoice(383,List(3831, 3832, 3833))
// Invoice(384,List(3841, 3842, 3843))
// Invoice(385,List(3851, 3852, 3853))
// Invoice(386,List(3861, 3862, 3863))
// Invoice(387,List(3871))
// Invoice(388,List(3881))
// Invoice(389,List(3891))
// Invoice(390,List(3901, 3902))
// Invoice(391,List(3911))
// Invoice(392,List(3921, 3922, 3923))
// Invoice(393,List(3931, 3932, 3933))
// Invoice(394,List(3941, 3942, 3943))
// Invoice(395,List(3951, 3952))
// Invoice(396,List(3961, 3962, 3963))
// Invoice(397,List(3971, 3972, 3973, 3974, 3975))
// Invoice(398,List(3981, 3982))
// Invoice(399,List(3991, 3992))
// Invoice(400,List(4001, 4002, 4003))
// Invoice(401,List(4011, 4012))
// Invoice(402,List(4021, 4022, 4023, 4024, 4025))
// Invoice(403,List(4031, 4032, 4033))
// Invoice(404,List(4041, 4042, 4043, 4044, 4045))
// Invoice(405,List(4051))
// Invoice(406,List(4061))
// Invoice(407,List(4071))
// Invoice(408,List(4081))
// Invoice(409,List(4091, 4092, 4093))
// Invoice(410,List(4101, 4102))
// Invoice(411,List(4111, 4112, 4113, 4114))
// Invoice(412,List(4121, 4122, 4123, 4124))
// Invoice(413,List(4131, 4132))
// Invoice(414,List(4141, 4142, 4143, 4144, 4145))
// Invoice(415,List(4151, 4152, 4153))
// Invoice(416,List(4161, 4162, 4163, 4164))
// Invoice(417,List(4171, 4172))
// Invoice(418,List(4181, 4182))
// Invoice(419,List(4191, 4192, 4193, 4194, 4195))
// Invoice(420,List(4201, 4202))
// Invoice(421,List(4211, 4212, 4213))
// Invoice(422,List(4221))
// Invoice(423,List(4231, 4232, 4233, 4234, 4235))
// Invoice(424,List(4241, 4242, 4243))
// Invoice(425,List(4251, 4252, 4253, 4254, 4255))
// Invoice(426,List(4261, 4262))
// Invoice(427,List(4271, 4272, 4273, 4274, 4275))
// Invoice(428,List(4281, 4282, 4283))
// Invoice(429,List(4291, 4292, 4293, 4294))
// Invoice(430,List(4301, 4302, 4303, 4304))
// Invoice(431,List(4311, 4312, 4313, 4314, 4315))
// Invoice(432,List(4321, 4322, 4323, 4324, 4325))
// Invoice(433,List(4331))
// Invoice(434,List(4341))
// Invoice(435,List(4351, 4352))
// Invoice(436,List(4361, 4362, 4363, 4364))
// Invoice(437,List(4371, 4372, 4373, 4374))
// Invoice(438,List(4381, 4382, 4383, 4384))
// Invoice(439,List(4391, 4392, 4393))
// Invoice(440,List(4401))
// Invoice(441,List(4411, 4412, 4413, 4414))
// Invoice(442,List(4421))
// Invoice(443,List(4431, 4432, 4433, 4434))
// Invoice(444,List(4441, 4442, 4443, 4444))
// Invoice(445,List(4451))
// Invoice(446,List(4461, 4462, 4463))
// Invoice(447,List(4471, 4472))
// Invoice(448,List(4481, 4482))
// Invoice(449,List(4491))
// Invoice(450,List(4501, 4502, 4503, 4504, 4505))
// Invoice(451,List(4511, 4512, 4513))
// Invoice(452,List(4521, 4522, 4523, 4524))
// Invoice(453,List(4531, 4532, 4533, 4534))
// Invoice(454,List(4541, 4542))
// Invoice(455,List(4551))
// Invoice(456,List(4561, 4562))
// Invoice(457,List(4571, 4572, 4573, 4574, 4575))
// Invoice(458,List(4581, 4582, 4583, 4584, 4585))
// Invoice(459,List(4591, 4592, 4593))
// Invoice(460,List(4601, 4602, 4603, 4604))
// Invoice(461,List(4611, 4612))
// Invoice(462,List(4621, 4622, 4623, 4624))
// Invoice(463,List(4631, 4632, 4633, 4634, 4635))
// Invoice(464,List(4641, 4642, 4643, 4644, 4645))
// Invoice(465,List(4651, 4652))
// Invoice(466,List(4661, 4662, 4663, 4664, 4665))
// Invoice(467,List(4671, 4672, 4673))
// Invoice(468,List(4681, 4682, 4683, 4684, 4685))
// Invoice(469,List(4691, 4692))
// Invoice(470,List(4701))
// Invoice(471,List(4711, 4712))
// Invoice(472,List(4721, 4722, 4723, 4724, 4725))
// Invoice(473,List(4731))
// Invoice(474,List(4741))
// Invoice(475,List(4751))
// Invoice(476,List(4761, 4762))
// Invoice(477,List(4771, 4772, 4773, 4774, 4775))
// Invoice(478,List(4781))
// Invoice(479,List(4791, 4792))
// Invoice(480,List(4801, 4802, 4803))
// Invoice(481,List(4811, 4812))
// Invoice(482,List(4821, 4822, 4823))
// Invoice(483,List(4831, 4832, 4833))
// Invoice(484,List(4841, 4842, 4843))
// Invoice(485,List(4851, 4852))
// Invoice(486,List(4861, 4862))
// Invoice(487,List(4871))
// Invoice(488,List(4881, 4882))
// Invoice(489,List(4891, 4892, 4893))
// Invoice(490,List(4901, 4902, 4903, 4904))
// Invoice(491,List(4911, 4912, 4913, 4914))
// Invoice(492,List(4921, 4922, 4923, 4924, 4925))
// Invoice(493,List(4931))
// Invoice(494,List(4941, 4942))
// Invoice(495,List(4951, 4952, 4953, 4954, 4955))
// Invoice(496,List(4961, 4962, 4963))
// Invoice(497,List(4971, 4972, 4973, 4974, 4975))
// Invoice(498,List(4981, 4982))
// Invoice(499,List(4991, 4992, 4993))
// Invoice(500,List(5001, 5002, 5003, 5004))
// Invoice(501,List(5011))
// Invoice(502,List(5021, 5022, 5023))
// Invoice(503,List(5031, 5032))
// Invoice(504,List(5041, 5042, 5043, 5044, 5045))
// Invoice(505,List(5051, 5052, 5053, 5054, 5055))
// Invoice(506,List(5061))
// Invoice(507,List(5071, 5072))
// Invoice(508,List(5081, 5082, 5083, 5084))
// Invoice(509,List(5091, 5092, 5093, 5094))
// Invoice(510,List(5101))
// Invoice(511,List(5111, 5112, 5113, 5114))
// Invoice(512,List(5121, 5122))
// Invoice(513,List(5131, 5132, 5133))
// Invoice(514,List(5141))
// Invoice(515,List(5151, 5152, 5153))
// Invoice(516,List(5161))
// Invoice(517,List(5171))
// Invoice(518,List(5181))
// Invoice(519,List(5191, 5192))
// Invoice(520,List(5201, 5202, 5203, 5204, 5205))
// Invoice(521,List(5211, 5212))
// Invoice(522,List(5221, 5222, 5223, 5224))
// Invoice(523,List(5231, 5232, 5233, 5234))
// Invoice(524,List(5241, 5242, 5243))
// Invoice(525,List(5251, 5252))
// Invoice(526,List(5261, 5262, 5263, 5264))
// Invoice(527,List(5271, 5272, 5273, 5274))
// Invoice(528,List(5281, 5282, 5283, 5284))
// Invoice(529,List(5291, 5292, 5293, 5294))
// Invoice(530,List(5301, 5302, 5303, 5304, 5305))
// Invoice(531,List(5311, 5312))
// Invoice(532,List(5321, 5322, 5323, 5324))
// Invoice(533,List(5331, 5332, 5333))
// Invoice(534,List(5341))
// Invoice(535,List(5351))
// Invoice(536,List(5361, 5362, 5363))
// Invoice(537,List(5371, 5372, 5373, 5374))
// Invoice(538,List(5381, 5382, 5383, 5384, 5385))
// Invoice(539,List(5391, 5392, 5393))
// Invoice(540,List(5401, 5402))
// Invoice(541,List(5411, 5412, 5413, 5414, 5415))
// Invoice(542,List(5421, 5422, 5423, 5424))
// Invoice(543,List(5431, 5432, 5433))
// Invoice(544,List(5441, 5442, 5443))
// Invoice(545,List(5451))
// Invoice(546,List(5461, 5462, 5463, 5464, 5465))
// Invoice(547,List(5471, 5472, 5473, 5474, 5475))
// Invoice(548,List(5481, 5482, 5483))
// Invoice(549,List(5491, 5492, 5493, 5494, 5495))
// Invoice(550,List(5501, 5502, 5503))
// Invoice(551,List(5511, 5512))
// Invoice(552,List(5521))
// Invoice(553,List(5531, 5532, 5533))
// Invoice(554,List(5541, 5542))
// Invoice(555,List(5551, 5552, 5553))
// Invoice(556,List(5561, 5562))
// Invoice(557,List(5571, 5572, 5573, 5574, 5575))
// Invoice(558,List(5581, 5582, 5583, 5584))
// Invoice(559,List(5591, 5592, 5593, 5594, 5595))
// Invoice(560,List(5601, 5602, 5603, 5604, 5605))
// Invoice(561,List(5611, 5612, 5613, 5614))
// Invoice(562,List(5621, 5622, 5623))
// Invoice(563,List(5631, 5632, 5633, 5634, 5635))
// Invoice(564,List(5641, 5642, 5643))
// Invoice(565,List(5651))
// Invoice(566,List(5661, 5662))
// Invoice(567,List(5671))
// Invoice(568,List(5681))
// Invoice(569,List(5691))
// Invoice(570,List(5701))
// Invoice(571,List(5711, 5712, 5713))
// Invoice(572,List(5721, 5722, 5723))
// Invoice(573,List(5731))
// Invoice(574,List(5741))
// Invoice(575,List(5751, 5752, 5753, 5754))
// Invoice(576,List(5761, 5762))
// Invoice(577,List(5771, 5772, 5773))
// Invoice(578,List(5781, 5782, 5783, 5784, 5785))
// Invoice(579,List(5791, 5792))
// Invoice(580,List(5801, 5802))
// Invoice(581,List(5811, 5812, 5813))
// Invoice(582,List(5821, 5822, 5823))
// Invoice(583,List(5831, 5832))
// Invoice(584,List(5841, 5842, 5843))
// Invoice(585,List(5851, 5852, 5853, 5854))
// Invoice(586,List(5861, 5862, 5863, 5864))
// Invoice(587,List(5871, 5872))
// Invoice(588,List(5881))
// Invoice(589,List(5891, 5892, 5893))
// Invoice(590,List(5901, 5902, 5903, 5904))
// Invoice(591,List(5911))
// Invoice(592,List(5921, 5922, 5923))
// Invoice(593,List(5931, 5932, 5933))
// Invoice(594,List(5941, 5942, 5943))
// Invoice(595,List(5951, 5952, 5953, 5954))
// Invoice(596,List(5961))
// Invoice(597,List(5971, 5972))
// Invoice(598,List(5981, 5982))
// Invoice(599,List(5991, 5992, 5993, 5994))
// Invoice(600,List(6001, 6002, 6003, 6004, 6005))
// Invoice(601,List(6011, 6012, 6013, 6014, 6015))
// Invoice(602,List(6021, 6022, 6023, 6024, 6025))
// Invoice(603,List(6031, 6032, 6033, 6034))
// Invoice(604,List(6041, 6042, 6043, 6044))
// Invoice(605,List(6051, 6052, 6053, 6054, 6055))
// Invoice(606,List(6061, 6062, 6063, 6064, 6065))
// Invoice(607,List(6071, 6072, 6073))
// Invoice(608,List(6081, 6082, 6083, 6084))
// Invoice(609,List(6091, 6092))
// Invoice(610,List(6101, 6102, 6103, 6104, 6105))
// Invoice(611,List(6111, 6112))
// Invoice(612,List(6121, 6122, 6123, 6124, 6125))
// Invoice(613,List(6131, 6132, 6133, 6134, 6135))
// Invoice(614,List(6141))
// Invoice(615,List(6151, 6152, 6153))
// Invoice(616,List(6161, 6162, 6163, 6164))
// Invoice(617,List(6171, 6172, 6173, 6174, 6175))
// Invoice(618,List(6181))
// Invoice(619,List(6191))
// Invoice(620,List(6201))
// Invoice(621,List(6211, 6212, 6213))
// Invoice(622,List(6221, 6222, 6223, 6224, 6225))
// Invoice(623,List(6231, 6232, 6233))
// Invoice(624,List(6241, 6242, 6243, 6244))
// Invoice(625,List(6251, 6252, 6253))
// Invoice(626,List(6261, 6262, 6263, 6264))
// Invoice(627,List(6271, 6272))
// Invoice(628,List(6281, 6282, 6283))
// Invoice(629,List(6291, 6292, 6293, 6294, 6295))
// Invoice(630,List(6301, 6302, 6303, 6304))
// Invoice(631,List(6311))
// Invoice(632,List(6321, 6322, 6323, 6324, 6325))
// Invoice(633,List(6331, 6332))
// Invoice(634,List(6341, 6342))
// Invoice(635,List(6351, 6352, 6353))
// Invoice(636,List(6361, 6362))
// Invoice(637,List(6371, 6372, 6373, 6374, 6375))
// Invoice(638,List(6381))
// Invoice(639,List(6391, 6392, 6393))
// Invoice(640,List(6401, 6402, 6403))
// Invoice(641,List(6411))
// Invoice(642,List(6421, 6422, 6423, 6424, 6425))
// Invoice(643,List(6431, 6432, 6433, 6434))
// Invoice(644,List(6441, 6442, 6443))
// Invoice(645,List(6451, 6452))
// Invoice(646,List(6461, 6462, 6463, 6464, 6465))
// Invoice(647,List(6471, 6472, 6473, 6474))
// Invoice(648,List(6481, 6482, 6483))
// Invoice(649,List(6491, 6492, 6493))
// Invoice(650,List(6501))
// Invoice(651,List(6511, 6512, 6513))
// Invoice(652,List(6521))
// Invoice(653,List(6531, 6532, 6533, 6534, 6535))
// Invoice(654,List(6541, 6542, 6543, 6544, 6545))
// Invoice(655,List(6551, 6552, 6553, 6554, 6555))
// Invoice(656,List(6561, 6562))
// Invoice(657,List(6571, 6572, 6573, 6574))
// Invoice(658,List(6581, 6582, 6583, 6584))
// Invoice(659,List(6591, 6592))
// Invoice(660,List(6601, 6602))
// Invoice(661,List(6611))
// Invoice(662,List(6621, 6622))
// Invoice(663,List(6631, 6632, 6633, 6634, 6635))
// Invoice(664,List(6641))
// Invoice(665,List(6651, 6652, 6653, 6654))
// Invoice(666,List(6661, 6662, 6663, 6664))
// Invoice(667,List(6671, 6672, 6673, 6674, 6675))
// Invoice(668,List(6681, 6682, 6683, 6684))
// Invoice(669,List(6691, 6692, 6693, 6694, 6695))
// Invoice(670,List(6701, 6702, 6703))
// Invoice(671,List(6711, 6712, 6713, 6714, 6715))
// Invoice(672,List(6721, 6722, 6723, 6724, 6725))
// Invoice(673,List(6731, 6732, 6733))
// Invoice(674,List(6741))
// Invoice(675,List(6751, 6752, 6753))
// Invoice(676,List(6761, 6762, 6763))
// Invoice(677,List(6771, 6772))
// Invoice(678,List(6781))
// Invoice(679,List(6791, 6792))
// Invoice(680,List(6801, 6802))
// Invoice(681,List(6811, 6812))
// Invoice(682,List(6821, 6822, 6823))
// Invoice(683,List(6831, 6832))
// Invoice(684,List(6841, 6842))
// Invoice(685,List(6851, 6852, 6853, 6854))
// Invoice(686,List(6861, 6862, 6863, 6864))
// Invoice(687,List(6871, 6872))
// Invoice(688,List(6881, 6882, 6883))
// Invoice(689,List(6891, 6892, 6893, 6894))
// Invoice(690,List(6901))
// Invoice(691,List(6911, 6912, 6913))
// Invoice(692,List(6921, 6922, 6923, 6924, 6925))
// Invoice(693,List(6931))
// Invoice(694,List(6941, 6942))
// Invoice(695,List(6951, 6952, 6953))
// Invoice(696,List(6961, 6962, 6963, 6964))
// Invoice(697,List(6971, 6972))
// Invoice(698,List(6981, 6982, 6983, 6984, 6985))
// Invoice(699,List(6991))
// Invoice(700,List(7001, 7002, 7003, 7004))
// Invoice(701,List(7011, 7012))
// Invoice(702,List(7021, 7022, 7023, 7024))
// Invoice(703,List(7031, 7032, 7033))
// Invoice(704,List(7041))
// Invoice(705,List(7051, 7052, 7053))
// Invoice(706,List(7061, 7062, 7063))
// Invoice(707,List(7071))
// Invoice(708,List(7081))
// Invoice(709,List(7091, 7092, 7093))
// Invoice(710,List(7101, 7102))
// Invoice(711,List(7111, 7112, 7113, 7114, 7115))
// Invoice(712,List(7121))
// Invoice(713,List(7131, 7132, 7133, 7134))
// Invoice(714,List(7141, 7142, 7143, 7144, 7145))
// Invoice(715,List(7151, 7152, 7153, 7154, 7155))
// Invoice(716,List(7161, 7162))
// Invoice(717,List(7171, 7172))
// Invoice(718,List(7181, 7182, 7183, 7184))
// Invoice(719,List(7191, 7192, 7193))
// Invoice(720,List(7201, 7202, 7203))
// Invoice(721,List(7211, 7212, 7213, 7214))
// Invoice(722,List(7221, 7222, 7223, 7224))
// Invoice(723,List(7231, 7232, 7233, 7234))
// Invoice(724,List(7241, 7242, 7243))
// Invoice(725,List(7251, 7252))
// Invoice(726,List(7261, 7262, 7263, 7264, 7265))
// Invoice(727,List(7271))
// Invoice(728,List(7281))
// Invoice(729,List(7291, 7292, 7293))
// Invoice(730,List(7301))
// Invoice(731,List(7311, 7312, 7313, 7314, 7315))
// Invoice(732,List(7321, 7322))
// Invoice(733,List(7331, 7332, 7333, 7334, 7335))
// Invoice(734,List(7341, 7342))
// Invoice(735,List(7351, 7352, 7353, 7354, 7355))
// Invoice(736,List(7361, 7362))
// Invoice(737,List(7371, 7372))
// Invoice(738,List(7381, 7382, 7383, 7384, 7385))
// Invoice(739,List(7391, 7392, 7393, 7394))
// Invoice(740,List(7401, 7402, 7403))
// Invoice(741,List(7411, 7412, 7413, 7414))
// Invoice(742,List(7421, 7422))
// Invoice(743,List(7431))
// Invoice(744,List(7441))
// Invoice(745,List(7451, 7452, 7453))
// Invoice(746,List(7461, 7462, 7463, 7464))
// Invoice(747,List(7471, 7472, 7473, 7474))
// Invoice(748,List(7481))
// Invoice(749,List(7491))
// Invoice(750,List(7501, 7502, 7503))
// Invoice(751,List(7511, 7512, 7513))
// Invoice(752,List(7521))
// Invoice(753,List(7531, 7532, 7533, 7534, 7535))
// Invoice(754,List(7541, 7542, 7543, 7544))
// Invoice(755,List(7551, 7552, 7553))
// Invoice(756,List(7561, 7562))
// Invoice(757,List(7571, 7572, 7573, 7574))
// Invoice(758,List(7581, 7582, 7583))
// Invoice(759,List(7591, 7592, 7593, 7594, 7595))
// Invoice(760,List(7601))
// Invoice(761,List(7611, 7612))
// Invoice(762,List(7621, 7622))
// Invoice(763,List(7631, 7632))
// Invoice(764,List(7641, 7642, 7643))
// Invoice(765,List(7651, 7652))
// Invoice(766,List(7661, 7662, 7663))
// Invoice(767,List(7671, 7672, 7673, 7674))
// Invoice(768,List(7681, 7682, 7683))
// Invoice(769,List(7691, 7692, 7693))
// Invoice(770,List(7701))
// Invoice(771,List(7711, 7712, 7713, 7714, 7715))
// Invoice(772,List(7721, 7722, 7723, 7724))
// Invoice(773,List(7731))
// Invoice(774,List(7741, 7742, 7743))
// Invoice(775,List(7751, 7752))
// Invoice(776,List(7761))
// Invoice(777,List(7771, 7772, 7773))
// Invoice(778,List(7781, 7782, 7783, 7784, 7785))
// Invoice(779,List(7791, 7792))
// Invoice(780,List(7801, 7802, 7803))
// Invoice(781,List(7811, 7812, 7813, 7814))
// Invoice(782,List(7821, 7822, 7823, 7824, 7825))
// Invoice(783,List(7831, 7832))
// Invoice(784,List(7841))
// Invoice(785,List(7851, 7852))
// Invoice(786,List(7861, 7862, 7863))
// Invoice(787,List(7871))
// Invoice(788,List(7881, 7882, 7883, 7884, 7885))
// Invoice(789,List(7891, 7892, 7893))
// Invoice(790,List(7901, 7902, 7903, 7904))
// Invoice(791,List(7911))
// Invoice(792,List(7921))
// Invoice(793,List(7931))
// Invoice(794,List(7941, 7942, 7943))
// Invoice(795,List(7951))
// Invoice(796,List(7961, 7962, 7963))
// Invoice(797,List(7971, 7972, 7973, 7974, 7975))
// Invoice(798,List(7981))
// Invoice(799,List(7991, 7992, 7993))
// Invoice(800,List(8001))
// Invoice(801,List(8011, 8012, 8013, 8014, 8015))
// Invoice(802,List(8021, 8022, 8023, 8024, 8025))
// Invoice(803,List(8031, 8032))
// Invoice(804,List(8041, 8042, 8043))
// Invoice(805,List(8051, 8052, 8053))
// Invoice(806,List(8061))
// Invoice(807,List(8071, 8072, 8073, 8074, 8075))
// Invoice(808,List(8081, 8082, 8083))
// Invoice(809,List(8091, 8092, 8093, 8094, 8095))
// Invoice(810,List(8101, 8102, 8103, 8104))
// Invoice(811,List(8111, 8112, 8113, 8114, 8115))
// Invoice(812,List(8121, 8122, 8123))
// Invoice(813,List(8131))
// Invoice(814,List(8141, 8142, 8143))
// Invoice(815,List(8151, 8152, 8153, 8154, 8155))
// Invoice(816,List(8161, 8162))
// Invoice(817,List(8171, 8172, 8173, 8174))
// Invoice(818,List(8181))
// Invoice(819,List(8191, 8192, 8193, 8194, 8195))
// Invoice(820,List(8201, 8202))
// Invoice(821,List(8211, 8212, 8213))
// Invoice(822,List(8221, 8222, 8223))
// Invoice(823,List(8231))
// Invoice(824,List(8241, 8242, 8243))
// Invoice(825,List(8251, 8252, 8253, 8254, 8255))
// Invoice(826,List(8261))
// Invoice(827,List(8271))
// Invoice(828,List(8281, 8282, 8283, 8284))
// Invoice(829,List(8291))
// Invoice(830,List(8301, 8302, 8303, 8304))
// Invoice(831,List(8311))
// Invoice(832,List(8321, 8322))
// Invoice(833,List(8331))
// Invoice(834,List(8341, 8342))
// Invoice(835,List(8351, 8352, 8353, 8354, 8355))
// Invoice(836,List(8361, 8362, 8363, 8364))
// Invoice(837,List(8371))
// Invoice(838,List(8381, 8382))
// Invoice(839,List(8391, 8392, 8393, 8394, 8395))
// Invoice(840,List(8401, 8402, 8403, 8404))
// Invoice(841,List(8411, 8412))
// Invoice(842,List(8421, 8422, 8423))
// Invoice(843,List(8431, 8432, 8433))
// Invoice(844,List(8441, 8442, 8443))
// Invoice(845,List(8451, 8452, 8453, 8454))
// Invoice(846,List(8461, 8462, 8463, 8464, 8465))
// Invoice(847,List(8471, 8472, 8473))
// Invoice(848,List(8481, 8482, 8483, 8484))
// Invoice(849,List(8491, 8492, 8493, 8494, 8495))
// Invoice(850,List(8501, 8502, 8503, 8504, 8505))
// Invoice(851,List(8511, 8512, 8513, 8514, 8515))
// Invoice(852,List(8521, 8522, 8523, 8524))
// Invoice(853,List(8531, 8532))
// Invoice(854,List(8541, 8542, 8543))
// Invoice(855,List(8551, 8552, 8553, 8554))
// Invoice(856,List(8561, 8562, 8563, 8564))
// Invoice(857,List(8571, 8572, 8573, 8574, 8575))
// Invoice(858,List(8581, 8582))
// Invoice(859,List(8591, 8592))
// Invoice(860,List(8601, 8602, 8603, 8604, 8605))
// Invoice(861,List(8611, 8612, 8613))
// Invoice(862,List(8621, 8622, 8623))
// Invoice(863,List(8631, 8632, 8633))
// Invoice(864,List(8641, 8642, 8643))
// Invoice(865,List(8651))
// Invoice(866,List(8661, 8662))
// Invoice(867,List(8671, 8672, 8673))
// Invoice(868,List(8681, 8682, 8683, 8684))
// Invoice(869,List(8691, 8692))
// Invoice(870,List(8701, 8702, 8703, 8704, 8705))
// Invoice(871,List(8711, 8712, 8713, 8714))
// Invoice(872,List(8721, 8722))
// Invoice(873,List(8731))
// Invoice(874,List(8741, 8742, 8743, 8744))
// Invoice(875,List(8751, 8752, 8753, 8754))
// Invoice(876,List(8761, 8762, 8763, 8764, 8765))
// Invoice(877,List(8771, 8772))
// Invoice(878,List(8781, 8782, 8783, 8784, 8785))
// Invoice(879,List(8791, 8792, 8793, 8794))
// Invoice(880,List(8801, 8802, 8803, 8804))
// Invoice(881,List(8811, 8812, 8813))
// Invoice(882,List(8821, 8822, 8823, 8824, 8825))
// Invoice(883,List(8831, 8832))
// Invoice(884,List(8841))
// Invoice(885,List(8851, 8852, 8853, 8854))
// Invoice(886,List(8861))
// Invoice(887,List(8871, 8872, 8873, 8874))
// Invoice(888,List(8881))
// Invoice(889,List(8891))
// Invoice(890,List(8901, 8902))
// Invoice(891,List(8911))
// Invoice(892,List(8921, 8922))
// Invoice(893,List(8931, 8932))
// Invoice(894,List(8941, 8942))
// Invoice(895,List(8951, 8952, 8953, 8954))
// Invoice(896,List(8961, 8962, 8963))
// Invoice(897,List(8971, 8972, 8973, 8974, 8975))
// Invoice(898,List(8981, 8982, 8983))
// Invoice(899,List(8991, 8992, 8993, 8994, 8995))
// Invoice(900,List(9001))
// Invoice(901,List(9011, 9012))
// Invoice(902,List(9021, 9022, 9023))
// Invoice(903,List(9031, 9032, 9033, 9034))
// Invoice(904,List(9041))
// Invoice(905,List(9051, 9052, 9053))
// Invoice(906,List(9061))
// Invoice(907,List(9071))
// Invoice(908,List(9081, 9082, 9083, 9084))
// Invoice(909,List(9091, 9092, 9093, 9094))
// Invoice(910,List(9101, 9102, 9103, 9104, 9105))
// Invoice(911,List(9111, 9112, 9113, 9114))
// Invoice(912,List(9121, 9122, 9123, 9124))
// Invoice(913,List(9131, 9132))
// Invoice(914,List(9141, 9142))
// Invoice(915,List(9151, 9152, 9153, 9154, 9155))
// Invoice(916,List(9161))
// Invoice(917,List(9171))
// Invoice(918,List(9181, 9182, 9183, 9184))
// Invoice(919,List(9191, 9192, 9193))
// Invoice(920,List(9201, 9202, 9203, 9204))
// Invoice(921,List(9211, 9212, 9213, 9214))
// Invoice(922,List(9221))
// Invoice(923,List(9231, 9232, 9233, 9234))
// Invoice(924,List(9241, 9242, 9243))
// Invoice(925,List(9251))
// Invoice(926,List(9261, 9262, 9263))
// Invoice(927,List(9271, 9272, 9273, 9274))
// Invoice(928,List(9281, 9282, 9283))
// Invoice(929,List(9291))
// Invoice(930,List(9301, 9302, 9303, 9304))
// Invoice(931,List(9311, 9312, 9313, 9314, 9315))
// Invoice(932,List(9321, 9322))
// Invoice(933,List(9331, 9332, 9333, 9334, 9335))
// Invoice(934,List(9341, 9342, 9343))
// Invoice(935,List(9351))
// Invoice(936,List(9361, 9362, 9363, 9364, 9365))
// Invoice(937,List(9371, 9372, 9373, 9374))
// Invoice(938,List(9381, 9382, 9383, 9384))
// Invoice(939,List(9391, 9392, 9393, 9394, 9395))
// Invoice(940,List(9401, 9402))
// Invoice(941,List(9411, 9412, 9413, 9414, 9415))
// Invoice(942,List(9421, 9422))
// Invoice(943,List(9431, 9432, 9433))
// Invoice(944,List(9441, 9442, 9443, 9444, 9445))
// Invoice(945,List(9451, 9452, 9453))
// Invoice(946,List(9461, 9462, 9463, 9464))
// Invoice(947,List(9471, 9472, 9473))
// Invoice(948,List(9481, 9482))
// Invoice(949,List(9491, 9492, 9493, 9494))
// Invoice(950,List(9501))
// Invoice(951,List(9511, 9512, 9513, 9514, 9515))
// Invoice(952,List(9521, 9522, 9523, 9524, 9525))
// Invoice(953,List(9531, 9532, 9533, 9534))
// Invoice(954,List(9541, 9542, 9543, 9544))
// Invoice(955,List(9551, 9552, 9553))
// Invoice(956,List(9561, 9562))
// Invoice(957,List(9571, 9572, 9573))
// Invoice(958,List(9581, 9582, 9583, 9584))
// Invoice(959,List(9591, 9592, 9593, 9594))
// Invoice(960,List(9601))
// Invoice(961,List(9611, 9612, 9613, 9614))
// Invoice(962,List(9621, 9622, 9623, 9624, 9625))
// Invoice(963,List(9631, 9632, 9633, 9634))
// Invoice(964,List(9641, 9642, 9643))
// Invoice(965,List(9651, 9652, 9653, 9654, 9655))
// Invoice(966,List(9661, 9662, 9663, 9664, 9665))
// Invoice(967,List(9671, 9672, 9673))
// Invoice(968,List(9681, 9682, 9683))
// Invoice(969,List(9691, 9692))
// Invoice(970,List(9701))
// Invoice(971,List(9711, 9712))
// Invoice(972,List(9721))
// Invoice(973,List(9731, 9732, 9733))
// Invoice(974,List(9741, 9742))
// Invoice(975,List(9751, 9752, 9753, 9754, 9755))
// Invoice(976,List(9761, 9762))
// Invoice(977,List(9771))
// Invoice(978,List(9781, 9782, 9783, 9784))
// Invoice(979,List(9791))
// Invoice(980,List(9801, 9802, 9803, 9804))
// Invoice(981,List(9811, 9812, 9813, 9814, 9815))
// Invoice(982,List(9821))
// Invoice(983,List(9831, 9832, 9833, 9834))
// Invoice(984,List(9841))
// Invoice(985,List(9851, 9852))
// Invoice(986,List(9861, 9862, 9863))
// Invoice(987,List(9871, 9872))
// Invoice(988,List(9881, 9882, 9883, 9884, 9885))
// Invoice(989,List(9891, 9892, 9893))
// Invoice(990,List(9901, 9902))
// Invoice(991,List(9911))
// Invoice(992,List(9921, 9922))
// Invoice(993,List(9931, 9932, 9933, 9934))
// Invoice(994,List(9941))
// Invoice(995,List(9951, 9952))
// Invoice(996,List(9961, 9962, 9963, 9964, 9965))
// Invoice(997,List(9971, 9972, 9973))
// Invoice(998,List(9981, 9982, 9983))
// Invoice(999,List(9991, 9992, 9993, 9994, 9995))
// Invoice(1000,List(10001, 10002, 10003, 10004))
// Invoice(1001,List(10011, 10012))
// Invoice(1002,List(10021, 10022, 10023, 10024, 10025))
// Invoice(1003,List(10031, 10032, 10033, 10034, 10035))
// Invoice(1004,List(10041, 10042, 10043))
// Invoice(1005,List(10051, 10052))
// Invoice(1006,List(10061, 10062, 10063, 10064))
// Invoice(1007,List(10071))
// Invoice(1008,List(10081, 10082, 10083, 10084, 10085))
// Invoice(1009,List(10091, 10092, 10093, 10094))
// Invoice(1010,List(10101, 10102, 10103))
// Invoice(1011,List(10111, 10112, 10113, 10114))
// Invoice(1012,List(10121, 10122, 10123, 10124))
// Invoice(1013,List(10131))
// Invoice(1014,List(10141))
// Invoice(1015,List(10151, 10152, 10153, 10154))
// Invoice(1016,List(10161, 10162, 10163))
// Invoice(1017,List(10171, 10172))
// Invoice(1018,List(10181, 10182, 10183, 10184))
// Invoice(1019,List(10191, 10192, 10193, 10194, 10195))
// Invoice(1020,List(10201, 10202))
// Invoice(1021,List(10211, 10212, 10213, 10214, 10215))
// Invoice(1022,List(10221, 10222, 10223))
// Invoice(1023,List(10231))
// Invoice(1024,List(10241, 10242, 10243, 10244))
// Invoice(1025,List(10251))
// Invoice(1026,List(10261, 10262, 10263, 10264))
// Invoice(1027,List(10271, 10272, 10273, 10274, 10275))
// Invoice(1028,List(10281, 10282))
// Invoice(1029,List(10291))
// Invoice(1030,List(10301, 10302, 10303, 10304))
// Invoice(1031,List(10311))
// Invoice(1032,List(10321, 10322, 10323, 10324))
// Invoice(1033,List(10331, 10332, 10333, 10334, 10335))
// Invoice(1034,List(10341, 10342, 10343))
// Invoice(1035,List(10351, 10352, 10353))
// Invoice(1036,List(10361, 10362))
// Invoice(1037,List(10371, 10372, 10373, 10374))
// Invoice(1038,List(10381, 10382, 10383, 10384))
// Invoice(1039,List(10391, 10392))
// Invoice(1040,List(10401))
// Invoice(1041,List(10411, 10412, 10413, 10414))
// Invoice(1042,List(10421, 10422))
// Invoice(1043,List(10431))
// Invoice(1044,List(10441, 10442))
// Invoice(1045,List(10451, 10452, 10453))
// Invoice(1046,List(10461, 10462))
// Invoice(1047,List(10471, 10472, 10473))
// Invoice(1048,List(10481, 10482, 10483, 10484, 10485))
// Invoice(1049,List(10491, 10492, 10493))
// Invoice(1050,List(10501))
// Invoice(1051,List(10511, 10512, 10513, 10514, 10515))
// Invoice(1052,List(10521, 10522, 10523, 10524))
// Invoice(1053,List(10531))
// Invoice(1054,List(10541, 10542, 10543, 10544, 10545))
// Invoice(1055,List(10551, 10552))
// Invoice(1056,List(10561, 10562, 10563, 10564))
// Invoice(1057,List(10571, 10572, 10573, 10574))
// Invoice(1058,List(10581, 10582, 10583))
// Invoice(1059,List(10591, 10592, 10593, 10594, 10595))
// Invoice(1060,List(10601))
// Invoice(1061,List(10611, 10612, 10613, 10614))
// Invoice(1062,List(10621, 10622, 10623, 10624, 10625))
// Invoice(1063,List(10631, 10632))
// Invoice(1064,List(10641))
// Invoice(1065,List(10651, 10652, 10653, 10654))
// Invoice(1066,List(10661, 10662, 10663, 10664))
// Invoice(1067,List(10671, 10672, 10673, 10674, 10675))
// Invoice(1068,List(10681, 10682, 10683, 10684, 10685))
// Invoice(1069,List(10691, 10692, 10693, 10694))
// Invoice(1070,List(10701, 10702))
// Invoice(1071,List(10711, 10712, 10713, 10714))
// Invoice(1072,List(10721, 10722, 10723, 10724, 10725))
// Invoice(1073,List(10731, 10732, 10733, 10734))
// Invoice(1074,List(10741))
// Invoice(1075,List(10751))
// Invoice(1076,List(10761, 10762, 10763, 10764, 10765))
// Invoice(1077,List(10771))
// Invoice(1078,List(10781))
// Invoice(1079,List(10791, 10792))
// Invoice(1080,List(10801, 10802))
// Invoice(1081,List(10811, 10812))
// Invoice(1082,List(10821))
// Invoice(1083,List(10831, 10832))
// Invoice(1084,List(10841, 10842, 10843))
// Invoice(1085,List(10851, 10852))
// Invoice(1086,List(10861, 10862, 10863))
// Invoice(1087,List(10871, 10872, 10873))
// Invoice(1088,List(10881, 10882, 10883))
// Invoice(1089,List(10891, 10892))
// Invoice(1090,List(10901, 10902, 10903))
// Invoice(1091,List(10911))
// Invoice(1092,List(10921))
// Invoice(1093,List(10931, 10932, 10933, 10934))
// Invoice(1094,List(10941, 10942, 10943, 10944, 10945))
// Invoice(1095,List(10951))
// Invoice(1096,List(10961, 10962, 10963))
// Invoice(1097,List(10971))
// Invoice(1098,List(10981, 10982, 10983, 10984))
// Invoice(1099,List(10991, 10992, 10993, 10994))
// Invoice(1100,List(11001, 11002))
// ...
// Invoice(1623,List(16231, 16232, 16233))
// Invoice(1624,List(16241, 16242, 16243, 16244, 16245))
// Invoice(1625,List(16251, 16252, 16253, 16254, 16255))
// Invoice(1626,List(16261, 16262, 16263, 16264, 16265))
// Invoice(1627,List(16271, 16272, 16273))
// Invoice(1628,List(16281, 16282, 16283, 16284))
// Invoice(1629,List(16291, 16292, 16293))
// Invoice(1630,List(16301, 16302))
// Invoice(1631,List(16311))
// Invoice(1632,List(16321, 16322, 16323, 16324))
// Invoice(1633,List(16331, 16332, 16333))
// Invoice(1634,List(16341, 16342))
// Invoice(1635,List(16351))
// Invoice(1636,List(16361, 16362))
// Invoice(1637,List(16371, 16372, 16373))
// Invoice(1638,List(16381, 16382, 16383, 16384, 16385))
// Invoice(1639,List(16391, 16392, 16393, 16394, 16395))
// Invoice(1640,List(16401, 16402, 16403))
// Invoice(1641,List(16411, 16412))
// Invoice(1642,List(16421, 16422, 16423, 16424, 16425))
// Invoice(1643,List(16431, 16432, 16433, 16434, 16435))
// Invoice(1644,List(16441))
// Invoice(1645,List(16451, 16452))
// Invoice(1646,List(16461, 16462, 16463, 16464))
// Invoice(1647,List(16471, 16472, 16473, 16474))
// Invoice(1648,List(16481))
// Invoice(1649,List(16491, 16492, 16493))
// Invoice(1650,List(16501, 16502, 16503, 16504, 16505))
// Invoice(1651,List(16511, 16512))
// Invoice(1652,List(16521, 16522, 16523, 16524, 16525))
// Invoice(1653,List(16531, 16532))
// Invoice(1654,List(16541))
// Invoice(1655,List(16551, 16552, 16553))
// Invoice(1656,List(16561, 16562, 16563, 16564))
// Invoice(1657,List(16571, 16572, 16573, 16574, 16575))
// Invoice(1658,List(16581, 16582, 16583, 16584))
// Invoice(1659,List(16591, 16592))
// Invoice(1660,List(16601))
// Invoice(1661,List(16611, 16612))
// Invoice(1662,List(16621, 16622))
// Invoice(1663,List(16631, 16632, 16633, 16634))
// Invoice(1664,List(16641, 16642, 16643))
// Invoice(1665,List(16651, 16652, 16653, 16654))
// Invoice(1666,List(16661, 16662, 16663, 16664, 16665))
// Invoice(1667,List(16671, 16672))
// Invoice(1668,List(16681, 16682, 16683, 16684))
// Invoice(1669,List(16691, 16692, 16693))
// Invoice(1670,List(16701, 16702))
// Invoice(1671,List(16711, 16712, 16713, 16714, 16715))
// Invoice(1672,List(16721))
// Invoice(1673,List(16731, 16732, 16733))
// Invoice(1674,List(16741, 16742, 16743, 16744, 16745))
// Invoice(1675,List(16751, 16752))
// Invoice(1676,List(16761, 16762))
// Invoice(1677,List(16771, 16772, 16773))
// Invoice(1678,List(16781))
// Invoice(1679,List(16791, 16792, 16793, 16794, 16795))
// Invoice(1680,List(16801))
// Invoice(1681,List(16811, 16812, 16813))
// Invoice(1682,List(16821, 16822, 16823, 16824, 16825))
// Invoice(1683,List(16831, 16832))
// Invoice(1684,List(16841, 16842, 16843, 16844, 16845))
// Invoice(1685,List(16851, 16852))
// Invoice(1686,List(16861, 16862))
// Invoice(1687,List(16871, 16872, 16873, 16874, 16875))
// Invoice(1688,List(16881, 16882, 16883))
// Invoice(1689,List(16891, 16892, 16893, 16894, 16895))
// Invoice(1690,List(16901))
// Invoice(1691,List(16911))
// Invoice(1692,List(16921))
// Invoice(1693,List(16931, 16932, 16933, 16934, 16935))
// Invoice(1694,List(16941, 16942, 16943, 16944))
// Invoice(1695,List(16951, 16952, 16953, 16954))
// Invoice(1696,List(16961, 16962, 16963, 16964))
// Invoice(1697,List(16971, 16972, 16973))
// Invoice(1698,List(16981, 16982, 16983, 16984))
// Invoice(1699,List(16991, 16992))
// Invoice(1700,List(17001, 17002, 17003))
// Invoice(1701,List(17011, 17012, 17013))
// Invoice(1702,List(17021, 17022, 17023, 17024))
// Invoice(1703,List(17031, 17032, 17033))
// Invoice(1704,List(17041, 17042, 17043, 17044, 17045))
// Invoice(1705,List(17051, 17052))
// Invoice(1706,List(17061))
// Invoice(1707,List(17071, 17072, 17073, 17074, 17075))
// Invoice(1708,List(17081, 17082, 17083))
// Invoice(1709,List(17091, 17092, 17093, 17094))
// Invoice(1710,List(17101, 17102, 17103, 17104, 17105))
// Invoice(1711,List(17111))
// Invoice(1712,List(17121))
// Invoice(1713,List(17131, 17132))
// Invoice(1714,List(17141, 17142, 17143, 17144, 17145))
// Invoice(1715,List(17151, 17152, 17153, 17154))
// Invoice(1716,List(17161, 17162))
// Invoice(1717,List(17171, 17172, 17173))
// Invoice(1718,List(17181, 17182))
// Invoice(1719,List(17191, 17192))
// Invoice(1720,List(17201, 17202, 17203))
// Invoice(1721,List(17211))
// Invoice(1722,List(17221, 17222))
// Invoice(1723,List(17231, 17232))
// Invoice(1724,List(17241))
// Invoice(1725,List(17251, 17252))
// Invoice(1726,List(17261, 17262, 17263, 17264, 17265))
// Invoice(1727,List(17271, 17272, 17273, 17274))
// Invoice(1728,List(17281, 17282, 17283, 17284))
// Invoice(1729,List(17291, 17292, 17293, 17294, 17295))
// Invoice(1730,List(17301, 17302, 17303))
// Invoice(1731,List(17311, 17312, 17313, 17314))
// Invoice(1732,List(17321, 17322, 17323, 17324, 17325))
// Invoice(1733,List(17331, 17332, 17333, 17334, 17335))
// Invoice(1734,List(17341, 17342))
// Invoice(1735,List(17351))
// Invoice(1736,List(17361))
// Invoice(1737,List(17371, 17372, 17373, 17374, 17375))
// Invoice(1738,List(17381, 17382, 17383))
// Invoice(1739,List(17391, 17392, 17393))
// Invoice(1740,List(17401, 17402))
// Invoice(1741,List(17411, 17412, 17413, 17414, 17415))
// Invoice(1742,List(17421, 17422, 17423))
// Invoice(1743,List(17431, 17432, 17433))
// Invoice(1744,List(17441, 17442))
// Invoice(1745,List(17451, 17452, 17453, 17454))
// Invoice(1746,List(17461))
// Invoice(1747,List(17471))
// Invoice(1748,List(17481, 17482, 17483))
// Invoice(1749,List(17491))
// Invoice(1750,List(17501, 17502))
// Invoice(1751,List(17511, 17512, 17513))
// Invoice(1752,List(17521, 17522, 17523, 17524, 17525))
// Invoice(1753,List(17531, 17532))
// Invoice(1754,List(17541, 17542))
// Invoice(1755,List(17551))
// Invoice(1756,List(17561))
// Invoice(1757,List(17571, 17572, 17573))
// Invoice(1758,List(17581, 17582, 17583, 17584, 17585))
// Invoice(1759,List(17591, 17592, 17593))
// Invoice(1760,List(17601, 17602, 17603))
// Invoice(1761,List(17611, 17612, 17613, 17614))
// Invoice(1762,List(17621, 17622, 17623))
// Invoice(1763,List(17631, 17632))
// Invoice(1764,List(17641))
// Invoice(1765,List(17651, 17652, 17653, 17654))
// Invoice(1766,List(17661, 17662, 17663, 17664, 17665))
// Invoice(1767,List(17671, 17672))
// Invoice(1768,List(17681, 17682, 17683, 17684, 17685))
// Invoice(1769,List(17691))
// Invoice(1770,List(17701))
// Invoice(1771,List(17711, 17712))
// Invoice(1772,List(17721, 17722))
// Invoice(1773,List(17731, 17732, 17733, 17734))
// Invoice(1774,List(17741, 17742, 17743))
// Invoice(1775,List(17751, 17752, 17753, 17754, 17755))
// Invoice(1776,List(17761))
// Invoice(1777,List(17771, 17772, 17773, 17774, 17775))
// Invoice(1778,List(17781, 17782, 17783))
// Invoice(1779,List(17791, 17792, 17793, 17794, 17795))
// Invoice(1780,List(17801))
// Invoice(1781,List(17811, 17812, 17813, 17814))
// Invoice(1782,List(17821))
// Invoice(1783,List(17831, 17832))
// Invoice(1784,List(17841, 17842, 17843, 17844))
// Invoice(1785,List(17851))
// Invoice(1786,List(17861, 17862, 17863, 17864, 17865))
// Invoice(1787,List(17871, 17872, 17873, 17874))
// Invoice(1788,List(17881, 17882, 17883, 17884, 17885))
// Invoice(1789,List(17891, 17892, 17893, 17894, 17895))
// Invoice(1790,List(17901, 17902))
// Invoice(1791,List(17911, 17912))
// Invoice(1792,List(17921, 17922, 17923))
// Invoice(1793,List(17931))
// Invoice(1794,List(17941, 17942, 17943, 17944))
// Invoice(1795,List(17951, 17952, 17953, 17954))
// Invoice(1796,List(17961, 17962, 17963))
// Invoice(1797,List(17971))
// Invoice(1798,List(17981, 17982, 17983, 17984, 17985))
// Invoice(1799,List(17991, 17992, 17993))
// Invoice(1800,List(18001, 18002, 18003, 18004))
// Invoice(1801,List(18011, 18012))
// Invoice(1802,List(18021, 18022, 18023, 18024))
// Invoice(1803,List(18031, 18032, 18033))
// Invoice(1804,List(18041, 18042, 18043, 18044, 18045))
// Invoice(1805,List(18051, 18052, 18053, 18054))
// Invoice(1806,List(18061, 18062))
// Invoice(1807,List(18071, 18072, 18073, 18074, 18075))
// Invoice(1808,List(18081, 18082, 18083, 18084, 18085))
// Invoice(1809,List(18091, 18092, 18093))
// Invoice(1810,List(18101, 18102, 18103, 18104, 18105))
// Invoice(1811,List(18111, 18112))
// Invoice(1812,List(18121, 18122, 18123))
// Invoice(1813,List(18131, 18132, 18133, 18134))
// Invoice(1814,List(18141, 18142, 18143))
// Invoice(1815,List(18151, 18152, 18153, 18154, 18155))
// Invoice(1816,List(18161, 18162, 18163))
// Invoice(1817,List(18171, 18172))
// Invoice(1818,List(18181, 18182, 18183, 18184))
// Invoice(1819,List(18191, 18192, 18193, 18194, 18195))
// Invoice(1820,List(18201, 18202, 18203))
// Invoice(1821,List(18211, 18212, 18213, 18214, 18215))
// Invoice(1822,List(18221, 18222, 18223, 18224, 18225))
// Invoice(1823,List(18231))
// Invoice(1824,List(18241, 18242, 18243, 18244))
// Invoice(1825,List(18251, 18252, 18253, 18254, 18255))
// Invoice(1826,List(18261, 18262, 18263))
// Invoice(1827,List(18271, 18272, 18273))
// Invoice(1828,List(18281, 18282))
// Invoice(1829,List(18291, 18292))
// Invoice(1830,List(18301, 18302))
// Invoice(1831,List(18311, 18312))
// Invoice(1832,List(18321))
// Invoice(1833,List(18331, 18332))
// Invoice(1834,List(18341, 18342, 18343, 18344))
// Invoice(1835,List(18351, 18352, 18353))
// Invoice(1836,List(18361, 18362))
// Invoice(1837,List(18371, 18372, 18373))
// Invoice(1838,List(18381, 18382))
// Invoice(1839,List(18391, 18392, 18393, 18394))
// Invoice(1840,List(18401, 18402, 18403, 18404))
// Invoice(1841,List(18411, 18412, 18413))
// Invoice(1842,List(18421))
// Invoice(1843,List(18431, 18432, 18433, 18434, 18435))
// Invoice(1844,List(18441, 18442, 18443, 18444))
// Invoice(1845,List(18451, 18452))
// Invoice(1846,List(18461, 18462, 18463))
// Invoice(1847,List(18471, 18472, 18473))
// Invoice(1848,List(18481))
// Invoice(1849,List(18491))
// Invoice(1850,List(18501))
// Invoice(1851,List(18511, 18512, 18513, 18514))
// Invoice(1852,List(18521, 18522, 18523, 18524))
// Invoice(1853,List(18531, 18532, 18533))
// Invoice(1854,List(18541, 18542, 18543, 18544, 18545))
// Invoice(1855,List(18551, 18552, 18553))
// Invoice(1856,List(18561))
// Invoice(1857,List(18571, 18572, 18573, 18574))
// Invoice(1858,List(18581, 18582, 18583, 18584, 18585))
// Invoice(1859,List(18591, 18592, 18593))
// Invoice(1860,List(18601, 18602, 18603, 18604, 18605))
// Invoice(1861,List(18611, 18612))
// Invoice(1862,List(18621))
// Invoice(1863,List(18631, 18632))
// Invoice(1864,List(18641))
// Invoice(1865,List(18651, 18652, 18653, 18654, 18655))
// Invoice(1866,List(18661, 18662))
// Invoice(1867,List(18671, 18672, 18673, 18674))
// Invoice(1868,List(18681, 18682, 18683, 18684, 18685))
// Invoice(1869,List(18691, 18692))
// Invoice(1870,List(18701, 18702))
// Invoice(1871,List(18711, 18712, 18713))
// Invoice(1872,List(18721, 18722, 18723))
// Invoice(1873,List(18731))
// Invoice(1874,List(18741, 18742, 18743, 18744))
// Invoice(1875,List(18751, 18752))
// Invoice(1876,List(18761, 18762, 18763))
// Invoice(1877,List(18771, 18772))
// Invoice(1878,List(18781, 18782, 18783, 18784, 18785))
// Invoice(1879,List(18791))
// Invoice(1880,List(18801, 18802, 18803, 18804, 18805))
// Invoice(1881,List(18811, 18812))
// Invoice(1882,List(18821, 18822, 18823))
// Invoice(1883,List(18831, 18832, 18833, 18834))
// Invoice(1884,List(18841, 18842, 18843, 18844, 18845))
// Invoice(1885,List(18851, 18852, 18853, 18854, 18855))
// Invoice(1886,List(18861))
// Invoice(1887,List(18871, 18872, 18873, 18874, 18875))
// Invoice(1888,List(18881, 18882, 18883, 18884))
// Invoice(1889,List(18891, 18892, 18893))
// Invoice(1890,List(18901, 18902))
// Invoice(1891,List(18911, 18912))
// Invoice(1892,List(18921, 18922, 18923))
// Invoice(1893,List(18931, 18932, 18933, 18934, 18935))
// Invoice(1894,List(18941))
// Invoice(1895,List(18951, 18952, 18953))
// Invoice(1896,List(18961, 18962))
// Invoice(1897,List(18971, 18972, 18973, 18974))
// Invoice(1898,List(18981, 18982, 18983))
// Invoice(1899,List(18991))
// Invoice(1900,List(19001, 19002, 19003, 19004, 19005))
// Invoice(1901,List(19011, 19012, 19013, 19014))
// Invoice(1902,List(19021, 19022, 19023, 19024, 19025))
// Invoice(1903,List(19031, 19032, 19033, 19034))
// Invoice(1904,List(19041, 19042, 19043, 19044))
// Invoice(1905,List(19051, 19052, 19053, 19054))
// Invoice(1906,List(19061, 19062))
// Invoice(1907,List(19071, 19072))
// Invoice(1908,List(19081))
// Invoice(1909,List(19091))
// Invoice(1910,List(19101))
// Invoice(1911,List(19111, 19112, 19113, 19114, 19115))
// Invoice(1912,List(19121, 19122, 19123))
// Invoice(1913,List(19131, 19132, 19133, 19134, 19135))
// Invoice(1914,List(19141))
// Invoice(1915,List(19151, 19152, 19153, 19154, 19155))
// Invoice(1916,List(19161, 19162, 19163))
// Invoice(1917,List(19171))
// Invoice(1918,List(19181, 19182, 19183, 19184))
// Invoice(1919,List(19191, 19192, 19193, 19194, 19195))
// Invoice(1920,List(19201, 19202, 19203, 19204))
// Invoice(1921,List(19211, 19212))
// Invoice(1922,List(19221, 19222, 19223, 19224))
// Invoice(1923,List(19231, 19232, 19233, 19234, 19235))
// Invoice(1924,List(19241, 19242, 19243, 19244, 19245))
// Invoice(1925,List(19251, 19252))
// Invoice(1926,List(19261))
// Invoice(1927,List(19271, 19272))
// Invoice(1928,List(19281, 19282))
// Invoice(1929,List(19291))
// Invoice(1930,List(19301, 19302, 19303, 19304, 19305))
// Invoice(1931,List(19311, 19312))
// Invoice(1932,List(19321))
// Invoice(1933,List(19331, 19332))
// Invoice(1934,List(19341, 19342))
// Invoice(1935,List(19351, 19352))
// Invoice(1936,List(19361, 19362, 19363, 19364, 19365))
// Invoice(1937,List(19371))
// Invoice(1938,List(19381, 19382, 19383, 19384, 19385))
// Invoice(1939,List(19391, 19392, 19393, 19394, 19395))
// Invoice(1940,List(19401, 19402))
// Invoice(1941,List(19411, 19412, 19413))
// Invoice(1942,List(19421, 19422, 19423))
// Invoice(1943,List(19431))
// Invoice(1944,List(19441, 19442, 19443, 19444, 19445))
// Invoice(1945,List(19451))
// Invoice(1946,List(19461))
// Invoice(1947,List(19471, 19472, 19473, 19474))
// Invoice(1948,List(19481))
// Invoice(1949,List(19491))
// Invoice(1950,List(19501, 19502, 19503, 19504, 19505))
// Invoice(1951,List(19511, 19512, 19513))
// Invoice(1952,List(19521, 19522))
// Invoice(1953,List(19531, 19532, 19533, 19534))
// Invoice(1954,List(19541, 19542, 19543))
// Invoice(1955,List(19551, 19552, 19553, 19554, 19555))
// Invoice(1956,List(19561, 19562, 19563))
// Invoice(1957,List(19571, 19572))
// Invoice(1958,List(19581, 19582, 19583, 19584, 19585))
// Invoice(1959,List(19591, 19592, 19593, 19594))
// Invoice(1960,List(19601, 19602, 19603, 19604))
// Invoice(1961,List(19611, 19612, 19613))
// Invoice(1962,List(19621, 19622, 19623))
// Invoice(1963,List(19631, 19632, 19633))
// Invoice(1964,List(19641, 19642, 19643, 19644, 19645))
// Invoice(1965,List(19651))
// Invoice(1966,List(19661, 19662))
// Invoice(1967,List(19671, 19672, 19673, 19674, 19675))
// Invoice(1968,List(19681, 19682))
// Invoice(1969,List(19691, 19692, 19693, 19694))
// Invoice(1970,List(19701, 19702, 19703, 19704, 19705))
// Invoice(1971,List(19711, 19712, 19713, 19714))
// Invoice(1972,List(19721, 19722, 19723))
// Invoice(1973,List(19731, 19732, 19733, 19734))
// Invoice(1974,List(19741, 19742, 19743))
// Invoice(1975,List(19751, 19752, 19753, 19754, 19755))
// Invoice(1976,List(19761))
// Invoice(1977,List(19771, 19772))
// Invoice(1978,List(19781, 19782, 19783))
// Invoice(1979,List(19791, 19792, 19793, 19794))
// Invoice(1980,List(19801, 19802))
// Invoice(1981,List(19811))
// Invoice(1982,List(19821, 19822, 19823, 19824, 19825))
// Invoice(1983,List(19831, 19832, 19833))
// Invoice(1984,List(19841, 19842))
// Invoice(1985,List(19851, 19852, 19853, 19854))
// Invoice(1986,List(19861, 19862, 19863))
// Invoice(1987,List(19871, 19872))
// Invoice(1988,List(19881, 19882, 19883, 19884, 19885))
// Invoice(1989,List(19891))
// Invoice(1990,List(19901, 19902))
// Invoice(1991,List(19911, 19912))
// Invoice(1992,List(19921, 19922, 19923, 19924))
// Invoice(1993,List(19931, 19932, 19933, 19934))
// Invoice(1994,List(19941, 19942))
// Invoice(1995,List(19951, 19952))
// Invoice(1996,List(19961, 19962, 19963, 19964, 19965))
// Invoice(1997,List(19971))
// Invoice(1998,List(19981, 19982, 19983))
// Invoice(1999,List(19991, 19992, 19993, 19994, 19995))
// Invoice(2000,List(20001, 20002))
// defined class Employee
// defined class MediaType
// defined class Genre
// defined class Track
// defined class InvoiceItem
// defined class Invoice
// employees = Array(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// mediaTypes = Array(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// genres = Array(Genre(...
// Array(Genre(...

// %% [markdown]
// # Atelier 3
//
// ## 1/ Filtrage - Titre en fonction d'un média spécifique

// %%
val mediaFilter = List(1, 3, 5)

val filteredTracks = tracksArray.filter(track => mediaFilter.contains(track.mediaTypeId))

println(s"Nombre de tracks filtrées: ${filteredTracks.length}")
// Out:
// Nombre de tracks filtrées: 115
// mediaFilter = List(1, 3, 5)
// filteredTracks = Array(Track(1,Raging Knights from the East,5,7), Track(2,Toxic Machines in Chains,5,7), Track(3,Midnight Shadows of Death,3,15), Track(4,Eternal Prophets from Mars,3,18), Track(7,Atomic Ghosts in Flames,1,4), Track(9,Wild Wizards of the Abyss,1,18), Track(11,Sonic Giants in Flames,3,9), Track(16,Primal Giants from the East,1,11), Track(17,Screaming Outlaws in Disguise,5,23), Track(20,Golden Horizon from Mars,3,8), Track(23,Eternal Shadows of the North,1,16), Track(25,Phantom Horizon of the North,1,21), Track(26,Golden Wolves of Death,3,3), Track(28,Primal Rebels of Death,3,24), Track(29,Urban Knights of Destruction,3,8), Track(30,Sonic Giants from the Desert,1,23), Track(31,Silent Ravens in Disguise,1,13), Track(34,Et...
// Array(Track(1,Raging Knights from the East,5,7), Track(2,Toxic Machines in Chains,5,7), Track(3,Midnight Shadows of Death,3,15), Track(4,Eternal Prophets from Mars,3,18), Track(7,Atomic Ghosts in Flames,1,4), Track(9,Wild Wizards of the Abyss,1,18), Track(11,Sonic Giants in Flames,3,9), Track(16,Primal Giants from the East,1,11), Track(17,Screaming Outlaws in Disguise,5,23), Track(20,Golden Horizon from Mars,3,8), Track(23,Eternal Shadows of the North,1,16), Track(25,Phantom Horizon of the North,1,21), Track(26,Golden Wolves of Death,3,3), Track(28,Primal Rebels of Death,3,24), Track(29,Urban Knights of Destruction,3,8), Track(30,Sonic Giants from the Desert,1,23), Track(31,Silent Ravens in Disguise,1,13), Track(34,Et...

// %% [markdown]
// ## 1/ Filtrage - Commandes ayant un maximum de titres du genre 1

// %%
// Initiation InvoiceItems
val invoiceItems = invoicesArray.flatMap { invoice =>
  val itemCount = Random.nextInt(5) + 1
  val selectedTracks = Random.shuffle(tracksArray.toList).take(itemCount)
  
  selectedTracks.zipWithIndex.map { case (track, index) =>
    val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
    val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
    
    InvoiceItem(
      invoiceLineId = invoice.invoiceId * 10 + index + 1,
      invoiceId = invoice.invoiceId,
      trackId = track.trackId,
      unitPrice = unitPrice,
      quantity = quantity
    )
  }
}

def countGenre1TracksInInvoice(invoiceId: Int): Int = {
  invoiceItems
    .filter(_.invoiceId == invoiceId)
    .map(_.trackId)
    .map(trackId => tracksArray.find(_.trackId == trackId))
    .flatten
    .count(_.genreId == 1)
}

val maxGenre1Count = invoicesArray.map(invoice => countGenre1TracksInInvoice(invoice.invoiceId)).max

val invoicesWithMaxGenre1 = invoicesArray.filter(invoice => 
  countGenre1TracksInInvoice(invoice.invoiceId) == maxGenre1Count
)

println(s"Maximum de titres du genre 1 (Rock) dans une commande: $maxGenre1Count")
println(s"Nombre de commandes ayant ce maximum: ${invoicesWithMaxGenre1.length}")
// Out:
// Maximum de titres du genre 1 (Rock) dans une commande: 2
// Nombre de commandes ayant ce maximum: 13
// invoiceItems = Array(InvoiceItem(11,1,169,1.97,1), InvoiceItem(12,1,175,1.03,1), InvoiceItem(13,1,128,1.41,1), InvoiceItem(14,1,44,1.47,1), InvoiceItem(15,1,146,1.07,1), InvoiceItem(21,2,49,1.59,2), InvoiceItem(31,3,128,1.71,1), InvoiceItem(41,4,152,1.93,1), InvoiceItem(42,4,132,1.86,1), InvoiceItem(43,4,28,2.00,1), InvoiceItem(44,4,2,1.38,1), InvoiceItem(45,4,173,1.84,1), InvoiceItem(51,5,128,1.62,1), InvoiceItem(52,5,57,1.23,1), InvoiceItem(61,6,16,1.78,1), InvoiceItem(62,6,6,1.11,1), InvoiceItem(71,7,63,1.92,1), InvoiceItem(72,7,73,1.59,2), InvoiceItem(73,7,89,1.23,1), InvoiceItem(74,7,157,1.30,1), InvoiceItem(81,8,97,1.61,1), InvoiceItem(82,8,43,1.43,1), InvoiceItem(91,9,193,1.60,1), InvoiceItem(92,9,5,1.86,1), InvoiceItem(93,9,24,1.74,1), InvoiceItem(94,9,104,1....
// Array(InvoiceItem(11,1,169,1.97,1), InvoiceItem(12,1,175,1.03,1), InvoiceItem(13,1,128,1.41,1), InvoiceItem(14,1,44,1.47,1), InvoiceItem(15,1,146,1.07,1), InvoiceItem(21,2,49,1.59,2), InvoiceItem(31,3,128,1.71,1), InvoiceItem(41,4,152,1.93,1), InvoiceItem(42,4,132,1.86,1), InvoiceItem(43,4,28,2.00,1), InvoiceItem(44,4,2,1.38,1), InvoiceItem(45,4,173,1.84,1), InvoiceItem(51,5,128,1.62,1), InvoiceItem(52,5,57,1.23,1), InvoiceItem(61,6,16,1.78,1), InvoiceItem(62,6,6,1.11,1), InvoiceItem(71,7,63,1.92,1), InvoiceItem(72,7,73,1.59,2), InvoiceItem(73,7,89,1.23,1), InvoiceItem(74,7,157,1.30,1), InvoiceItem(81,8,97,1.61,1), InvoiceItem(82,8,43,1.43,1), InvoiceItem(91,9,193,1.60,1), InvoiceItem(92,9,5,1.86,1), InvoiceItem(93,9,24,1.74,1), InvoiceItem(94,9,104,1....

// %% [markdown]
// ## 2/ Agrégations - Top 5 titres en nombre de ventes

// %%
val trackSales = invoiceItems
  .groupBy(_.trackId)
  .map { case (trackId, items) =>
    trackId -> items.map(_.quantity).sum
  }

val top5Tracks = trackSales
  .toSeq
  .sortBy(-_._2)
  .take(5)
  .map { case (trackId, totalSales) =>
    val track = tracksArray.find(_.trackId == trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (track, totalSales, genreName)
  }

println("Top 5 des titres en nombre de ventes:")
top5Tracks.zipWithIndex.foreach { case ((track, sales, genre), index) =>
  println(s"${index + 1}. ${track.name} - $sales ventes (Genre: $genre)")
}
// Out:
// Top 5 des titres en nombre de ventes:
// 1. Lost Wizards in Chains - 58 ventes (Genre: Hip Hop/Rap)
// 2. Mystic Zombies of the Abyss - 55 ventes (Genre: Blues)
// 3. Stellar Titans from Mars - 55 ventes (Genre: Metal)
// 4. Crystal Demons in Chains - 53 ventes (Genre: Jazz)
// 5. Electric Echo of Tomorrow - 52 ventes (Genre: Opera)
// trackSales = Map(69 -> 32, 138 -> 41, 101 -> 26, 88 -> 23, 170 -> 50, 115 -> 33, 5 -> 42, 120 -> 39, 10 -> 32, 56 -> 42, 142 -> 29, 153 -> 27, 174 -> 40, 185 -> 50, 42 -> 44, 24 -> 32, 37 -> 48, 25 -> 42, 52 -> 21, 14 -> 29, 184 -> 39, 110 -> 30, 125 -> 47, 196 -> 40, 157 -> 39, 189 -> 43, 20 -> 35, 46 -> 42, 93 -> 31, 152 -> 32, 57 -> 37, 78 -> 23, 29 -> 41, 164 -> 51, 179 -> 28, 106 -> 38, 121 -> 38, 84 -> 52, 147 -> 29, 61 -> 31, 132 -> 35, 89 -> 46, 133 -> 39, 116 -> 27, 1 -> 21, 74 -> 33, 6 -> 41, 60 -> 28, 117 -> 28, 85 -> 35, 102 -> 39, 28 -> 31, 38 -> 46, 160 -> 34, 70 -> 42, 192 -> 38, 21 -> 42, 137 -> 40, 165 -> 44, 33 -> 32, 92 -> 37, 197 -> 41, 65 -> 34, 97 -> 46, 156 -> 47, 9 -> 43, 188 -> 34, 53 -> 30, 169 -> 32, 141 -> 35, 109 -> 4...
// Map(69 -> 32, 138 -> 41, 101 -> 26, 88 -> 23, 170 -> 50, 115 -> 33, 5 -> 42, 120 -> 39, 10 -> 32, 56 -> 42, 142 -> 29, 153 -> 27, 174 -> 40, 185 -> 50, 42 -> 44, 24 -> 32, 37 -> 48, 25 -> 42, 52 -> 21, 14 -> 29, 184 -> 39, 110 -> 30, 125 -> 47, 196 -> 40, 157 -> 39, 189 -> 43, 20 -> 35, 46 -> 42, 93 -> 31, 152 -> 32, 57 -> 37, 78 -> 23, 29 -> 41, 164 -> 51, 179 -> 28, 106 -> 38, 121 -> 38, 84 -> 52, 147 -> 29, 61 -> 31, 132 -> 35, 89 -> 46, 133 -> 39, 116 -> 27, 1 -> 21, 74 -> 33, 6 -> 41, 60 -> 28, 117 -> 28, 85 -> 35, 102 -> 39, 28 -> 31, 38 -> 46, 160 -> 34, 70 -> 42, 192 -> 38, 21 -> 42, 137 -> 40, 165 -> 44, 33 -> 32, 92 -> 37, 197 -> 41, 65 -> 34, 97 -> 46, 156 -> 47, 9 -> 43, 188 -> 34, 53 -> 30, 169 -> 32, 141 -> 35, 109 -> 4...

// %% [markdown]
// ## 2/ Agrégations - Total commande par genre

// %%
val totalByGenre = invoiceItems
  .map { item =>
    val track = tracksArray.find(_.trackId == item.trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (genreName, item.unitPrice * item.quantity, item.quantity)
  }
  .groupBy(_._1)
  .map { case (genre, items) =>
    val total = items.map(_._2).sum
    val commandes = items.map(_._3).sum
    (genre, total, commandes)
  }
  .toSeq
  .sortBy(-_._2)

println("Total des commandes par genre:")
totalByGenre.foreach { case (genre, total, commandes) =>
  println(f"$genre: $commandes commandes pour ${total}%.2f€")
}
// Out:
// Total des commandes par genre:
// Sci Fi & Fantasy: 513 commandes pour 769.52€
// Jazz: 447 commandes pour 668.26€
// Comedy: 445 commandes pour 645.22€
// Latin: 375 commandes pour 557.45€
// Heavy Metal: 366 commandes pour 543.08€
// Pop: 354 commandes pour 537.28€
// Metal: 352 commandes pour 535.33€
// Alternative & Punk: 336 commandes pour 502.89€
// Science Fiction: 333 commandes pour 493.88€
// Rock And Roll: 309 commandes pour 463.01€
// Bossa Nova: 288 commandes pour 436.40€
// Rock: 292 commandes pour 434.86€
// Easy Listening: 286 commandes pour 423.00€
// Classical: 269 commandes pour 402.31€
// R&B/Soul: 260 commandes pour 388.36€
// Hip Hop/Rap: 254 commandes pour 386.67€
// Opera: 253 commandes pour 382.33€
// World: 251 commandes pour 381.66€
// Blues: 242 commandes pour 375.27€
// Alternative: 216 commandes pour 324.73€
// Reggae: 183 commandes pour 273.35€
// Drama: 171 commandes pour 262.98€
// Electronica/Dance: 151 commandes pour 224.60€
// TV Shows: 145 commandes pour 217.53€
// Soundtrack: 126 commandes pour 187.62€
// totalByGenre = List((Sci Fi & Fantasy,769.52,513), (Jazz,668.26,447), (Comedy,645.22,445), (Latin,557.45,375), (Heavy Metal,543.08,366), (Pop,537.28,354), (Metal,535.33,352), (Alternative & Punk,502.89,336), (Science Fiction,493.88,333), (Rock And Roll,463.01,309), (Bossa Nova,436.40,288), (Rock,434.86,292), (Easy Listening,423.00,286), (Classical,402.31,269), (R&B/Soul,388.36,260), (Hip Hop/Rap,386.67,254), (Opera,382.33,253), (World,381.66,251), (Blues,375.27,242), (Alternative,324.73,216), (Reggae,273.35,183), (Drama,262.98,171), (Electronica/Dance,224.60,151), (TV Shows,217.53,145), (Soundtrack,187.62,126))
// List((Sci Fi & Fantasy,769.52,513), (Jazz,668.26,447), (Comedy,645.22,445), (Latin,557.45,375), (Heavy Metal,543.08,366), (Pop,537.28,354), (Metal,535.33,352), (Alternative & Punk,502.89,336), (Science Fiction,493.88,333), (Rock And Roll,463.01,309), (Bossa Nova,436.40,288), (Rock,434.86,292), (Easy Listening,423.00,286), (Classical,402.31,269), (R&B/Soul,388.36,260), (Hip Hop/Rap,386.67,254), (Opera,382.33,253), (World,381.66,251), (Blues,375.27,242), (Alternative,324.73,216), (Reggae,273.35,183), (Drama,262.98,171), (Electronica/Dance,224.60,151), (TV Shows,217.53,145), (Soundtrack,187.62,126))

// %% [markdown]
// ## 3/ Traitement récursif - Fonction récursive pour trouver le plus haut responsable

// %%
def findTopManager(employeeId: Int): Employee = {
  val employee = employees.find(_.employeeId == employeeId)
    .getOrElse(throw new IllegalArgumentException(s"Employee $employeeId not found"))
  
  if (employee.reportsTo == 0) {
    employee
  } else {
    findTopManager(employee.reportsTo)
  }
}

println("Tests de la fonction récursive findTopManager:")
println()

employees.foreach { employee =>
  val topManager = findTopManager(employee.employeeId)
  val hierarchy = buildHierarchyPath(employee.employeeId)
  
  println(s"${employee.firstName} ${employee.lastName} (${employee.title})")
  println(s"  → Plus haut responsable: ${topManager.firstName} ${topManager.lastName} (${topManager.title})")
  println(s"  → Chemin hiérarchique: $hierarchy")
  println()
}

def buildHierarchyPath(employeeId: Int): String = {
  def buildPath(currentId: Int, path: List[String]): List[String] = {
    val employee = employees.find(_.employeeId == currentId).get
    val employeeName = s"${employee.firstName} ${employee.lastName}"

    if (employee.reportsTo == 0) {
      path :+ employeeName
    } else {
      buildPath(employee.reportsTo, path :+ employeeName)
    }
  }

  buildPath(employeeId, List()).mkString(" → ")
}
// Out:
// findTopManager: (employeeId: Int)Employee
// buildHierarchyPath: (employeeId: Int)String
// Tests de la fonction récursive findTopManager:
//
// Andrew Adams (General Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Andrew Adams
//
// Nancy Edwards (Sales Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Nancy Edwards → Andrew Adams
//
// Jane Peacock (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Jane Peacock → Nancy Edwards → Andrew Adams
//
// Margaret Park (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Margaret Park → Nancy Edwards → Andrew Adams
//
// Steve Johnson (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Steve Johnson → Nancy Edwards → Andrew Adams
//
// Michael Mitchell (IT Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Michael Mitchell → Andrew Adams
//
// Robert King (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Robert King → Michael Mitchell → Andrew Adams
//
// Laura Callahan (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Laura Callahan → Michael Mitchell → Andrew Adams

// %% [markdown]
// # ATELIER 4 - Transposition sur Spark
//
// ## At. 4 - Etape 1/ Manipulation des données générées

// %%
// Creation RDD
// tracks ; invoices ; invoiceItems ; mediaFilter => générés pendant l'atelier 3
val tracksRDD = sc.parallelize(tracks)
val invoiceItemsRDD = sc.parallelize(invoiceItems)
val invoicesRDD = sc.parallelize(invoices)

val filteredTracksRDD = tracksRDD.filter(track => mediaFilter.contains(track.mediaTypeId))

// COMMANDES TITRES ROCK
val trackGenreRDD = tracksRDD.map(track => (track.trackId, track.genreId))
val invoiceTrackRDD = invoiceItemsRDD.map(item => (item.trackId, item.invoiceId))
val invoiceGenreCountRDD = invoiceTrackRDD
  .join(trackGenreRDD) 
  .filter(_._2._2 == 1)  // 1 = Genre Rock
  .map { case (trackId, (invoiceId, genreId)) => (invoiceId, 1) }
  .reduceByKey(_ + _) 

val maxGenre1CountRDD = invoiceGenreCountRDD.map(_._2).max()
val invoicesWithMaxGenre1RDD = invoiceGenreCountRDD.filter(_._2 == maxGenre1CountRDD)

println(s"Maximum de titres Rock dans une commande: $maxGenre1CountRDD")
println(s"Nombre de commandes ayant ce maximum: ${invoicesWithMaxGenre1RDD.count()}\n")


// TOP 5 Titres
val trackSalesRDD = invoiceItemsRDD
  .map(item => (item.trackId, item.quantity))
  .reduceByKey(_ + _)

val top5TracksRDD = trackSalesRDD
  .map { case (trackId, totalSales) => (totalSales, trackId) }
  .sortByKey(false)
  .map { case (totalSales, trackId) => (trackId, totalSales) }
  .take(5)
  
top5TracksRDD.zipWithIndex.foreach { case ((trackId, sales), index) =>
  val track = tracksRDD.filter(_.trackId == trackId).first()
  val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
  println(s"${index + 1}. ${track.name} - $sales ventes (Genre: $genreName)")
}
println("\n")

// COMMANDES PAR GENRE
val trackGenreMapRDD = tracksRDD.map(track => (track.trackId, track.genreId))

val totalByGenreRDD = invoiceItemsRDD
  .map(item => (item.trackId, item.unitPrice * item.quantity))
  .join(trackGenreMapRDD)
  .map { case (trackId, (montant, genreId)) => (genreId, montant) }
  .reduceByKey(_ + _)
  .map { case (genreId, total) =>
    val genreName = genres.find(_.genreId == genreId).map(_.name).getOrElse("Unknown")
    (genreName, total)
  }
  .sortBy(-_._2)

totalByGenreRDD.collect().foreach { case (genre, total) =>
  println(f"$genre: ${total}%.2f€")
}

val totalRevenueRDD = totalByGenreRDD.map(_._2).sum()
println(f"Chiffre d'affaires total: ${totalRevenueRDD}%.2f€")
// Out:
// Maximum de titres Rock dans une commande: 2
// Nombre de commandes ayant ce maximum: 13
//
// 1. Lost Wizards in Chains - 58 ventes (Genre: Hip Hop/Rap)
// 2. Mystic Zombies of the Abyss - 55 ventes (Genre: Blues)
// 3. Stellar Titans from Mars - 55 ventes (Genre: Metal)
// 4. Crystal Demons in Chains - 53 ventes (Genre: Jazz)
// 5. Electric Echo of Tomorrow - 52 ventes (Genre: Opera)
//
//
// Sci Fi & Fantasy: 769.52€
// Jazz: 668.26€
// Comedy: 645.22€
// Latin: 557.45€
// Heavy Metal: 543.08€
// Pop: 537.28€
// Metal: 535.33€
// Alternative & Punk: 502.89€
// Science Fiction: 493.88€
// Rock And Roll: 463.01€
// Bossa Nova: 436.40€
// Rock: 434.86€
// Easy Listening: 423.00€
// Classical: 402.31€
// R&B/Soul: 388.36€
// Hip Hop/Rap: 386.67€
// Opera: 382.33€
// World: 381.66€
// Blues: 375.27€
// Alternative: 324.73€
// Reggae: 273.35€
// Drama: 262.98€
// Electronica/Dance: 224.60€
// TV Shows: 217.53€
// Soundtrack: 187.62€
// Chiffre d'affaires total: 10817.59€
// tracksRDD = ParallelCollectionRDD[82] at parallelize at <console>:44
// invoiceItemsRDD = ParallelCollectionRDD[83] at parallelize at <console>:45
// invoicesRDD = ParallelCollectionRDD[84] at parallelize at <console>:46
// filteredTracksRDD = MapPartitionsRDD[85] at filter at <console>:48
// trackGenreRDD = MapPartitionsRDD[86] at map at <console>:51
// invoiceTrackRDD = MapPartitionsRDD[87] at map at <console>:52
// invoiceGenreCountRDD = ShuffledRDD[93] at reduceByKey at <console>:57
// maxGenre1CountRDD = 2
// invoicesWithMaxGenre1RDD: org.apache.spark...
// 2

// %% [markdown]
// ## Etape 2/ Analyse des transformation

// %%
println("\n1. PIPELINE FILTRAGE MÉDIA:")
println(filteredTracksRDD.toDebugString)

val trackSalesAnalysisRDD = invoiceItemsRDD
  .map(item => (item.trackId, item.quantity))
  .reduceByKey(_ + _)
  .map { case (trackId, totalSales) => (totalSales, trackId) }
  .sortByKey(false)

println("\n2. PIPELINE TOP 5 TRACKS:")
println(trackSalesAnalysisRDD.toDebugString)

val genreAnalysisRDD = invoiceItemsRDD
  .map(item => (item.trackId, item.unitPrice * item.quantity))
  .join(trackGenreMapRDD)
  .map { case (trackId, (montant, genreId)) => (genreId, montant) }
  .reduceByKey(_ + _)

println("\n3. PIPELINE TOTAL PAR GENRE:")
println(genreAnalysisRDD.toDebugString)

println("\n4. PIPELINE COMPTAGE ROCK:")
println(invoiceGenreCountRDD.toDebugString)
// Out:
// 1. PIPELINE FILTRAGE MÉDIA:
// (2) MapPartitionsRDD[85] at filter at <console>:48 []
//  |  ParallelCollectionRDD[82] at parallelize at <console>:44 []
//
// 2. PIPELINE TOP 5 TRACKS:
// (2) ShuffledRDD[164] at sortByKey at <console>:37 []
//  +-(2) MapPartitionsRDD[161] at map at <console>:36 []
//     |  ShuffledRDD[160] at reduceByKey at <console>:35 []
//     +-(2) MapPartitionsRDD[159] at map at <console>:34 []
//        |  ParallelCollectionRDD[83] at parallelize at <console>:45 []
//
// 3. PIPELINE TOTAL PAR GENRE:
// (2) ShuffledRDD[170] at reduceByKey at <console>:46 []
//  +-(2) MapPartitionsRDD[169] at map at <console>:45 []
//     |  MapPartitionsRDD[168] at join at <console>:44 []
//     |  MapPartitionsRDD[167] at join at <console>:44 []
//     |  CoGroupedRDD[166] at join at <console>:44 []
//     +-(2) MapPartitionsRDD[165] at map at <console>:43 []
//     |  |  ParallelCollectionRDD[83] at parallelize at <console>:45 []
//     +-(2) MapPartitionsRDD[108] at map at <console>:85 []
//        |  ParallelCollectionRDD[82] at parallelize at <console>:44 []
//
// 4. PIPELINE COMPTAGE ROCK:
// (2) ShuffledRDD[93] at reduceByKey at <console>:57 []
//  +-(2) MapPartitionsRDD[92] at map at <console>:56 []
//     |  MapPartitionsRDD[91] at filter at <console>:55 []
//     |  MapPartitionsRDD[90] at join at <console>:54 []
//     |  MapPartitionsRDD[89] at join at <console>:54 []
//     |  CoGroupedRDD[88] at join at <console>:54 []
//     +-(2) MapPartitionsRDD[87] at map at <console>:52 []
//     |  |  ParallelCollectionRDD[83] at parallelize at <console>:45 []
//     +-(2) MapPartitionsRDD[86] at map at <console>:51 []
//        |  ParallelCollectionRDD[82] at parallelize at <console>:44 []
// trackSalesAnalysisRDD = ShuffledRDD[164] at sortByKey at <console>:37
// genreAnalysisRDD = ShuffledRDD[170] at reduceByKey at <console>:46
// ShuffledRDD[170] at reduceByKey at <console>:46

// %% [markdown]
// On peut voir grace au toDebugString que les pipelines avec du shuffle sont :
// - PIPELINE TOP 5 TRACKS
// - PIPELINE TOTAL PAR GENRE
// - PIPELINE COMPTAGE ROCK

// %% [markdown]
// ## Etape 3/ Chargement des CSV
