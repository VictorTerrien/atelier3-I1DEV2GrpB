// %% [markdown]
// # ATELIER 2

// %%
import scala.util.Random

case class Employee(
  employeeId: Int,
  lastName: String, 
  firstName: String,
  title: String,
  reportsTo: Int
)

case class MediaType(
  mediaTypeId: Int,
  name: String
)

case class Genre(
  genreId: Int,
  name: String
)

case class Track(
  trackId: Int,
  name: String,
  mediaTypeId: Int,
  genreId: Int
)

case class InvoiceItem(
  invoiceLineId: Int,
  invoiceId: Int,
  trackId: Int,
  unitPrice: BigDecimal,
  quantity: Int,
)

case class Invoice(
  invoiceId: Int,
  items: List[Int]
)


val employees = Array(
  Employee(1, "Adams", "Andrew", "General Manager", 0),
  Employee(2, "Edwards", "Nancy", "Sales Manager", 1), 
  Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  Employee(7, "King", "Robert", "IT Staff", 6),
  Employee(8, "Callahan", "Laura", "IT Staff", 6)
)

val mediaTypes = Array(
  MediaType(1, "MPEG audio file"),
  MediaType(2, "Protected AAC audio file"), 
  MediaType(3, "Protected MPEG-4 video file"),
  MediaType(4, "Purchased AAC audio file"),
  MediaType(5, "AAC audio file")
)

val genres = Array(
  Genre(1, "Rock"), 
  Genre(2, "Jazz"),
  Genre(3, "Metal"), 
  Genre(4, "Alternative & Punk"),
  Genre(5, "Rock And Roll"),
  Genre(6, "Blues"),
  Genre(7, "Latin"),
  Genre(8, "Reggae"),
  Genre(9, "Pop"),
  Genre(10, "Soundtrack"),
  Genre(11, "Bossa Nova"),
  Genre(12, "Easy Listening"),
  Genre(13, "Heavy Metal"), 
  Genre(14, "R&B/Soul"),
  Genre(15, "Electronica/Dance"),
  Genre(16, "World"), 
  Genre(17, "Hip Hop/Rap"),
  Genre(18, "Science Fiction"),
  Genre(19, "TV Shows"), 
  Genre(20, "Sci Fi & Fantasy"),
  Genre(21, "Drama"), 
  Genre(22, "Comedy"), 
  Genre(23, "Alternative"),
  Genre(24, "Classical"), 
  Genre(25, "Opera")
)

val adjectives = Array(
  "Cosmic", "Electric", "Velvet", "Mystic", "Atomic", "Phantom", "Silent", 
  "Savage", "Eternal", "Digital", "Lost", "Sacred", "Wild", "Urban", "Golden", 
  "Crystal", "Liquid", "Toxic", "Neon", "Crimson", "Stellar", "Raging", 
  "Arctic", "Sonic", "Primal", "Midnight", "Screaming", "Infinite", "Royal", "Lunar"
)

val nouns = Array(
  "Echo", "Giants", "Wolves", "Horizon", "Empire", "Void", "Thunder", "Dragons", 
  "Saints", "Kings", "Ghosts", "Ravens", "Pirates", "Heroes", "Rebels", "Demons", 
  "Machines", "Angels", "Knights", "Lions", "Shadows", "Zombies", "Wizards", 
  "Killers", "Titans", "Outlaws", "Rebels", "Prophets", "Bandits", "Warriors"
)

val complements = Array(
  "of Doom", "in Chains", "from Mars", "of the North", "of Death", "in Disguise", 
  "of the Night", "from Hell", "of Tomorrow", "in Flames", "of the Deep", 
  "from Beyond", "of Destruction", "in Shadow", "from the Sky", "of the Abyss", 
  "in Exile", "from the East", "of Eternity", "from the Desert", "of the Underground"
)

object Track {
  def generateTrack(trackId: Int): Track = {
    val randomGenre = genres(Random.nextInt(genres.length))
    val randomMediaType = mediaTypes(Random.nextInt(mediaTypes.length))
    
    val adjective = adjectives(Random.nextInt(adjectives.length))
    val noun = nouns(Random.nextInt(nouns.length))
    val complement = complements(Random.nextInt(complements.length))
    
    val trackName = s"$adjective $noun $complement"
    
    Track(trackId, trackName, randomMediaType.mediaTypeId, randomGenre.genreId)
  }
}


object Invoice {
  def generateInvoice(invoiceId: Int, availableTracks: Array[Track]): Invoice = {
    val itemCount = Random.nextInt(5) + 1
    val selectedTracks = Random.shuffle(availableTracks.toList).take(itemCount)
    
    val items = selectedTracks.zipWithIndex.map { case (track, index) =>
      val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
      val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
      
      InvoiceItem(
        invoiceLineId = invoiceId * 10 + index + 1,
        invoiceId = invoiceId,
        trackId = track.trackId,
        unitPrice = unitPrice,
        quantity = quantity,
      )
    }
    
    Invoice(invoiceId, items.map(_.invoiceLineId))
  }
}

val tracks = for(index <- 1 to 200) yield Track.generateTrack(index)
val tracksArray = tracks.toArray
println("Liste des tracks :")
tracksArray.foreach(println)


val invoices = for(index <- 1 to 2000) yield Invoice.generateInvoice(index, tracksArray)
val invoicesArray = invoices.toArray
println("\nListe des invoices :")
invoicesArray.foreach(println)
// Out:
// Liste des tracks :
// Track(1,Velvet Rebels from the East,4,17)
// Track(2,Crystal Rebels from the Desert,3,13)
// Track(3,Primal Rebels from Hell,4,1)
// Track(4,Stellar Machines in Shadow,3,6)
// Track(5,Velvet Prophets of the Deep,2,17)
// Track(6,Electric Zombies from Mars,4,13)
// Track(7,Arctic Wizards from Beyond,5,19)
// Track(8,Primal Rebels of the Underground,2,12)
// Track(9,Toxic Bandits of Doom,3,20)
// Track(10,Atomic Saints from the East,4,9)
// Track(11,Wild Rebels from the Desert,1,5)
// Track(12,Toxic Horizon of Tomorrow,2,25)
// Track(13,Sacred Lions from the East,4,3)
// Track(14,Royal Titans in Exile,1,6)
// Track(15,Crystal Warriors in Chains,5,25)
// Track(16,Stellar Pirates of Tomorrow,1,7)
// Track(17,Sacred Saints of the North,3,3)
// Track(18,Toxic Thunder from Hell,2,21)
// Track(19,Sonic Prophets of the Abyss,2,1)
// Track(20,Infinite Wolves in Shadow,2,12)
// Track(21,Primal Zombies of Tomorrow,4,16)
// Track(22,Electric Zombies from Mars,5,2)
// Track(23,Velvet Rebels from the Desert,2,2)
// Track(24,Liquid Heroes of Destruction,1,9)
// Track(25,Crimson Heroes from the East,4,2)
// Track(26,Stellar Rebels of Eternity,5,18)
// Track(27,Neon Lions of Doom,3,18)
// Track(28,Raging Lions in Chains,4,14)
// Track(29,Eternal Killers from the East,2,19)
// Track(30,Sonic Giants in Disguise,1,17)
// Track(31,Eternal Shadows from the Sky,1,20)
// Track(32,Cosmic Wolves from the Desert,2,3)
// Track(33,Atomic Bandits from Mars,5,22)
// Track(34,Atomic Giants of Tomorrow,4,22)
// Track(35,Wild Dragons of Doom,1,16)
// Track(36,Liquid Outlaws from Beyond,4,9)
// Track(37,Mystic Prophets in Shadow,5,18)
// Track(38,Wild Lions in Exile,2,10)
// Track(39,Crimson Warriors of the Deep,5,24)
// Track(40,Infinite Warriors of Eternity,4,4)
// Track(41,Screaming Saints from the East,1,23)
// Track(42,Velvet Rebels of Eternity,4,8)
// Track(43,Raging Rebels in Chains,1,3)
// Track(44,Eternal Giants of Tomorrow,1,23)
// Track(45,Eternal Angels of the North,1,6)
// Track(46,Crimson Echo of Doom,2,15)
// Track(47,Stellar Wolves in Chains,2,5)
// Track(48,Sacred Rebels of Eternity,3,10)
// Track(49,Silent Warriors from Mars,2,22)
// Track(50,Primal Killers in Shadow,4,3)
// Track(51,Phantom Wizards from the Desert,5,17)
// Track(52,Phantom Giants of the Deep,4,4)
// Track(53,Silent Bandits from Mars,4,4)
// Track(54,Midnight Angels of Death,1,24)
// Track(55,Wild Titans of the Abyss,3,16)
// Track(56,Liquid Empire in Chains,1,10)
// Track(57,Crystal Rebels in Flames,1,16)
// Track(58,Toxic Ghosts of Destruction,5,15)
// Track(59,Atomic Lions of Doom,3,13)
// Track(60,Infinite Echo of the Underground,5,2)
// Track(61,Wild Machines in Flames,3,19)
// Track(62,Raging Wizards in Exile,3,3)
// Track(63,Sonic Horizon of the Abyss,1,10)
// Track(64,Mystic Machines in Chains,3,24)
// Track(65,Screaming Wizards from Mars,1,6)
// Track(66,Sonic Ghosts of the Abyss,4,6)
// Track(67,Mystic Heroes of Doom,1,6)
// Track(68,Silent Angels of Destruction,5,15)
// Track(69,Primal Bandits of Death,1,9)
// Track(70,Silent Bandits from Beyond,2,18)
// Track(71,Velvet Dragons from Hell,1,7)
// Track(72,Savage Outlaws of Doom,1,1)
// Track(73,Midnight Ravens from the Sky,4,6)
// Track(74,Neon Lions of Eternity,4,12)
// Track(75,Neon Heroes in Chains,1,8)
// Track(76,Stellar Dragons of the North,5,10)
// Track(77,Primal Angels of Tomorrow,4,23)
// Track(78,Primal Angels in Chains,2,19)
// Track(79,Cosmic Lions in Chains,4,13)
// Track(80,Royal Killers from the Desert,5,17)
// Track(81,Crystal Bandits from the Desert,3,10)
// Track(82,Silent Heroes in Shadow,3,15)
// Track(83,Crystal Saints in Exile,2,8)
// Track(84,Raging Ghosts of the North,1,7)
// Track(85,Velvet Thunder from the East,1,6)
// Track(86,Lost Rebels of Tomorrow,2,22)
// Track(87,Wild Demons in Disguise,2,4)
// Track(88,Eternal Demons of the Abyss,4,5)
// Track(89,Neon Dragons of Destruction,1,11)
// Track(90,Sonic Wizards of Doom,2,24)
// Track(91,Silent Kings of Eternity,3,18)
// Track(92,Phantom Machines of the Night,2,3)
// Track(93,Wild Empire from Mars,2,19)
// Track(94,Primal Dragons of Death,4,1)
// Track(95,Infinite Empire from the Desert,5,5)
// Track(96,Liquid Kings from the Desert,2,9)
// Track(97,Liquid Dragons in Chains,5,24)
// Track(98,Arctic Empire of the Abyss,5,9)
// Track(99,Screaming Ghosts from the East,1,5)
// Track(100,Velvet Echo from the Sky,1,1)
// Track(101,Urban Titans from Beyond,4,20)
// Track(102,Crystal Angels of Eternity,2,17)
// Track(103,Arctic Outlaws from the Desert,3,18)
// Track(104,Infinite Titans from the Sky,3,2)
// Track(105,Raging Rebels in Exile,4,2)
// Track(106,Silent Saints from the Desert,5,16)
// Track(107,Primal Demons from the Desert,2,14)
// Track(108,Eternal Outlaws from the Sky,2,1)
// Track(109,Cosmic Bandits of the North,4,15)
// Track(110,Urban Void of the Night,2,13)
// Track(111,Mystic Lions of Doom,2,24)
// Track(112,Sonic Thunder from Mars,4,2)
// Track(113,Midnight Heroes in Exile,1,4)
// Track(114,Mystic Wolves of Death,1,8)
// Track(115,Arctic Killers of the Night,1,12)
// Track(116,Sonic Pirates from Hell,3,16)
// Track(117,Arctic Kings in Flames,4,19)
// Track(118,Crystal Prophets of Death,5,13)
// Track(119,Stellar Rebels of the Underground,5,4)
// Track(120,Primal Dragons of the Underground,2,9)
// Track(121,Eternal Heroes in Chains,4,18)
// Track(122,Golden Ravens in Flames,1,20)
// Track(123,Wild Shadows from the East,4,13)
// Track(124,Silent Rebels in Flames,2,8)
// Track(125,Neon Outlaws from Mars,2,11)
// Track(126,Crimson Shadows of the Night,5,20)
// Track(127,Savage Ravens from Hell,2,22)
// Track(128,Electric Shadows of the North,3,16)
// Track(129,Raging Knights of the Deep,5,5)
// Track(130,Primal Dragons of the Deep,1,24)
// Track(131,Digital Bandits of Death,3,22)
// Track(132,Liquid Void from Beyond,3,6)
// Track(133,Mystic Dragons from Beyond,3,15)
// Track(134,Liquid Wolves from Hell,2,1)
// Track(135,Lost Ravens in Chains,2,3)
// Track(136,Urban Shadows of Doom,4,24)
// Track(137,Infinite Angels of Tomorrow,4,6)
// Track(138,Eternal Machines in Disguise,5,22)
// Track(139,Crimson Thunder of Tomorrow,2,11)
// Track(140,Urban Pirates in Chains,2,14)
// Track(141,Cosmic Wolves from the Sky,1,7)
// Track(142,Raging Shadows of the Deep,1,1)
// Track(143,Royal Ghosts of the North,3,4)
// Track(144,Lunar Prophets of the Night,4,5)
// Track(145,Midnight Zombies of the Night,4,10)
// Track(146,Crimson Wolves of Tomorrow,3,23)
// Track(147,Royal Kings from the Sky,1,3)
// Track(148,Electric Machines of the Underground,4,8)
// Track(149,Atomic Angels in Chains,2,18)
// Track(150,Infinite Bandits of Death,3,2)
// Track(151,Stellar Empire in Shadow,5,19)
// Track(152,Sacred Wizards of the Abyss,4,20)
// Track(153,Screaming Zombies of the Night,2,20)
// Track(154,Raging Killers of the Abyss,5,7)
// Track(155,Arctic Shadows of the North,2,1)
// Track(156,Crimson Warriors of Destruction,3,18)
// Track(157,Arctic Giants of Doom,3,13)
// Track(158,Electric Lions from Hell,4,25)
// Track(159,Cosmic Titans of Death,2,3)
// Track(160,Crystal Angels of the Abyss,3,15)
// Track(161,Electric Rebels in Flames,4,18)
// Track(162,Toxic Shadows in Chains,5,23)
// Track(163,Urban Horizon of Destruction,1,15)
// Track(164,Urban Warriors of Destruction,4,7)
// Track(165,Cosmic Giants in Chains,4,25)
// Track(166,Mystic Angels of Doom,4,4)
// Track(167,Lost Lions from Mars,3,13)
// Track(168,Crimson Echo of the Deep,2,17)
// Track(169,Midnight Kings of the Underground,4,11)
// Track(170,Stellar Thunder in Exile,3,11)
// Track(171,Digital Kings of Death,5,24)
// Track(172,Phantom Rebels of Death,4,7)
// Track(173,Wild Echo in Chains,5,8)
// Track(174,Silent Empire in Shadow,3,4)
// Track(175,Urban Knights in Exile,3,7)
// Track(176,Cosmic Titans in Disguise,5,23)
// Track(177,Wild Titans of Tomorrow,3,16)
// Track(178,Midnight Zombies of Tomorrow,4,4)
// Track(179,Savage Dragons from Mars,2,4)
// Track(180,Digital Titans of the Night,5,23)
// Track(181,Velvet Rebels in Shadow,2,2)
// Track(182,Mystic Zombies of the Underground,1,17)
// Track(183,Royal Heroes in Shadow,2,6)
// Track(184,Silent Pirates of Tomorrow,3,4)
// Track(185,Crimson Rebels in Flames,2,19)
// Track(186,Cosmic Outlaws of the North,2,16)
// Track(187,Velvet Kings in Chains,5,16)
// Track(188,Arctic Lions in Chains,2,15)
// Track(189,Crystal Bandits from Mars,3,10)
// Track(190,Raging Ravens in Shadow,2,11)
// Track(191,Digital Bandits from Mars,1,16)
// Track(192,Lunar Bandits in Flames,1,1)
// Track(193,Raging Wolves of the Night,4,5)
// Track(194,Toxic Ravens of Doom,3,14)
// Track(195,Liquid Wizards from the Sky,3,10)
// Track(196,Neon Kings of the Abyss,1,19)
// Track(197,Stellar Rebels in Disguise,5,19)
// Track(198,Sonic Shadows in Flames,3,12)
// Track(199,Savage Prophets from Hell,3,12)
// Track(200,Sacred Heroes in Disguise,4,23)
//
// Liste des invoices :
// Invoice(1,List(11, 12, 13))
// Invoice(2,List(21, 22, 23))
// Invoice(3,List(31, 32, 33))
// Invoice(4,List(41, 42))
// Invoice(5,List(51, 52, 53))
// Invoice(6,List(61, 62, 63, 64, 65))
// Invoice(7,List(71, 72))
// Invoice(8,List(81))
// Invoice(9,List(91, 92, 93))
// Invoice(10,List(101))
// Invoice(11,List(111))
// Invoice(12,List(121, 122, 123, 124, 125))
// Invoice(13,List(131, 132, 133, 134))
// Invoice(14,List(141))
// Invoice(15,List(151, 152, 153, 154, 155))
// Invoice(16,List(161, 162, 163))
// Invoice(17,List(171, 172, 173))
// Invoice(18,List(181, 182))
// Invoice(19,List(191))
// Invoice(20,List(201))
// Invoice(21,List(211, 212, 213, 214))
// Invoice(22,List(221, 222))
// Invoice(23,List(231))
// Invoice(24,List(241, 242, 243, 244))
// Invoice(25,List(251, 252, 253, 254, 255))
// Invoice(26,List(261, 262))
// Invoice(27,List(271, 272, 273))
// Invoice(28,List(281, 282, 283, 284))
// Invoice(29,List(291, 292, 293, 294))
// Invoice(30,List(301))
// Invoice(31,List(311, 312, 313, 314, 315))
// Invoice(32,List(321, 322, 323, 324, 325))
// Invoice(33,List(331, 332))
// Invoice(34,List(341, 342, 343))
// Invoice(35,List(351, 352, 353))
// Invoice(36,List(361, 362, 363, 364, 365))
// Invoice(37,List(371, 372, 373))
// Invoice(38,List(381, 382, 383))
// Invoice(39,List(391, 392, 393, 394, 395))
// Invoice(40,List(401, 402, 403, 404, 405))
// Invoice(41,List(411, 412, 413, 414))
// Invoice(42,List(421, 422))
// Invoice(43,List(431, 432, 433, 434))
// Invoice(44,List(441, 442, 443))
// Invoice(45,List(451, 452, 453, 454, 455))
// Invoice(46,List(461))
// Invoice(47,List(471, 472, 473))
// Invoice(48,List(481, 482, 483, 484))
// Invoice(49,List(491, 492))
// Invoice(50,List(501, 502, 503, 504, 505))
// Invoice(51,List(511, 512, 513))
// Invoice(52,List(521, 522))
// Invoice(53,List(531, 532, 533))
// Invoice(54,List(541, 542, 543, 544, 545))
// Invoice(55,List(551, 552, 553, 554))
// Invoice(56,List(561, 562, 563, 564))
// Invoice(57,List(571, 572))
// Invoice(58,List(581))
// Invoice(59,List(591, 592))
// Invoice(60,List(601))
// Invoice(61,List(611, 612))
// Invoice(62,List(621, 622, 623, 624))
// Invoice(63,List(631))
// Invoice(64,List(641, 642))
// Invoice(65,List(651, 652, 653))
// Invoice(66,List(661))
// Invoice(67,List(671))
// Invoice(68,List(681, 682))
// Invoice(69,List(691, 692, 693, 694))
// Invoice(70,List(701, 702, 703))
// Invoice(71,List(711, 712, 713, 714))
// Invoice(72,List(721, 722))
// Invoice(73,List(731, 732))
// Invoice(74,List(741, 742, 743, 744, 745))
// Invoice(75,List(751, 752, 753))
// Invoice(76,List(761, 762, 763, 764, 765))
// Invoice(77,List(771, 772))
// Invoice(78,List(781, 782, 783))
// Invoice(79,List(791, 792, 793))
// Invoice(80,List(801, 802, 803, 804, 805))
// Invoice(81,List(811, 812, 813, 814))
// Invoice(82,List(821))
// Invoice(83,List(831, 832, 833))
// Invoice(84,List(841, 842, 843))
// Invoice(85,List(851))
// Invoice(86,List(861, 862, 863, 864))
// Invoice(87,List(871, 872, 873, 874))
// Invoice(88,List(881, 882))
// Invoice(89,List(891, 892, 893))
// Invoice(90,List(901, 902, 903, 904))
// Invoice(91,List(911, 912))
// Invoice(92,List(921, 922))
// Invoice(93,List(931, 932, 933))
// Invoice(94,List(941))
// Invoice(95,List(951))
// Invoice(96,List(961))
// Invoice(97,List(971, 972, 973, 974))
// Invoice(98,List(981, 982))
// Invoice(99,List(991))
// Invoice(100,List(1001, 1002, 1003, 1004))
// Invoice(101,List(1011, 1012, 1013, 1014))
// Invoice(102,List(1021, 1022, 1023))
// Invoice(103,List(1031, 1032))
// Invoice(104,List(1041, 1042, 1043, 1044, 1045))
// Invoice(105,List(1051, 1052))
// Invoice(106,List(1061, 1062, 1063, 1064, 1065))
// Invoice(107,List(1071))
// Invoice(108,List(1081, 1082, 1083, 1084))
// Invoice(109,List(1091, 1092, 1093, 1094))
// Invoice(110,List(1101))
// Invoice(111,List(1111, 1112))
// Invoice(112,List(1121, 1122, 1123))
// Invoice(113,List(1131, 1132, 1133, 1134, 1135))
// Invoice(114,List(1141, 1142, 1143, 1144, 1145))
// Invoice(115,List(1151, 1152, 1153, 1154))
// Invoice(116,List(1161))
// Invoice(117,List(1171, 1172, 1173, 1174))
// Invoice(118,List(1181, 1182, 1183, 1184, 1185))
// Invoice(119,List(1191, 1192, 1193, 1194, 1195))
// Invoice(120,List(1201, 1202))
// Invoice(121,List(1211, 1212))
// Invoice(122,List(1221, 1222, 1223, 1224))
// Invoice(123,List(1231, 1232))
// Invoice(124,List(1241, 1242, 1243))
// Invoice(125,List(1251, 1252))
// Invoice(126,List(1261))
// Invoice(127,List(1271))
// Invoice(128,List(1281, 1282, 1283))
// Invoice(129,List(1291))
// Invoice(130,List(1301, 1302, 1303))
// Invoice(131,List(1311, 1312, 1313, 1314))
// Invoice(132,List(1321))
// Invoice(133,List(1331, 1332, 1333, 1334, 1335))
// Invoice(134,List(1341, 1342))
// Invoice(135,List(1351, 1352, 1353))
// Invoice(136,List(1361, 1362))
// Invoice(137,List(1371, 1372))
// Invoice(138,List(1381, 1382, 1383))
// Invoice(139,List(1391))
// Invoice(140,List(1401, 1402))
// Invoice(141,List(1411, 1412))
// Invoice(142,List(1421, 1422, 1423))
// Invoice(143,List(1431, 1432, 1433, 1434, 1435))
// Invoice(144,List(1441, 1442, 1443, 1444))
// Invoice(145,List(1451, 1452, 1453, 1454, 1455))
// Invoice(146,List(1461, 1462))
// Invoice(147,List(1471))
// Invoice(148,List(1481, 1482, 1483, 1484, 1485))
// Invoice(149,List(1491))
// Invoice(150,List(1501))
// Invoice(151,List(1511, 1512, 1513))
// Invoice(152,List(1521, 1522, 1523, 1524))
// Invoice(153,List(1531, 1532))
// Invoice(154,List(1541, 1542, 1543))
// Invoice(155,List(1551, 1552, 1553, 1554, 1555))
// Invoice(156,List(1561, 1562, 1563, 1564, 1565))
// Invoice(157,List(1571))
// Invoice(158,List(1581, 1582, 1583, 1584))
// Invoice(159,List(1591))
// Invoice(160,List(1601, 1602, 1603, 1604))
// Invoice(161,List(1611, 1612))
// Invoice(162,List(1621, 1622, 1623))
// Invoice(163,List(1631))
// Invoice(164,List(1641, 1642, 1643))
// Invoice(165,List(1651, 1652, 1653, 1654))
// Invoice(166,List(1661, 1662, 1663))
// Invoice(167,List(1671, 1672))
// Invoice(168,List(1681, 1682, 1683, 1684, 1685))
// Invoice(169,List(1691, 1692, 1693, 1694, 1695))
// Invoice(170,List(1701, 1702, 1703, 1704))
// Invoice(171,List(1711, 1712))
// Invoice(172,List(1721, 1722, 1723, 1724))
// Invoice(173,List(1731, 1732, 1733, 1734, 1735))
// Invoice(174,List(1741, 1742, 1743, 1744))
// Invoice(175,List(1751, 1752, 1753))
// Invoice(176,List(1761, 1762))
// Invoice(177,List(1771, 1772))
// Invoice(178,List(1781, 1782, 1783))
// Invoice(179,List(1791, 1792, 1793, 1794))
// Invoice(180,List(1801))
// Invoice(181,List(1811, 1812))
// Invoice(182,List(1821))
// Invoice(183,List(1831, 1832))
// Invoice(184,List(1841, 1842, 1843, 1844, 1845))
// Invoice(185,List(1851, 1852, 1853, 1854))
// Invoice(186,List(1861, 1862, 1863, 1864))
// Invoice(187,List(1871))
// Invoice(188,List(1881, 1882, 1883))
// Invoice(189,List(1891, 1892, 1893))
// Invoice(190,List(1901, 1902, 1903, 1904))
// Invoice(191,List(1911, 1912, 1913, 1914))
// Invoice(192,List(1921))
// Invoice(193,List(1931))
// Invoice(194,List(1941, 1942, 1943))
// Invoice(195,List(1951))
// Invoice(196,List(1961, 1962, 1963))
// Invoice(197,List(1971, 1972, 1973))
// Invoice(198,List(1981, 1982, 1983, 1984))
// Invoice(199,List(1991, 1992, 1993, 1994))
// Invoice(200,List(2001, 2002, 2003, 2004, 2005))
// Invoice(201,List(2011, 2012, 2013))
// Invoice(202,List(2021, 2022, 2023, 2024, 2025))
// Invoice(203,List(2031, 2032))
// Invoice(204,List(2041, 2042))
// Invoice(205,List(2051, 2052))
// Invoice(206,List(2061, 2062, 2063))
// Invoice(207,List(2071, 2072, 2073, 2074))
// Invoice(208,List(2081, 2082))
// Invoice(209,List(2091, 2092, 2093, 2094, 2095))
// Invoice(210,List(2101, 2102, 2103, 2104, 2105))
// Invoice(211,List(2111, 2112, 2113, 2114, 2115))
// Invoice(212,List(2121, 2122))
// Invoice(213,List(2131))
// Invoice(214,List(2141))
// Invoice(215,List(2151, 2152, 2153, 2154))
// Invoice(216,List(2161, 2162, 2163, 2164, 2165))
// Invoice(217,List(2171, 2172, 2173, 2174, 2175))
// Invoice(218,List(2181, 2182))
// Invoice(219,List(2191, 2192, 2193, 2194, 2195))
// Invoice(220,List(2201, 2202))
// Invoice(221,List(2211, 2212))
// Invoice(222,List(2221, 2222, 2223, 2224))
// Invoice(223,List(2231))
// Invoice(224,List(2241, 2242, 2243, 2244, 2245))
// Invoice(225,List(2251, 2252, 2253))
// Invoice(226,List(2261, 2262, 2263))
// Invoice(227,List(2271, 2272, 2273))
// Invoice(228,List(2281))
// Invoice(229,List(2291, 2292, 2293, 2294, 2295))
// Invoice(230,List(2301, 2302, 2303, 2304))
// Invoice(231,List(2311, 2312, 2313, 2314, 2315))
// Invoice(232,List(2321))
// Invoice(233,List(2331))
// Invoice(234,List(2341))
// Invoice(235,List(2351, 2352, 2353, 2354))
// Invoice(236,List(2361))
// Invoice(237,List(2371, 2372, 2373, 2374))
// Invoice(238,List(2381, 2382, 2383))
// Invoice(239,List(2391, 2392))
// Invoice(240,List(2401, 2402, 2403, 2404, 2405))
// Invoice(241,List(2411, 2412, 2413))
// Invoice(242,List(2421, 2422, 2423, 2424, 2425))
// Invoice(243,List(2431, 2432, 2433, 2434))
// Invoice(244,List(2441))
// Invoice(245,List(2451))
// Invoice(246,List(2461, 2462, 2463))
// Invoice(247,List(2471, 2472, 2473, 2474, 2475))
// Invoice(248,List(2481))
// Invoice(249,List(2491, 2492, 2493, 2494))
// Invoice(250,List(2501, 2502, 2503, 2504))
// Invoice(251,List(2511, 2512, 2513))
// Invoice(252,List(2521, 2522, 2523, 2524, 2525))
// Invoice(253,List(2531))
// Invoice(254,List(2541))
// Invoice(255,List(2551, 2552))
// Invoice(256,List(2561, 2562, 2563, 2564, 2565))
// Invoice(257,List(2571, 2572))
// Invoice(258,List(2581, 2582))
// Invoice(259,List(2591, 2592, 2593, 2594))
// Invoice(260,List(2601, 2602, 2603, 2604))
// Invoice(261,List(2611))
// Invoice(262,List(2621, 2622))
// Invoice(263,List(2631, 2632))
// Invoice(264,List(2641, 2642, 2643, 2644, 2645))
// Invoice(265,List(2651, 2652, 2653))
// Invoice(266,List(2661))
// Invoice(267,List(2671, 2672))
// Invoice(268,List(2681, 2682, 2683))
// Invoice(269,List(2691, 2692))
// Invoice(270,List(2701))
// Invoice(271,List(2711, 2712, 2713, 2714))
// Invoice(272,List(2721, 2722, 2723, 2724))
// Invoice(273,List(2731, 2732, 2733))
// Invoice(274,List(2741))
// Invoice(275,List(2751, 2752, 2753, 2754))
// Invoice(276,List(2761, 2762, 2763, 2764, 2765))
// Invoice(277,List(2771, 2772, 2773, 2774, 2775))
// Invoice(278,List(2781, 2782))
// Invoice(279,List(2791, 2792, 2793))
// Invoice(280,List(2801, 2802, 2803, 2804, 2805))
// Invoice(281,List(2811, 2812, 2813, 2814))
// Invoice(282,List(2821, 2822, 2823))
// Invoice(283,List(2831, 2832, 2833, 2834, 2835))
// Invoice(284,List(2841, 2842, 2843))
// Invoice(285,List(2851, 2852, 2853, 2854, 2855))
// Invoice(286,List(2861, 2862, 2863, 2864, 2865))
// Invoice(287,List(2871))
// Invoice(288,List(2881, 2882, 2883))
// Invoice(289,List(2891, 2892))
// Invoice(290,List(2901, 2902, 2903, 2904))
// Invoice(291,List(2911, 2912, 2913, 2914, 2915))
// Invoice(292,List(2921, 2922))
// Invoice(293,List(2931, 2932))
// Invoice(294,List(2941, 2942, 2943))
// Invoice(295,List(2951, 2952, 2953, 2954))
// Invoice(296,List(2961, 2962))
// Invoice(297,List(2971, 2972))
// Invoice(298,List(2981, 2982))
// Invoice(299,List(2991, 2992, 2993))
// Invoice(300,List(3001, 3002))
// Invoice(301,List(3011, 3012))
// Invoice(302,List(3021, 3022))
// Invoice(303,List(3031, 3032, 3033))
// Invoice(304,List(3041, 3042, 3043, 3044, 3045))
// Invoice(305,List(3051, 3052, 3053))
// Invoice(306,List(3061, 3062))
// Invoice(307,List(3071, 3072, 3073, 3074))
// Invoice(308,List(3081))
// Invoice(309,List(3091, 3092, 3093, 3094))
// Invoice(310,List(3101))
// Invoice(311,List(3111, 3112, 3113, 3114))
// Invoice(312,List(3121, 3122, 3123, 3124, 3125))
// Invoice(313,List(3131, 3132, 3133))
// Invoice(314,List(3141, 3142))
// Invoice(315,List(3151))
// Invoice(316,List(3161, 3162))
// Invoice(317,List(3171))
// Invoice(318,List(3181, 3182))
// Invoice(319,List(3191))
// Invoice(320,List(3201, 3202, 3203, 3204, 3205))
// Invoice(321,List(3211, 3212))
// Invoice(322,List(3221))
// Invoice(323,List(3231, 3232, 3233, 3234, 3235))
// Invoice(324,List(3241, 3242, 3243, 3244, 3245))
// Invoice(325,List(3251, 3252))
// Invoice(326,List(3261, 3262, 3263))
// Invoice(327,List(3271, 3272, 3273, 3274, 3275))
// Invoice(328,List(3281))
// Invoice(329,List(3291))
// Invoice(330,List(3301, 3302, 3303))
// Invoice(331,List(3311, 3312, 3313, 3314, 3315))
// Invoice(332,List(3321, 3322, 3323))
// Invoice(333,List(3331))
// Invoice(334,List(3341, 3342))
// Invoice(335,List(3351, 3352))
// Invoice(336,List(3361, 3362, 3363, 3364, 3365))
// Invoice(337,List(3371, 3372, 3373, 3374))
// Invoice(338,List(3381, 3382, 3383, 3384, 3385))
// Invoice(339,List(3391, 3392, 3393, 3394, 3395))
// Invoice(340,List(3401, 3402, 3403, 3404))
// Invoice(341,List(3411, 3412, 3413, 3414, 3415))
// Invoice(342,List(3421, 3422, 3423, 3424))
// Invoice(343,List(3431, 3432, 3433))
// Invoice(344,List(3441, 3442, 3443, 3444))
// Invoice(345,List(3451))
// Invoice(346,List(3461, 3462, 3463))
// Invoice(347,List(3471))
// Invoice(348,List(3481, 3482, 3483))
// Invoice(349,List(3491))
// Invoice(350,List(3501, 3502, 3503, 3504))
// Invoice(351,List(3511, 3512, 3513, 3514))
// Invoice(352,List(3521))
// Invoice(353,List(3531))
// Invoice(354,List(3541, 3542))
// Invoice(355,List(3551, 3552))
// Invoice(356,List(3561, 3562, 3563))
// Invoice(357,List(3571, 3572, 3573, 3574, 3575))
// Invoice(358,List(3581, 3582))
// Invoice(359,List(3591, 3592, 3593, 3594))
// Invoice(360,List(3601, 3602, 3603, 3604, 3605))
// Invoice(361,List(3611, 3612, 3613))
// Invoice(362,List(3621, 3622, 3623, 3624))
// Invoice(363,List(3631, 3632))
// Invoice(364,List(3641, 3642, 3643, 3644))
// Invoice(365,List(3651, 3652, 3653, 3654))
// Invoice(366,List(3661, 3662, 3663))
// Invoice(367,List(3671, 3672, 3673, 3674))
// Invoice(368,List(3681, 3682))
// Invoice(369,List(3691, 3692, 3693, 3694))
// Invoice(370,List(3701, 3702))
// Invoice(371,List(3711, 3712, 3713, 3714, 3715))
// Invoice(372,List(3721, 3722, 3723))
// Invoice(373,List(3731, 3732, 3733, 3734, 3735))
// Invoice(374,List(3741, 3742, 3743, 3744))
// Invoice(375,List(3751, 3752, 3753))
// Invoice(376,List(3761, 3762, 3763, 3764))
// Invoice(377,List(3771, 3772, 3773, 3774))
// Invoice(378,List(3781, 3782, 3783, 3784))
// Invoice(379,List(3791, 3792))
// Invoice(380,List(3801))
// Invoice(381,List(3811, 3812))
// Invoice(382,List(3821, 3822, 3823, 3824))
// Invoice(383,List(3831, 3832, 3833, 3834, 3835))
// Invoice(384,List(3841, 3842, 3843, 3844, 3845))
// Invoice(385,List(3851))
// Invoice(386,List(3861, 3862, 3863, 3864))
// Invoice(387,List(3871, 3872, 3873, 3874))
// Invoice(388,List(3881))
// Invoice(389,List(3891, 3892, 3893))
// Invoice(390,List(3901, 3902, 3903, 3904, 3905))
// Invoice(391,List(3911, 3912, 3913, 3914, 3915))
// Invoice(392,List(3921, 3922, 3923))
// Invoice(393,List(3931))
// Invoice(394,List(3941))
// Invoice(395,List(3951, 3952, 3953, 3954, 3955))
// Invoice(396,List(3961, 3962, 3963, 3964))
// Invoice(397,List(3971, 3972, 3973, 3974))
// Invoice(398,List(3981, 3982, 3983, 3984))
// Invoice(399,List(3991))
// Invoice(400,List(4001, 4002, 4003))
// Invoice(401,List(4011, 4012, 4013, 4014))
// Invoice(402,List(4021, 4022, 4023, 4024, 4025))
// Invoice(403,List(4031))
// Invoice(404,List(4041, 4042, 4043))
// Invoice(405,List(4051, 4052))
// Invoice(406,List(4061))
// Invoice(407,List(4071, 4072))
// Invoice(408,List(4081, 4082, 4083, 4084, 4085))
// Invoice(409,List(4091))
// Invoice(410,List(4101, 4102, 4103, 4104, 4105))
// Invoice(411,List(4111))
// Invoice(412,List(4121, 4122, 4123, 4124, 4125))
// Invoice(413,List(4131))
// Invoice(414,List(4141, 4142, 4143, 4144))
// Invoice(415,List(4151, 4152))
// Invoice(416,List(4161, 4162, 4163, 4164))
// Invoice(417,List(4171))
// Invoice(418,List(4181, 4182, 4183))
// Invoice(419,List(4191, 4192, 4193))
// Invoice(420,List(4201, 4202, 4203))
// Invoice(421,List(4211, 4212, 4213))
// Invoice(422,List(4221))
// Invoice(423,List(4231, 4232, 4233))
// Invoice(424,List(4241, 4242))
// Invoice(425,List(4251, 4252, 4253, 4254))
// Invoice(426,List(4261, 4262, 4263, 4264, 4265))
// Invoice(427,List(4271, 4272))
// Invoice(428,List(4281))
// Invoice(429,List(4291, 4292, 4293))
// Invoice(430,List(4301, 4302))
// Invoice(431,List(4311, 4312, 4313))
// Invoice(432,List(4321, 4322, 4323))
// Invoice(433,List(4331, 4332, 4333, 4334, 4335))
// Invoice(434,List(4341))
// Invoice(435,List(4351))
// Invoice(436,List(4361, 4362))
// Invoice(437,List(4371, 4372))
// Invoice(438,List(4381, 4382, 4383, 4384))
// Invoice(439,List(4391, 4392))
// Invoice(440,List(4401, 4402, 4403, 4404, 4405))
// Invoice(441,List(4411, 4412))
// Invoice(442,List(4421, 4422, 4423))
// Invoice(443,List(4431, 4432, 4433, 4434))
// Invoice(444,List(4441, 4442, 4443, 4444))
// Invoice(445,List(4451, 4452, 4453, 4454))
// Invoice(446,List(4461))
// Invoice(447,List(4471, 4472, 4473))
// Invoice(448,List(4481, 4482, 4483, 4484))
// Invoice(449,List(4491, 4492, 4493, 4494))
// Invoice(450,List(4501, 4502))
// Invoice(451,List(4511, 4512))
// Invoice(452,List(4521, 4522, 4523, 4524, 4525))
// Invoice(453,List(4531))
// Invoice(454,List(4541, 4542, 4543))
// Invoice(455,List(4551))
// Invoice(456,List(4561))
// Invoice(457,List(4571, 4572, 4573, 4574, 4575))
// Invoice(458,List(4581, 4582, 4583, 4584, 4585))
// Invoice(459,List(4591, 4592, 4593))
// Invoice(460,List(4601))
// Invoice(461,List(4611, 4612, 4613, 4614, 4615))
// Invoice(462,List(4621, 4622))
// Invoice(463,List(4631, 4632, 4633, 4634, 4635))
// Invoice(464,List(4641, 4642, 4643))
// Invoice(465,List(4651))
// Invoice(466,List(4661, 4662, 4663, 4664, 4665))
// Invoice(467,List(4671, 4672))
// Invoice(468,List(4681, 4682, 4683))
// Invoice(469,List(4691, 4692, 4693, 4694))
// Invoice(470,List(4701, 4702))
// Invoice(471,List(4711, 4712, 4713))
// Invoice(472,List(4721, 4722, 4723, 4724, 4725))
// Invoice(473,List(4731, 4732, 4733, 4734, 4735))
// Invoice(474,List(4741, 4742))
// Invoice(475,List(4751, 4752, 4753, 4754))
// Invoice(476,List(4761, 4762))
// Invoice(477,List(4771, 4772, 4773))
// Invoice(478,List(4781))
// Invoice(479,List(4791, 4792, 4793))
// Invoice(480,List(4801, 4802, 4803, 4804, 4805))
// Invoice(481,List(4811, 4812, 4813, 4814, 4815))
// Invoice(482,List(4821, 4822))
// Invoice(483,List(4831, 4832, 4833))
// Invoice(484,List(4841, 4842))
// Invoice(485,List(4851))
// Invoice(486,List(4861, 4862, 4863, 4864, 4865))
// Invoice(487,List(4871, 4872, 4873, 4874, 4875))
// Invoice(488,List(4881, 4882, 4883, 4884))
// Invoice(489,List(4891, 4892, 4893, 4894, 4895))
// Invoice(490,List(4901))
// Invoice(491,List(4911, 4912, 4913, 4914, 4915))
// Invoice(492,List(4921, 4922, 4923))
// Invoice(493,List(4931, 4932, 4933, 4934))
// Invoice(494,List(4941, 4942, 4943, 4944, 4945))
// Invoice(495,List(4951, 4952, 4953, 4954, 4955))
// Invoice(496,List(4961))
// Invoice(497,List(4971, 4972, 4973))
// Invoice(498,List(4981, 4982))
// Invoice(499,List(4991, 4992, 4993, 4994))
// Invoice(500,List(5001))
// Invoice(501,List(5011, 5012, 5013, 5014))
// Invoice(502,List(5021, 5022, 5023))
// Invoice(503,List(5031, 5032))
// Invoice(504,List(5041, 5042))
// Invoice(505,List(5051, 5052))
// Invoice(506,List(5061, 5062))
// Invoice(507,List(5071, 5072, 5073, 5074))
// Invoice(508,List(5081, 5082, 5083, 5084, 5085))
// Invoice(509,List(5091, 5092, 5093, 5094))
// Invoice(510,List(5101, 5102, 5103, 5104))
// Invoice(511,List(5111))
// Invoice(512,List(5121, 5122, 5123, 5124))
// Invoice(513,List(5131, 5132, 5133))
// Invoice(514,List(5141, 5142, 5143))
// Invoice(515,List(5151, 5152, 5153))
// Invoice(516,List(5161, 5162, 5163))
// Invoice(517,List(5171, 5172, 5173, 5174, 5175))
// Invoice(518,List(5181, 5182, 5183, 5184, 5185))
// Invoice(519,List(5191))
// Invoice(520,List(5201, 5202))
// Invoice(521,List(5211))
// Invoice(522,List(5221, 5222, 5223))
// Invoice(523,List(5231, 5232, 5233, 5234, 5235))
// Invoice(524,List(5241, 5242, 5243, 5244, 5245))
// Invoice(525,List(5251, 5252, 5253, 5254))
// Invoice(526,List(5261))
// Invoice(527,List(5271, 5272, 5273, 5274, 5275))
// Invoice(528,List(5281))
// Invoice(529,List(5291, 5292, 5293))
// Invoice(530,List(5301))
// Invoice(531,List(5311, 5312, 5313))
// Invoice(532,List(5321, 5322, 5323, 5324, 5325))
// Invoice(533,List(5331, 5332, 5333, 5334))
// Invoice(534,List(5341, 5342, 5343, 5344, 5345))
// Invoice(535,List(5351, 5352, 5353))
// Invoice(536,List(5361))
// Invoice(537,List(5371, 5372))
// Invoice(538,List(5381, 5382, 5383, 5384))
// Invoice(539,List(5391, 5392, 5393, 5394, 5395))
// Invoice(540,List(5401, 5402))
// Invoice(541,List(5411, 5412, 5413, 5414, 5415))
// Invoice(542,List(5421, 5422, 5423, 5424, 5425))
// Invoice(543,List(5431, 5432, 5433))
// Invoice(544,List(5441))
// Invoice(545,List(5451, 5452, 5453, 5454))
// Invoice(546,List(5461, 5462, 5463, 5464, 5465))
// Invoice(547,List(5471, 5472, 5473, 5474))
// Invoice(548,List(5481, 5482, 5483, 5484))
// Invoice(549,List(5491, 5492, 5493, 5494, 5495))
// Invoice(550,List(5501, 5502))
// Invoice(551,List(5511, 5512))
// Invoice(552,List(5521, 5522, 5523))
// Invoice(553,List(5531, 5532))
// Invoice(554,List(5541, 5542))
// Invoice(555,List(5551))
// Invoice(556,List(5561, 5562, 5563))
// Invoice(557,List(5571, 5572, 5573, 5574, 5575))
// Invoice(558,List(5581, 5582))
// Invoice(559,List(5591, 5592, 5593, 5594))
// Invoice(560,List(5601, 5602, 5603, 5604, 5605))
// Invoice(561,List(5611, 5612, 5613, 5614))
// Invoice(562,List(5621, 5622))
// Invoice(563,List(5631, 5632, 5633, 5634))
// Invoice(564,List(5641, 5642, 5643))
// Invoice(565,List(5651, 5652))
// Invoice(566,List(5661, 5662, 5663, 5664, 5665))
// Invoice(567,List(5671, 5672))
// Invoice(568,List(5681, 5682))
// Invoice(569,List(5691, 5692, 5693, 5694, 5695))
// Invoice(570,List(5701))
// Invoice(571,List(5711, 5712, 5713, 5714))
// Invoice(572,List(5721, 5722, 5723, 5724))
// Invoice(573,List(5731))
// Invoice(574,List(5741, 5742, 5743))
// Invoice(575,List(5751, 5752, 5753, 5754))
// Invoice(576,List(5761, 5762))
// Invoice(577,List(5771, 5772))
// Invoice(578,List(5781))
// Invoice(579,List(5791, 5792))
// Invoice(580,List(5801, 5802, 5803, 5804, 5805))
// Invoice(581,List(5811, 5812, 5813, 5814))
// Invoice(582,List(5821, 5822, 5823))
// Invoice(583,List(5831, 5832, 5833, 5834, 5835))
// Invoice(584,List(5841))
// Invoice(585,List(5851, 5852, 5853, 5854))
// Invoice(586,List(5861, 5862, 5863, 5864))
// Invoice(587,List(5871))
// Invoice(588,List(5881, 5882, 5883))
// Invoice(589,List(5891, 5892, 5893, 5894))
// Invoice(590,List(5901))
// Invoice(591,List(5911))
// Invoice(592,List(5921, 5922))
// Invoice(593,List(5931, 5932, 5933, 5934))
// Invoice(594,List(5941, 5942, 5943, 5944, 5945))
// Invoice(595,List(5951, 5952, 5953, 5954))
// Invoice(596,List(5961, 5962, 5963, 5964))
// Invoice(597,List(5971, 5972))
// Invoice(598,List(5981, 5982, 5983, 5984, 5985))
// Invoice(599,List(5991, 5992, 5993))
// Invoice(600,List(6001, 6002))
// Invoice(601,List(6011, 6012, 6013, 6014))
// Invoice(602,List(6021, 6022, 6023, 6024, 6025))
// Invoice(603,List(6031, 6032, 6033, 6034, 6035))
// Invoice(604,List(6041, 6042, 6043))
// Invoice(605,List(6051, 6052))
// Invoice(606,List(6061, 6062, 6063))
// Invoice(607,List(6071))
// Invoice(608,List(6081, 6082))
// Invoice(609,List(6091, 6092, 6093, 6094, 6095))
// Invoice(610,List(6101))
// Invoice(611,List(6111, 6112))
// Invoice(612,List(6121, 6122, 6123, 6124, 6125))
// Invoice(613,List(6131, 6132))
// Invoice(614,List(6141))
// Invoice(615,List(6151, 6152, 6153))
// Invoice(616,List(6161, 6162, 6163, 6164))
// Invoice(617,List(6171, 6172, 6173, 6174))
// Invoice(618,List(6181, 6182, 6183))
// Invoice(619,List(6191, 6192, 6193, 6194, 6195))
// Invoice(620,List(6201, 6202, 6203, 6204, 6205))
// Invoice(621,List(6211, 6212, 6213, 6214, 6215))
// Invoice(622,List(6221, 6222))
// Invoice(623,List(6231, 6232, 6233, 6234, 6235))
// Invoice(624,List(6241, 6242))
// Invoice(625,List(6251, 6252, 6253))
// Invoice(626,List(6261, 6262, 6263))
// Invoice(627,List(6271, 6272, 6273, 6274, 6275))
// Invoice(628,List(6281, 6282, 6283))
// Invoice(629,List(6291, 6292, 6293, 6294))
// Invoice(630,List(6301, 6302))
// Invoice(631,List(6311))
// Invoice(632,List(6321))
// Invoice(633,List(6331))
// Invoice(634,List(6341, 6342))
// Invoice(635,List(6351, 6352, 6353))
// Invoice(636,List(6361, 6362))
// Invoice(637,List(6371, 6372, 6373))
// Invoice(638,List(6381, 6382, 6383, 6384))
// Invoice(639,List(6391))
// Invoice(640,List(6401, 6402, 6403))
// Invoice(641,List(6411, 6412))
// Invoice(642,List(6421, 6422))
// Invoice(643,List(6431, 6432, 6433, 6434))
// Invoice(644,List(6441, 6442))
// Invoice(645,List(6451, 6452, 6453))
// Invoice(646,List(6461, 6462, 6463))
// Invoice(647,List(6471, 6472, 6473))
// Invoice(648,List(6481))
// Invoice(649,List(6491, 6492, 6493))
// Invoice(650,List(6501, 6502, 6503, 6504))
// Invoice(651,List(6511))
// Invoice(652,List(6521, 6522, 6523))
// Invoice(653,List(6531, 6532, 6533, 6534, 6535))
// Invoice(654,List(6541, 6542, 6543))
// Invoice(655,List(6551, 6552, 6553))
// Invoice(656,List(6561))
// Invoice(657,List(6571))
// Invoice(658,List(6581, 6582, 6583))
// Invoice(659,List(6591, 6592, 6593))
// Invoice(660,List(6601, 6602, 6603, 6604))
// Invoice(661,List(6611, 6612, 6613))
// Invoice(662,List(6621))
// Invoice(663,List(6631, 6632, 6633))
// Invoice(664,List(6641))
// Invoice(665,List(6651, 6652, 6653))
// Invoice(666,List(6661))
// Invoice(667,List(6671))
// Invoice(668,List(6681, 6682, 6683))
// Invoice(669,List(6691, 6692, 6693, 6694, 6695))
// Invoice(670,List(6701))
// Invoice(671,List(6711, 6712, 6713, 6714, 6715))
// Invoice(672,List(6721, 6722, 6723, 6724))
// Invoice(673,List(6731, 6732, 6733, 6734))
// Invoice(674,List(6741, 6742, 6743))
// Invoice(675,List(6751, 6752, 6753, 6754, 6755))
// Invoice(676,List(6761))
// Invoice(677,List(6771, 6772))
// Invoice(678,List(6781, 6782, 6783))
// Invoice(679,List(6791, 6792, 6793))
// Invoice(680,List(6801))
// Invoice(681,List(6811, 6812, 6813, 6814))
// Invoice(682,List(6821, 6822, 6823, 6824))
// Invoice(683,List(6831, 6832, 6833, 6834))
// Invoice(684,List(6841, 6842))
// Invoice(685,List(6851))
// Invoice(686,List(6861, 6862, 6863))
// Invoice(687,List(6871, 6872, 6873, 6874))
// Invoice(688,List(6881, 6882, 6883))
// Invoice(689,List(6891, 6892, 6893))
// Invoice(690,List(6901, 6902, 6903))
// Invoice(691,List(6911, 6912, 6913, 6914, 6915))
// Invoice(692,List(6921, 6922, 6923))
// Invoice(693,List(6931, 6932, 6933, 6934))
// Invoice(694,List(6941, 6942, 6943, 6944, 6945))
// Invoice(695,List(6951, 6952, 6953, 6954, 6955))
// Invoice(696,List(6961, 6962, 6963, 6964))
// Invoice(697,List(6971, 6972, 6973, 6974, 6975))
// Invoice(698,List(6981, 6982))
// Invoice(699,List(6991, 6992))
// Invoice(700,List(7001, 7002, 7003))
// Invoice(701,List(7011, 7012, 7013, 7014))
// Invoice(702,List(7021, 7022))
// Invoice(703,List(7031, 7032, 7033, 7034))
// Invoice(704,List(7041, 7042))
// Invoice(705,List(7051, 7052))
// Invoice(706,List(7061, 7062, 7063))
// Invoice(707,List(7071, 7072))
// Invoice(708,List(7081, 7082, 7083, 7084))
// Invoice(709,List(7091, 7092, 7093, 7094))
// Invoice(710,List(7101, 7102))
// Invoice(711,List(7111))
// Invoice(712,List(7121, 7122, 7123, 7124))
// Invoice(713,List(7131, 7132))
// Invoice(714,List(7141))
// Invoice(715,List(7151, 7152, 7153, 7154))
// Invoice(716,List(7161, 7162, 7163, 7164, 7165))
// Invoice(717,List(7171, 7172, 7173))
// Invoice(718,List(7181, 7182, 7183, 7184, 7185))
// Invoice(719,List(7191, 7192))
// Invoice(720,List(7201, 7202, 7203, 7204, 7205))
// Invoice(721,List(7211, 7212, 7213, 7214))
// Invoice(722,List(7221, 7222, 7223, 7224, 7225))
// Invoice(723,List(7231, 7232, 7233, 7234))
// Invoice(724,List(7241))
// Invoice(725,List(7251))
// Invoice(726,List(7261, 7262, 7263))
// Invoice(727,List(7271, 7272, 7273, 7274))
// Invoice(728,List(7281, 7282, 7283, 7284, 7285))
// Invoice(729,List(7291, 7292))
// Invoice(730,List(7301, 7302, 7303))
// Invoice(801,List(8011, 8012))
// Invoice(802,List(8021, 8022))
// Invoice(803,List(8031))
// Invoice(804,List(8041))
// Invoice(805,List(8051, 8052))
// Invoice(806,List(8061, 8062, 8063))
// Invoice(807,List(8071, 8072))
// Invoice(808,List(8081))
// Invoice(809,List(8091, 8092, 8093, 8094))
// Invoice(810,List(8101, 8102))
// Invoice(811,List(8111, 8112))
// Invoice(812,List(8121, 8122))
// Invoice(813,List(8131, 8132, 8133, 8134, 8135))
// Invoice(814,List(8141, 8142))
// Invoice(815,List(8151, 8152))
// Invoice(816,List(8161, 8162, 8163, 8164))
// Invoice(817,List(8171, 8172, 8173))
// Invoice(818,List(8181, 8182, 8183, 8184))
// Invoice(819,List(8191, 8192, 8193, 8194))
// Invoice(820,List(8201, 8202, 8203, 8204, 8205))
// Invoice(821,List(8211, 8212, 8213, 8214))
// Invoice(822,List(8221))
// Invoice(823,List(8231, 8232, 8233, 8234, 8235))
// Invoice(824,List(8241, 8242))
// Invoice(825,List(8251, 8252, 8253, 8254, 8255))
// Invoice(826,List(8261, 8262, 8263, 8264))
// Invoice(827,List(8271, 8272, 8273, 8274, 8275))
// Invoice(828,List(8281, 8282, 8283, 8284, 8285))
// Invoice(829,List(8291, 8292, 8293))
// Invoice(830,List(8301))
// Invoice(831,List(8311, 8312))
// Invoice(832,List(8321, 8322, 8323, 8324, 8325))
// Invoice(833,List(8331, 8332))
// Invoice(834,List(8341, 8342, 8343))
// Invoice(835,List(8351, 8352, 8353, 8354, 8355))
// Invoice(836,List(8361, 8362, 8363))
// Invoice(837,List(8371))
// Invoice(838,List(8381, 8382, 8383, 8384))
// Invoice(839,List(8391, 8392, 8393, 8394))
// Invoice(840,List(8401))
// Invoice(841,List(8411, 8412, 8413, 8414, 8415))
// Invoice(842,List(8421, 8422))
// Invoice(843,List(8431, 8432, 8433, 8434))
// Invoice(844,List(8441, 8442, 8443, 8444, 8445))
// Invoice(845,List(8451, 8452, 8453, 8454))
// Invoice(846,List(8461, 8462, 8463, 8464, 8465))
// Invoice(847,List(8471))
// Invoice(848,List(8481, 8482, 8483, 8484))
// Invoice(849,List(8491, 8492, 8493))
// Invoice(850,List(8501, 8502, 8503))
// Invoice(851,List(8511, 8512))
// Invoice(852,List(8521, 8522, 8523, 8524, 8525))
// Invoice(853,List(8531, 8532, 8533))
// Invoice(854,List(8541, 8542, 8543, 8544))
// Invoice(855,List(8551))
// Invoice(856,List(8561, 8562, 8563, 8564))
// Invoice(857,List(8571))
// Invoice(858,List(8581))
// Invoice(859,List(8591))
// Invoice(860,List(8601, 8602, 8603, 8604))
// Invoice(861,List(8611, 8612))
// Invoice(862,List(8621, 8622, 8623, 8624))
// Invoice(863,List(8631))
// Invoice(864,List(8641))
// Invoice(865,List(8651, 8652))
// Invoice(866,List(8661, 8662, 8663, 8664, 8665))
// Invoice(867,List(8671))
// Invoice(868,List(8681, 8682, 8683))
// Invoice(869,List(8691, 8692))
// Invoice(870,List(8701))
// Invoice(871,List(8711, 8712))
// Invoice(872,List(8721, 8722))
// Invoice(873,List(8731, 8732, 8733))
// Invoice(874,List(8741, 8742, 8743, 8744))
// Invoice(875,List(8751, 8752, 8753, 8754, 8755))
// Invoice(876,List(8761, 8762))
// Invoice(877,List(8771, 8772, 8773, 8774, 8775))
// Invoice(878,List(8781))
// Invoice(879,List(8791, 8792))
// Invoice(880,List(8801, 8802, 8803))
// Invoice(881,List(8811))
// Invoice(882,List(8821))
// Invoice(883,List(8831, 8832))
// Invoice(884,List(8841, 8842))
// Invoice(885,List(8851))
// Invoice(886,List(8861, 8862, 8863, 8864, 8865))
// Invoice(887,List(8871))
// Invoice(888,List(8881))
// Invoice(889,List(8891, 8892, 8893))
// Invoice(890,List(8901, 8902, 8903))
// Invoice(891,List(8911, 8912))
// Invoice(892,List(8921, 8922, 8923, 8924, 8925))
// Invoice(893,List(8931, 8932))
// Invoice(894,List(8941, 8942, 8943, 8944, 8945))
// Invoice(895,List(8951, 8952, 8953, 8954))
// Invoice(896,List(8961, 8962))
// Invoice(897,List(8971, 8972, 8973, 8974))
// Invoice(898,List(8981, 8982, 8983, 8984))
// Invoice(899,List(8991, 8992))
// Invoice(900,List(9001, 9002, 9003))
// Invoice(901,List(9011))
// Invoice(902,List(9021, 9022, 9023, 9024))
// Invoice(903,List(9031, 9032))
// Invoice(904,List(9041, 9042, 9043, 9044))
// Invoice(905,List(9051, 9052, 9053))
// Invoice(906,List(9061))
// Invoice(907,List(9071, 9072, 9073, 9074, 9075))
// Invoice(908,List(9081, 9082, 9083, 9084, 9085))
// Invoice(909,List(9091, 9092, 9093))
// Invoice(910,List(9101, 9102, 9103, 9104))
// Invoice(911,List(9111, 9112, 9113))
// Invoice(912,List(9121))
// Invoice(913,List(9131, 9132, 9133, 9134))
// Invoice(914,List(9141, 9142, 9143))
// Invoice(915,List(9151, 9152, 9153, 9154, 9155))
// Invoice(916,List(9161, 9162))
// Invoice(917,List(9171, 9172, 9173))
// Invoice(918,List(9181))
// Invoice(919,List(9191, 9192, 9193))
// Invoice(920,List(9201))
// Invoice(921,List(9211, 9212, 9213, 9214, 9215))
// Invoice(922,List(9221))
// Invoice(923,List(9231))
// Invoice(924,List(9241))
// Invoice(925,List(9251, 9252, 9253, 9254, 9255))
// Invoice(926,List(9261))
// Invoice(927,List(9271, 9272, 9273, 9274, 9275))
// Invoice(928,List(9281, 9282, 9283))
// Invoice(929,List(9291, 9292, 9293))
// Invoice(930,List(9301, 9302))
// Invoice(931,List(9311, 9312, 9313))
// Invoice(932,List(9321))
// Invoice(933,List(9331, 9332, 9333, 9334))
// Invoice(934,List(9341))
// Invoice(935,List(9351, 9352, 9353, 9354, 9355))
// Invoice(936,List(9361, 9362, 9363, 9364, 9365))
// Invoice(937,List(9371))
// Invoice(938,List(9381, 9382, 9383))
// Invoice(939,List(9391, 9392, 9393))
// Invoice(940,List(9401, 9402, 9403))
// Invoice(941,List(9411))
// Invoice(942,List(9421, 9422, 9423, 9424, 9425))
// Invoice(943,List(9431, 9432))
// Invoice(944,List(9441))
// Invoice(945,List(9451, 9452))
// Invoice(946,List(9461, 9462))
// Invoice(947,List(9471, 9472, 9473, 9474, 9475))
// Invoice(948,List(9481))
// Invoice(949,List(9491, 9492, 9493, 9494, 9495))
// Invoice(950,List(9501, 9502, 9503, 9504, 9505))
// Invoice(951,List(9511, 9512))
// Invoice(952,List(9521, 9522))
// Invoice(953,List(9531, 9532))
// Invoice(954,List(9541, 9542, 9543, 9544))
// Invoice(955,List(9551))
// Invoice(956,List(9561, 9562, 9563))
// Invoice(957,List(9571, 9572, 9573, 9574))
// Invoice(958,List(9581, 9582, 9583, 9584))
// Invoice(959,List(9591, 9592, 9593, 9594, 9595))
// Invoice(960,List(9601))
// Invoice(961,List(9611, 9612, 9613, 9614))
// Invoice(962,List(9621))
// Invoice(963,List(9631, 9632, 9633, 9634))
// Invoice(964,List(9641, 9642, 9643, 9644, 9645))
// Invoice(965,List(9651, 9652, 9653, 9654))
// Invoice(966,List(9661))
// Invoice(967,List(9671, 9672, 9673, 9674, 9675))
// Invoice(968,List(9681, 9682))
// Invoice(969,List(9691, 9692, 9693, 9694))
// Invoice(970,List(9701))
// Invoice(971,List(9711, 9712, 9713))
// Invoice(972,List(9721))
// Invoice(973,List(9731, 9732, 9733, 9734))
// Invoice(974,List(9741, 9742, 9743))
// Invoice(975,List(9751, 9752))
// Invoice(976,List(9761, 9762, 9763, 9764, 9765))
// Invoice(977,List(9771, 9772, 9773))
// Invoice(978,List(9781, 9782, 9783))
// Invoice(979,List(9791))
// Invoice(980,List(9801))
// Invoice(981,List(9811, 9812))
// Invoice(982,List(9821, 9822, 9823, 9824))
// Invoice(983,List(9831, 9832, 9833, 9834))
// Invoice(984,List(9841, 9842, 9843, 9844))
// Invoice(985,List(9851, 9852))
// Invoice(986,List(9861, 9862, 9863))
// Invoice(987,List(9871, 9872, 9873))
// Invoice(988,List(9881))
// Invoice(989,List(9891, 9892))
// Invoice(990,List(9901, 9902, 9903, 9904))
// Invoice(991,List(9911))
// Invoice(992,List(9921))
// Invoice(993,List(9931))
// Invoice(994,List(9941))
// Invoice(995,List(9951, 9952))
// Invoice(996,List(9961, 9962, 9963, 9964, 9965))
// Invoice(997,List(9971, 9972, 9973, 9974, 9975))
// Invoice(998,List(9981))
// Invoice(999,List(9991, 9992))
// Invoice(1000,List(10001, 10002, 10003, 10004))
// Invoice(1001,List(10011, 10012, 10013, 10014))
// Invoice(1002,List(10021, 10022, 10023))
// Invoice(1003,List(10031, 10032, 10033, 10034, 10035))
// Invoice(1004,List(10041, 10042))
// Invoice(1005,List(10051, 10052))
// Invoice(1006,List(10061, 10062, 10063, 10064))
// Invoice(1007,List(10071, 10072, 10073, 10074, 10075))
// Invoice(1008,List(10081, 10082, 10083, 10084, 10085))
// Invoice(1009,List(10091))
// Invoice(1010,List(10101, 10102, 10103, 10104))
// Invoice(1011,List(10111, 10112, 10113, 10114))
// Invoice(1012,List(10121, 10122, 10123))
// Invoice(1013,List(10131, 10132, 10133, 10134))
// Invoice(1014,List(10141, 10142))
// Invoice(1015,List(10151, 10152, 10153))
// Invoice(1016,List(10161, 10162, 10163, 10164, 10165))
// Invoice(1017,List(10171, 10172))
// Invoice(1018,List(10181))
// Invoice(1019,List(10191, 10192, 10193, 10194, 10195))
// Invoice(1020,List(10201, 10202, 10203))
// Invoice(1021,List(10211, 10212, 10213))
// Invoice(1022,List(10221))
// Invoice(1023,List(10231, 10232, 10233, 10234))
// Invoice(1024,List(10241, 10242, 10243, 10244, 10245))
// Invoice(1025,List(10251, 10252, 10253, 10254, 10255))
// Invoice(1026,List(10261, 10262, 10263, 10264, 10265))
// Invoice(1027,List(10271, 10272, 10273))
// Invoice(1028,List(10281, 10282))
// Invoice(1029,List(10291, 10292, 10293))
// Invoice(1030,List(10301, 10302, 10303, 10304))
// Invoice(1031,List(10311, 10312, 10313, 10314))
// Invoice(1032,List(10321, 10322))
// Invoice(1033,List(10331, 10332, 10333, 10334, 10335))
// Invoice(1034,List(10341, 10342, 10343))
// Invoice(1035,List(10351, 10352, 10353, 10354))
// Invoice(1036,List(10361, 10362))
// Invoice(1037,List(10371, 10372, 10373))
// Invoice(1038,List(10381, 10382, 10383, 10384, 10385))
// Invoice(1039,List(10391, 10392))
// Invoice(1040,List(10401, 10402, 10403, 10404))
// Invoice(1041,List(10411, 10412, 10413))
// Invoice(1042,List(10421))
// Invoice(1043,List(10431))
// Invoice(1044,List(10441))
// Invoice(1045,List(10451, 10452, 10453))
// Invoice(1046,List(10461))
// Invoice(1047,List(10471, 10472))
// Invoice(1048,List(10481, 10482, 10483))
// Invoice(1049,List(10491))
// Invoice(1050,List(10501, 10502, 10503))
// Invoice(1051,List(10511, 10512, 10513, 10514, 10515))
// Invoice(1052,List(10521))
// Invoice(1053,List(10531))
// Invoice(1054,List(10541, 10542))
// Invoice(1055,List(10551))
// Invoice(1056,List(10561, 10562, 10563, 10564, 10565))
// Invoice(1057,List(10571, 10572, 10573, 10574))
// Invoice(1058,List(10581, 10582, 10583))
// Invoice(1059,List(10591, 10592))
// Invoice(1060,List(10601, 10602, 10603))
// Invoice(1061,List(10611))
// Invoice(1062,List(10621, 10622))
// Invoice(1063,List(10631, 10632, 10633, 10634))
// Invoice(1064,List(10641, 10642, 10643))
// Invoice(1065,List(10651))
// Invoice(1066,List(10661))
// Invoice(1067,List(10671, 10672, 10673, 10674, 10675))
// Invoice(1068,List(10681))
// Invoice(1069,List(10691, 10692, 10693))
// Invoice(1070,List(10701))
// Invoice(1071,List(10711, 10712, 10713, 10714))
// Invoice(1072,List(10721))
// Invoice(1073,List(10731))
// Invoice(1074,List(10741, 10742, 10743))
// Invoice(1075,List(10751, 10752))
// Invoice(1076,List(10761, 10762))
// Invoice(1077,List(10771, 10772, 10773, 10774))
// Invoice(1078,List(10781, 10782, 10783, 10784))
// Invoice(1079,List(10791, 10792, 10793, 10794, 10795))
// Invoice(1080,List(10801, 10802, 10803))
// Invoice(1081,List(10811))
// Invoice(1082,List(10821, 10822, 10823, 10824))
// Invoice(1991,List(19911, 19912))
// Invoice(1992,List(19921, 19922, 19923, 19924, 19925))
// Invoice(1993,List(19931))
// Invoice(1994,List(19941, 19942, 19943))
// Invoice(1995,List(19951, 19952))
// Invoice(1996,List(19961, 19962, 19963))
// Invoice(1997,List(19971))
// Invoice(1998,List(19981, 19982, 19983, 19984, 19985))
// Invoice(1999,List(19991))
// Invoice(2000,List(20001, 20002))
// defined class Employee
// defined class MediaType
// defined class Genre
// defined class Track
// defined class InvoiceItem
// defined class Invoice
// employees = Array(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// mediaTypes = Array(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// genres = Array(Genre(...
// Array(Genre(...

// %% [markdown]
// # Atelier 3
//
// ## 1/ Filtrage - Titre en fonction d'un média spécifique

// %%
val mediaFilter = List(1, 3, 5)

val filteredTracks = tracksArray.filter(track => mediaFilter.contains(track.mediaTypeId))

println(s"Nombre de tracks filtrées: ${filteredTracks.length}")
// Out:
// Nombre de tracks filtrées: 108
// mediaFilter = List(1, 3, 5)
// filteredTracks = Array(Track(2,Crystal Rebels from the Desert,3,13), Track(4,Stellar Machines in Shadow,3,6), Track(7,Arctic Wizards from Beyond,5,19), Track(9,Toxic Bandits of Doom,3,20), Track(11,Wild Rebels from the Desert,1,5), Track(14,Royal Titans in Exile,1,6), Track(15,Crystal Warriors in Chains,5,25), Track(16,Stellar Pirates of Tomorrow,1,7), Track(17,Sacred Saints of the North,3,3), Track(22,Electric Zombies from Mars,5,2), Track(24,Liquid Heroes of Destruction,1,9), Track(26,Stellar Rebels of Eternity,5,18), Track(27,Neon Lions of Doom,3,18), Track(30,Sonic Giants in Disguise,1,17), Track(31,Eternal Shadows from the Sky,1,20), Track(33,Atomic Bandits from Mars,5,22), Track(35,Wild Dragons of Doom,1,16), Track(37,Mystic Pro...
// Array(Track(2,Crystal Rebels from the Desert,3,13), Track(4,Stellar Machines in Shadow,3,6), Track(7,Arctic Wizards from Beyond,5,19), Track(9,Toxic Bandits of Doom,3,20), Track(11,Wild Rebels from the Desert,1,5), Track(14,Royal Titans in Exile,1,6), Track(15,Crystal Warriors in Chains,5,25), Track(16,Stellar Pirates of Tomorrow,1,7), Track(17,Sacred Saints of the North,3,3), Track(22,Electric Zombies from Mars,5,2), Track(24,Liquid Heroes of Destruction,1,9), Track(26,Stellar Rebels of Eternity,5,18), Track(27,Neon Lions of Doom,3,18), Track(30,Sonic Giants in Disguise,1,17), Track(31,Eternal Shadows from the Sky,1,20), Track(33,Atomic Bandits from Mars,5,22), Track(35,Wild Dragons of Doom,1,16), Track(37,Mystic Pro...

// %% [markdown]
// ## 1/ Filtrage - Commandes ayant un maximum de titres du genre 1

// %%
// Inititation InvoiceItems
val invoiceItems = invoicesArray.flatMap { invoice =>
  val itemCount = Random.nextInt(5) + 1
  val selectedTracks = Random.shuffle(tracksArray.toList).take(itemCount)
  
  selectedTracks.zipWithIndex.map { case (track, index) =>
    val quantity = if (Random.nextDouble() > 0.2) 1 else Random.nextInt(3) + 1
    val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
    
    InvoiceItem(
      invoiceLineId = invoice.invoiceId * 10 + index + 1,
      invoiceId = invoice.invoiceId,
      trackId = track.trackId,
      unitPrice = unitPrice,
      quantity = quantity
    )
  }
}

def countGenre1TracksInInvoice(invoiceId: Int): Int = {
  invoiceItems
    .filter(_.invoiceId == invoiceId)
    .map(_.trackId)
    .map(trackId => tracksArray.find(_.trackId == trackId))
    .flatten
    .count(_.genreId == 1)
}

val maxGenre1Count = invoicesArray.map(invoice => countGenre1TracksInInvoice(invoice.invoiceId)).max

val invoicesWithMaxGenre1 = invoicesArray.filter(invoice => 
  countGenre1TracksInInvoice(invoice.invoiceId) == maxGenre1Count
)

println(s"Maximum de titres du genre 1 (Rock) dans une commande: $maxGenre1Count")
println(s"Nombre de commandes ayant ce maximum: ${invoicesWithMaxGenre1.length}")
// Out:
// Maximum de titres du genre 1 (Rock) dans une commande: 3
// Nombre de commandes ayant ce maximum: 1
// invoiceItems = Array(InvoiceItem(11,1,57,1.66,1), InvoiceItem(21,2,195,1.00,1), InvoiceItem(31,3,109,1.85,1), InvoiceItem(41,4,191,1.99,2), InvoiceItem(42,4,154,1.63,1), InvoiceItem(51,5,78,1.18,1), InvoiceItem(61,6,84,1.83,1), InvoiceItem(62,6,142,2.00,1), InvoiceItem(63,6,199,1.27,1), InvoiceItem(64,6,70,1.35,1), InvoiceItem(65,6,161,1.22,1), InvoiceItem(71,7,196,1.39,1), InvoiceItem(81,8,137,1.93,1), InvoiceItem(82,8,51,1.78,1), InvoiceItem(91,9,155,1.84,1), InvoiceItem(92,9,179,1.74,1), InvoiceItem(93,9,40,1.33,1), InvoiceItem(94,9,156,1.42,1), InvoiceItem(95,9,194,1.51,1), InvoiceItem(101,10,169,1.94,1), InvoiceItem(111,11,164,1.22,1), InvoiceItem(112,11,179,1.38,1), InvoiceItem(113,11,129,1.87,1), InvoiceItem(121,12,198,1.54,1), InvoiceItem(122,12,129,1.91,2), ...
// Array(InvoiceItem(11,1,57,1.66,1), InvoiceItem(21,2,195,1.00,1), InvoiceItem(31,3,109,1.85,1), InvoiceItem(41,4,191,1.99,2), InvoiceItem(42,4,154,1.63,1), InvoiceItem(51,5,78,1.18,1), InvoiceItem(61,6,84,1.83,1), InvoiceItem(62,6,142,2.00,1), InvoiceItem(63,6,199,1.27,1), InvoiceItem(64,6,70,1.35,1), InvoiceItem(65,6,161,1.22,1), InvoiceItem(71,7,196,1.39,1), InvoiceItem(81,8,137,1.93,1), InvoiceItem(82,8,51,1.78,1), InvoiceItem(91,9,155,1.84,1), InvoiceItem(92,9,179,1.74,1), InvoiceItem(93,9,40,1.33,1), InvoiceItem(94,9,156,1.42,1), InvoiceItem(95,9,194,1.51,1), InvoiceItem(101,10,169,1.94,1), InvoiceItem(111,11,164,1.22,1), InvoiceItem(112,11,179,1.38,1), InvoiceItem(113,11,129,1.87,1), InvoiceItem(121,12,198,1.54,1), InvoiceItem(122,12,129,1.91,2), ...

// %% [markdown]
// ## 2/ Agrégations - Top 5 titres en nombre de ventes

// %%
val trackSales = invoiceItems
  .groupBy(_.trackId)
  .map { case (trackId, items) =>
    trackId -> items.map(_.quantity).sum
  }

val top5Tracks = trackSales
  .toSeq
  .sortBy(-_._2)
  .take(5)
  .map { case (trackId, totalSales) =>
    val track = tracksArray.find(_.trackId == trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (track, totalSales, genreName)
  }

println("Top 5 des titres en nombre de ventes:")
top5Tracks.zipWithIndex.foreach { case ((track, sales, genre), index) =>
  println(s"${index + 1}. ${track.name} - $sales ventes (Genre: $genre)")
}
// Out:
// Top 5 des titres en nombre de ventes:
// 1. Midnight Ravens from the Sky - 57 ventes (Genre: Blues)
// 2. Eternal Angels of the North - 52 ventes (Genre: Blues)
// 3. Sacred Rebels of Eternity - 52 ventes (Genre: Soundtrack)
// 4. Silent Empire in Shadow - 51 ventes (Genre: Alternative & Punk)
// 5. Liquid Dragons in Chains - 51 ventes (Genre: Classical)
// trackSales = Map(69 -> 45, 138 -> 48, 101 -> 32, 88 -> 18, 170 -> 35, 115 -> 34, 5 -> 37, 120 -> 36, 10 -> 30, 56 -> 43, 142 -> 39, 153 -> 37, 174 -> 51, 185 -> 43, 42 -> 25, 24 -> 43, 37 -> 36, 25 -> 49, 52 -> 48, 14 -> 47, 184 -> 44, 110 -> 29, 125 -> 41, 196 -> 33, 157 -> 40, 189 -> 40, 20 -> 35, 46 -> 26, 93 -> 42, 152 -> 35, 57 -> 33, 78 -> 35, 29 -> 30, 164 -> 35, 179 -> 42, 106 -> 48, 121 -> 48, 84 -> 33, 147 -> 38, 61 -> 36, 132 -> 36, 89 -> 27, 133 -> 29, 116 -> 40, 1 -> 32, 74 -> 25, 6 -> 36, 60 -> 33, 117 -> 36, 85 -> 21, 102 -> 30, 28 -> 28, 38 -> 45, 160 -> 38, 70 -> 38, 192 -> 47, 21 -> 41, 137 -> 40, 165 -> 40, 33 -> 37, 92 -> 28, 197 -> 33, 65 -> 46, 97 -> 51, 156 -> 37, 9 -> 36, 188 -> 28, 53 -> 46, 169 -> 42, 141 -> 28, 109 -> 3...
// Map(69 -> 45, 138 -> 48, 101 -> 32, 88 -> 18, 170 -> 35, 115 -> 34, 5 -> 37, 120 -> 36, 10 -> 30, 56 -> 43, 142 -> 39, 153 -> 37, 174 -> 51, 185 -> 43, 42 -> 25, 24 -> 43, 37 -> 36, 25 -> 49, 52 -> 48, 14 -> 47, 184 -> 44, 110 -> 29, 125 -> 41, 196 -> 33, 157 -> 40, 189 -> 40, 20 -> 35, 46 -> 26, 93 -> 42, 152 -> 35, 57 -> 33, 78 -> 35, 29 -> 30, 164 -> 35, 179 -> 42, 106 -> 48, 121 -> 48, 84 -> 33, 147 -> 38, 61 -> 36, 132 -> 36, 89 -> 27, 133 -> 29, 116 -> 40, 1 -> 32, 74 -> 25, 6 -> 36, 60 -> 33, 117 -> 36, 85 -> 21, 102 -> 30, 28 -> 28, 38 -> 45, 160 -> 38, 70 -> 38, 192 -> 47, 21 -> 41, 137 -> 40, 165 -> 40, 33 -> 37, 92 -> 28, 197 -> 33, 65 -> 46, 97 -> 51, 156 -> 37, 9 -> 36, 188 -> 28, 53 -> 46, 169 -> 42, 141 -> 28, 109 -> 3...

// %% [markdown]
// ## 2/ Agrégations - Total commande par genre

// %%
val totalByGenre = invoiceItems
  .map { item =>
    val track = tracksArray.find(_.trackId == item.trackId).get
    val genreName = genres.find(_.genreId == track.genreId).map(_.name).getOrElse("Unknown")
    (genreName, item.unitPrice * item.quantity, item.quantity)
  }
  .groupBy(_._1)
  .map { case (genre, items) =>
    val total = items.map(_._2).sum
    val commandes = items.map(_._3).sum
    (genre, total, commandes)
  }
  .toSeq
  .sortBy(-_._2)

println("Total des commandes par genre:")
totalByGenre.foreach { case (genre, total, commandes) =>
  println(f"$genre: $commandes commandes pour ${total}%.2f€")
}
// Out:
// Total des commandes par genre:
// Alternative & Punk: 496 commandes pour 742.03€
// Blues: 450 commandes pour 671.88€
// World: 406 commandes pour 608.80€
// TV Shows: 374 commandes pour 568.44€
// Rock: 367 commandes pour 550.89€
// Science Fiction: 360 commandes pour 531.85€
// Soundtrack: 353 commandes pour 523.54€
// Classical: 331 commandes pour 485.37€
// Metal: 321 commandes pour 475.15€
// Heavy Metal: 308 commandes pour 464.41€
// Jazz: 313 commandes pour 458.27€
// Rock And Roll: 286 commandes pour 442.14€
// Latin: 293 commandes pour 435.93€
// Hip Hop/Rap: 285 commandes pour 423.54€
// Alternative: 281 commandes pour 422.89€
// Electronica/Dance: 269 commandes pour 408.37€
// Pop: 266 commandes pour 399.40€
// Sci Fi & Fantasy: 262 commandes pour 394.15€
// Comedy: 246 commandes pour 363.53€
// Reggae: 231 commandes pour 341.49€
// Easy Listening: 212 commandes pour 319.06€
// Bossa Nova: 205 commandes pour 296.28€
// Opera: 151 commandes pour 224.98€
// R&B/Soul: 138 commandes pour 208.35€
// Drama: 35 commandes pour 54.60€
// totalByGenre = List((Alternative & Punk,742.03,496), (Blues,671.88,450), (World,608.80,406), (TV Shows,568.44,374), (Rock,550.89,367), (Science Fiction,531.85,360), (Soundtrack,523.54,353), (Classical,485.37,331), (Metal,475.15,321), (Heavy Metal,464.41,308), (Jazz,458.27,313), (Rock And Roll,442.14,286), (Latin,435.93,293), (Hip Hop/Rap,423.54,285), (Alternative,422.89,281), (Electronica/Dance,408.37,269), (Pop,399.40,266), (Sci Fi & Fantasy,394.15,262), (Comedy,363.53,246), (Reggae,341.49,231), (Easy Listening,319.06,212), (Bossa Nova,296.28,205), (Opera,224.98,151), (R&B/Soul,208.35,138), (Drama,54.60,35))
// List((Alternative & Punk,742.03,496), (Blues,671.88,450), (World,608.80,406), (TV Shows,568.44,374), (Rock,550.89,367), (Science Fiction,531.85,360), (Soundtrack,523.54,353), (Classical,485.37,331), (Metal,475.15,321), (Heavy Metal,464.41,308), (Jazz,458.27,313), (Rock And Roll,442.14,286), (Latin,435.93,293), (Hip Hop/Rap,423.54,285), (Alternative,422.89,281), (Electronica/Dance,408.37,269), (Pop,399.40,266), (Sci Fi & Fantasy,394.15,262), (Comedy,363.53,246), (Reggae,341.49,231), (Easy Listening,319.06,212), (Bossa Nova,296.28,205), (Opera,224.98,151), (R&B/Soul,208.35,138), (Drama,54.60,35))

// %% [markdown]
// ## 3/ Traitement récursif - Fonction récursive pour trouver le plus haut responsable

// %%
def findTopManager(employeeId: Int): Employee = {
  val employee = employees.find(_.employeeId == employeeId)
    .getOrElse(throw new IllegalArgumentException(s"Employee $employeeId not found"))
  
  if (employee.reportsTo == 0) {
    employee
  } else {
    findTopManager(employee.reportsTo)
  }
}

println("Tests de la fonction récursive findTopManager:")
println()

employees.foreach { employee =>
  val topManager = findTopManager(employee.employeeId)
  val hierarchy = buildHierarchyPath(employee.employeeId)
  
  println(s"${employee.firstName} ${employee.lastName} (${employee.title})")
  println(s"  → Plus haut responsable: ${topManager.firstName} ${topManager.lastName} (${topManager.title})")
  println(s"  → Chemin hiérarchique: $hierarchy")
  println()
}

def buildHierarchyPath(employeeId: Int): String = {
  def buildPath(currentId: Int, path: List[String]): List[String] = {
    val employee = employees.find(_.employeeId == currentId).get
    val employeeName = s"${employee.firstName} ${employee.lastName}"

    if (employee.reportsTo == 0) {
      path :+ employeeName
    } else {
      buildPath(employee.reportsTo, path :+ employeeName)
    }
  }

  buildPath(employeeId, List()).mkString(" → ")
}
// Out:
// findTopManager: (employeeId: Int)Employee
// buildHierarchyPath: (employeeId: Int)String
// Tests de la fonction récursive findTopManager:
//
// Andrew Adams (General Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Andrew Adams
//
// Nancy Edwards (Sales Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Nancy Edwards → Andrew Adams
//
// Jane Peacock (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Jane Peacock → Nancy Edwards → Andrew Adams
//
// Margaret Park (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Margaret Park → Nancy Edwards → Andrew Adams
//
// Steve Johnson (Sales Support Agent)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Steve Johnson → Nancy Edwards → Andrew Adams
//
// Michael Mitchell (IT Manager)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Michael Mitchell → Andrew Adams
//
// Robert King (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Robert King → Michael Mitchell → Andrew Adams
//
// Laura Callahan (IT Staff)
//   → Plus haut responsable: Andrew Adams (General Manager)
//   → Chemin hiérarchique: Laura Callahan → Michael Mitchell → Andrew Adams

// %% [markdown]
// # ATELIER 4 - Transposition sur Spark
//
// ## At. 4 - Etape 1/ Manipulation des données générées

// %% [markdown]
// ## Etape 2/ Analyse des transformation

// %% [markdown]
// ## Etape 3/ Chargement des CSV
